# %% [markdown]
# By: Muhammad Khalid - Samaa Khaled
# Based on: Eng. Muhammad Alaref startup code

# %% [markdown]
# # Reinforcement Learning (RL)
#
# Reinforcement learning is a technique used in _unknown_ environments. It is based on the idea of rewards that differentiate good states from bad ones. That is, the environment changes with every action you take in undeterministic ways and the distribution of possible next states is _unknown_. The only _precepts_ taken from the environment are the current state, the possible actions and the reward upon doing any action. Therefore, some form of _learning_ is needed to make progress in these environments.
#
# We use the same definitions, concepts and annotations from decision processes; $s$, $a$, $s'$, $a'$, etc.

# %% [markdown]
# ## Environment Formulation
#
# We formulate an environment in a similar way to decision processes _without_ a way to know the transition model.

# %%
class Environment:
    '''
    Abstract base class for an (interactive) environment formulation.
    It declares the expected methods to be used to solve it.
    All the methods declared are just placeholders that throw errors if not overriden by child "concrete" classes!
    '''
    
    def __init__(self):
        '''Constructor that initializes the problem. Typically used to setup the initial state.'''
        self.state = None
    
    def actions(self):
        '''Returns an iterable with the applicable actions to the current environment state.'''
        raise NotImplementedError
    
    def apply(self, action):
        '''Applies the action to the current state of the environment and returns the new state from applying the given action to the current environment state; not necessarily deterministic.'''
        raise NotImplementedError
    
    @classmethod
    def new_random_instance(cls):
        '''Factory method to a problem instance with a random initial state.'''
        raise NotImplementedError

# %% [markdown]
# Generally, to _learn_ any value, we can experiment in the environment and keep a tally of our the experiences. Then, using the consecutive rewards collected, value estimates can be calculated. Also, by keeping track of transition statistics, the transition model can be estimated. This, in effect, reduces the problem to an MDP that can be solved using value or policy iteration techniques. This is called **model-based** learning.
#
# $$V = E[V]$$
#
# Another way to estimate a value is to start with an initial value (say 0) and update it with every new experience. This is called **temporal-difference (TD) learning**. _Note that does NOT require the transition model for learning!_ This is called **model-free** learning and it will be focus of this notebook.
#
# $$V = (1 - \alpha)V_{old} + \alpha V_{new} $$
# or equivalently,
# $$V = V_{old} + \alpha (V_{new} - V_{old}) $$
#
# _Provided $\alpha$ decreases as the number of experiences (of $V$) increases, $V$ will converge to the true value._

# %% [markdown]
# ## Q-Learning
#
# Recall how we get a policy from Q-values!
#
# $$\pi^*(s) = \argmax_{a \in A_s} Q(s,a)$$
#
# Unlike value iteration and policy iteration that rely on utility values, extracting the policy from Q-values does NOT depend on the transition model in any way.

# %%
from shutil import get_terminal_size
terminal_width, _ = get_terminal_size()

_visualizers = {}

def _default_visualizer(_, state):
    '''Generic visualizer for unknown problems.'''
    print(state)

class Visualizer:
    '''Visualization and printing functionality encapsulation.'''

    def __init__(self, problem):
        '''Constructor with the problem to visualize.'''
        self.problem = problem
        self.counter = 0
    
    def visualize(self, frontier):
        '''Visualizes the frontier at every step.'''
        self.counter += 1
        print(f'Frontier at step {self.counter}')
        for state in frontier:
            print()
            _visualizers.get(type(self.problem), _default_visualizer)(self.problem, state)
        print('-' * terminal_width)

def _tom_and_jerry_visualizer(env, state):
    '''Custom visualizer for Tom and Jerry.'''
    tom, jerry, spike = env.state
    for j in range(env.bounds[1] - 1, -1, -1):
        for i in range(env.bounds[0]):
            print('🐱' if (i, j) == tom else '🐭' if (i, j) == jerry else '🐶' if (i, j) == spike else '⬜', end='')
        print()

# %%
def action_from_q(env, q, verbose=True):
    '''Get the best action for the current state of the environment from Q-values'''
    return max((action for action in env.actions()), key=lambda action: q.get((env.state, action), 0))

# %% [markdown]
# Combining Q-values with TD learning yields an iterative technique that does not need a transition model in learning nor in decision making!
#
# $$Q_{i+1}(s,a) = Q_i(s,a) + \alpha (r_s + \gamma \times \max_{a'} Q_i(s',a') - Q_i(s,a))$$

# %%
def q_learning(env, q={}, n={}, f=lambda q, n: (q+1)/(n+1), alpha=lambda n: 60/(n+59), error=1e-6, verbose=False):
    '''Q-learning implementation that trains on an environment till no more actions can be taken'''
    if verbose: visualizer = Visualizer(env)
    while env.state is not None:
        if verbose: visualizer.visualize([env.state])
        state = env.state
        action = max(env.actions(),
                     key=lambda next_action: f(q.get((state, next_action), 0), n.get((state, next_action), 0)))
        n[(state, action)] = n.get((state, action), 0) + 1
        reward = env.apply(action)
        q[(state, action)] = q.get((state, action), 0) \
                           + alpha(n[state, action]) \
                           * (reward
                              + env.discount * max((q.get((env.state, next_action), 0) for next_action in env.actions()), default=0)
                              - q.get((state, action), 0))
    return q, n

# %% [markdown]
# Now, we have one question left to answer: what is `f`? That is, _how_ are we going to act in the environment? What actions should be taken in each state to _learn_? Different strategies yield with different properties!
#
# Right now, let's leave it as is (we will come back to it later) and consider an example _(+ a little bit of helper code for simulation)_!

# %%
from math import inf
from time import time
from itertools import count

def simulate(env_ctor, n_iterations=inf, duration=inf, **q_learning_params):
    '''A helper function to train for a fixed number of iterations or fixed time'''
    for param in ('q', 'n'): q_learning_params[param] = q_learning_params.get(param, {})
    start_time = time()
    i = count()
    while time() < start_time + duration and next(i) < n_iterations:
        env = env_ctor()
        q, n = q_learning(env, **q_learning_params)
        q.append()
    return q_learning_params['q'], q_learning_params['n']

# %% [markdown]
# #ZC Agent

# %%
from random import choice, randrange , random
#6 is OSS , 9 is AB Gate A , 8 is AB gate F , 7 is NB , 11 is HB , 13 is AB Gate B , 14 and 10 are cancelled
class ZCRobot(Environment):
    '''Dynamic Tom & Jerry world'''
    def __init__(self, maxReward, discount , movingReward , actionsLimit):
              self.ResultsMovements =  {1:{ 'SE':3 }
                          , 2: { 'SE':4 }
                          , 3 : {'NW':1 , 'NE':4 , 'SW':17}
                          , 4: {'NW':2 , 'SW':3 , 'NE':5}
                          , 5: {'NE':6 , 'SW':4}
                          , 6: {'SW':5 , 'S':9 , 'E':7}
                          , 7: {'W':6 , 'SW':8 }
                          , 8: {'NE':7}
                          , 9: {'N':6}
                          , 11: {'W':16}
                          , 12: {'NW':15 , 'SE':13}
                          , 13:{'NW':12}
                          , 15: {'N':16 , 'SE':12}
                          , 16: {'S':15 , 'E':11 , 'NE':17}
                          , 17: {'NE':3 , 'SW':16 } }

              import random
              self.state = (random.randint(1, 2) , False , 4 , 4 , 0 , 0) 
              #initial place (1 or 2) -> main gate
              #False: not carrying anything
              #First 4: four remaining items in NB
              #Second 4: four remaning items in HB
              #First 0: Zero delivered items to AB
              #Second 0: Zero delivered items to OSS
              self.maxReward = maxReward #Max reward is when you deliver all items
              self.discount = discount #discout rate
              self.movingReward = movingReward #moving reward is when you Pick/Deliver items
              self.actionsLimit = actionsLimit #limit the number of actions taken in one itteration
    def actions(self):
              if self.state is None: return [] #as defined in q_learning function to terminate the learning
              directions = []
              for i in self.ResultsMovements[self.state[0]]: #get all possible movements from a given location
                directions.append(i) #all possible directions to move
              
              #Now we need to check if we are in NB or HB because in this case the action will be only PickUp !
              #As defined, location 7 is NB and location 11 is HB

              if ( (self.state[0] == 7) and (self.state[1] == False) and (self.state[2] == 1 or self.state[2] == 2 or self.state[2] == 3 or self.state[2] == 4 ) ): return['Pick']
              #if you are in NB , and you are not carrying anythinig , and there are 1 or 2 or 3 or 4 items left in NB, then take an item.

              if ( (self.state[0] == 11) and (self.state[1] == False) and (self.state[3] == 1 or self.state[3] == 2 or self.state[3] == 3 or self.state[3] == 4 ) ): return['Pick']
              #if you are in HB , and you are not carrying anythinig , and there are 1 or 2 or 3 or 4 items left in NB, then take an item.


              #Now we need to check if we are in AB or OSS because in this case the action will be only Deliver !
              #As defined, location 6 is One Stop Shop and location 8,9,13 are AB
              
              if ( (self.state[0] == 6) and (self.state[1] == True) and (self.state[4] == 1 or self.state[4] == 2 or self.state[4] == 3 or self.state[4] == 0 ) ): return['Deliver']
              #if you are in OSS , and you are carrying anythinig , and there are 1 or 2 or 3 or 0 items left in OSS, then deliver an item.                            
              
              
              if ( ( (self.state[0] == 8) or (self.state[0] == 9) or (self.state[0] == 13) )and (self.state[1] == True) and (self.state[5] == 1 or self.state[5] == 2 or self.state[5] == 3 or self.state[5] == 0 ) ): return['Deliver']
              #if you are in AB , and you are carrying anythinig , and there are 1 or 2 or 3 or 0 items left in OSS, then deliver an item.  



              #if you are not in any of the previous buildings , or you are carrying an item , then return list of possible actions
              return directions 
          


    def apply(self, action):
              tempState = list(self.state)
              #We have limits in actions (ex: 1000 , for each action appy, reduce the limit by 1)
              self.actionsLimit = self.actionsLimit - 1

              #if the agent consumed the allowable number of actions then return end the game

              if(self.actionsLimit == 0):
                self.state = None
                return -self.maxReward



              #WON THE GAME
              #If you are in either OSS or AB and all are delivered then the agent won the game
              #AB
              if (( (self.state[0] == 8) or (self.state[0] == 9) or (self.state[0] == 13) ) and (self.state[1] == False) and (self.state[2] == 0 ) and (self.state[3] == 0 )  and (self.state[4] == 4 and (self.state[5] == 4 ) )):
                 self.state = None
                 return self.maxReward

              #OSS
              if ((self.state[0] == 6 ) and (self.state[1] == False) and (self.state[2] == 0 ) and (self.state[3] == 0 )  and (self.state[4] == 4 and (self.state[5] == 4 ) )):
                 self.state = None
                 return self.maxReward

              #Else , if you are taking then update the remaining items in NB or HB
              if ((self.state[0] == 7 ) and (action == 'Pick')): #NB
                  tempState[1] = True #Carrying
                  tempState[2] = tempState[2]-1
                  self.state = tuple(tempState)
                  return self.movingReward


              if ( self.state[0] == 11  ) and (action == 'Pick'): #HB
                  tempState[1] = True #Carrying
                  tempState[3] = tempState[3]-1
                  self.state = tuple(tempState)
                  return self.movingReward



              #Else , if you are Delivering then update the remaining items in AB or OSS
              if ((self.state[0] == 6 ) and (action == 'Deliver')): #OSS
                  tempState[1] = False #Delivering
                  tempState[4] = tempState[4]+1
                  self.state = tuple(tempState)
                  return self.movingReward


              if ( (self.state[0] == 8) or (self.state[0] == 9) or (self.state[0] == 13)  ) and (action == 'Deliver'): #AB
                  tempState[1] = False #Delivering
                  tempState[5] = tempState[5]+1
                  self.state = tuple(tempState)
                  return self.movingReward




              #Else, If you are moving between other roads
              else:
                Num = self.ResultsMovements[tempState[0]][action]
                tempState[0] = Num
                self.state = tuple(tempState)
                return -1 #Negative reward equivalent to the cost between both roads

# %% [markdown]
# #Random Q-Learning

# %%
q, n = {}, {}
#(self, maxReward, discount , movingReward , actionsLimit):
simulate(lambda: ZCRobot(50,0.1,30,3000), duration=60, q=q, n=n)
simulate(lambda: ZCRobot(50,0.1,30,3000), n_iterations=1, q=q, n=n, verbose=True)
# Out:
# Streaming output truncated to the last 5000 lines.
# Frontier at step 1751
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1752
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1753
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1754
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1755
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1756
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1757
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1758
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1759
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1760
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1761
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1762
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1763
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1764
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1765
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1766
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1767
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1768
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1769
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1770
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1771
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1772
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1773
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1774
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1775
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1776
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1777
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1778
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1779
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1780
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1781
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1782
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1783
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1784
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1785
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1786
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1787
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1788
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1789
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1790
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1791
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1792
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1793
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1794
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1795
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1796
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1797
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1798
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1799
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1800
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1801
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1802
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1803
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1804
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1805
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1806
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1807
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1808
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1809
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1810
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1811
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1812
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1813
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1814
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1815
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1816
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1817
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1818
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1819
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1820
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1821
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1822
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1823
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1824
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1825
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1826
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1827
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1828
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1829
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1830
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1831
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1832
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1833
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1834
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1835
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1836
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1837
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1838
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1839
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1840
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1841
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1842
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1843
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1844
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1845
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1846
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1847
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1848
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1849
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1850
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1851
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1852
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1853
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1854
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1855
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1856
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1857
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1858
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1859
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1860
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1861
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1862
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1863
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1864
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1865
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1866
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1867
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1868
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1869
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1870
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1871
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1872
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1873
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1874
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1875
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1876
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1877
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1878
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1879
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1880
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1881
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1882
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1883
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1884
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1885
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1886
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1887
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1888
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1889
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1890
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1891
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1892
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1893
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1894
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1895
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1896
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1897
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1898
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1899
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1900
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1901
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1902
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1903
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1904
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1905
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1906
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1907
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1908
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1909
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1910
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1911
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1912
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1913
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1914
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1915
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1916
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1917
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1918
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1919
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1920
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1921
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1922
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1923
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1924
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1925
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1926
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1927
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1928
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1929
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1930
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1931
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1932
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1933
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1934
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1935
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1936
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1937
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1938
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1939
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1940
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1941
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1942
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1943
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1944
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1945
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1946
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1947
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1948
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1949
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1950
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1951
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1952
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1953
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1954
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1955
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1956
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1957
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1958
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1959
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1960
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1961
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1962
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1963
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1964
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1965
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1966
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1967
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1968
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1969
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1970
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1971
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1972
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1973
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1974
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1975
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1976
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1977
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1978
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1979
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1980
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1981
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1982
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1983
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1984
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1985
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1986
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1987
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1988
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1989
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1990
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1991
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1992
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1993
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1994
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1995
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1996
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1997
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1998
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 1999
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2000
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2001
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2002
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2003
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2004
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2005
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2006
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2007
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2008
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2009
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2010
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2011
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2012
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2013
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2014
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2015
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2016
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2017
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2018
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2019
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2020
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2021
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2022
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2023
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2024
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2025
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2026
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2027
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2028
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2029
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2030
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2031
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2032
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2033
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2034
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2035
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2036
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2037
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2038
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2039
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2040
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2041
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2042
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2043
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2044
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2045
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2046
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2047
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2048
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2049
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2050
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2051
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2052
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2053
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2054
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2055
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2056
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2057
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2058
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2059
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2060
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2061
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2062
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2063
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2064
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2065
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2066
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2067
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2068
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2069
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2070
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2071
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2072
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2073
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2074
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2075
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2076
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2077
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2078
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2079
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2080
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2081
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2082
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2083
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2084
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2085
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2086
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2087
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2088
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2089
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2090
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2091
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2092
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2093
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2094
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2095
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2096
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2097
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2098
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2099
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2100
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2101
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2102
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2103
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2104
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2105
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2106
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2107
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2108
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2109
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2110
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2111
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2112
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2113
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2114
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2115
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2116
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2117
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2118
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2119
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2120
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2121
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2122
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2123
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2124
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2125
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2126
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2127
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2128
#
# (4, False, 4, 4, 0, 0)
# ...
#   ((3, True, 4, 1, 0, 2), 'NW'): -1.0,
#   ((1, True, 4, 1, 0, 2), 'SE'): -1.0,
#   ((3, True, 4, 1, 0, 2), 'NE'): -1.0,
#   ((4, True, 4, 1, 0, 2), 'NW'): -1.0,
#   ((2, True, 4, 1, 0, 2), 'SE'): -1.0,
#   ((4, True, 4, 1, 0, 2), 'SW'): -1.0,
#   ((3, True, 4, 1, 0, 2), 'SW'): -1.0,
#   ((17, True, 4, 1, 0, 2), 'SW'): -1.1,
#   ((15, True, 4, 1, 0, 2), 'SE'): -1.0,
#   ((12, True, 4, 1, 0, 2), 'NW'): -1.1,
#   ((12, True, 4, 1, 0, 2), 'SE'): -1.0,
#   ((13, True, 4, 1, 0, 2), 'Deliver'): 30.0,
#   ((13, False, 4, 1, 0, 3), 'NW'): -1.098360655737705,
#   ((12, False, 4, 1, 0, 3), 'NW'): -1.098360655737705,
#   ((15, False, 4, 1, 0, 3), 'N'): -1.0,
#   ((16, False, 4, 1, 0, 3), 'S'): -1.0,
#   ((15, False, 4, 1, 0, 3), 'SE'): -1.0,
#   ((12, False, 4, 1, 0, 3), 'SE'): -1.1,
#   ((16, False, 4, 1, 0, 3), 'E'): -1.0,
#   ((11, False, 4, 1, 0, 3), 'Pick'): 30.0,
#   ((11, True, 4, 0, 0, 3), 'W'): -1.0,
#   ((16, True, 4, 0, 0, 3), 'S'): -1.0967741935483872,
#   ((15, True, 4, 0, 0, 3), 'N'): -1.098360655737705,
#   ((16, True, 4, 0, 0, 3), 'E'): -1.1,
#   ((16, True, 4, 0, 0, 3), 'NE'): -1.0,
#   ((17, True, 4, 0, 0, 3), 'NE'): -1.0,
#   ((3, True, 4, 0, 0, 3), 'NW'): -1.0,
#   ((1, True, 4, 0, 0, 3), 'SE'): -1.0,
#   ((3, True, 4, 0, 0, 3), 'NE'): -1.0,
#   ((4, True, 4, 0, 0, 3), 'NW'): -1.0,
#   ((2, True, 4, 0, 0, 3), 'SE'): -1.0,
#   ((4, True, 4, 0, 0, 3), 'SW'): -1.0,
#   ((3, True, 4, 0, 0, 3), 'SW'): -1.0,
#   ((17, True, 4, 0, 0, 3), 'SW'): -1.1,
#   ((15, True, 4, 0, 0, 3), 'SE'): -1.0,
#   ((12, True, 4, 0, 0, 3), 'NW'): -1.1,
#   ((12, True, 4, 0, 0, 3), 'SE'): -1.0,
#   ((13, True, 4, 0, 0, 3), 'Deliver'): 30.0,
#   ((13, False, 4, 0, 0, 4), 'NW'): -1.098360655737705,
#   ((12, False, 4, 0, 0, 4), 'NW'): -1.098360655737705,
#   ((15, False, 4, 0, 0, 4), 'N'): -1.0967741935483872,
#   ((16, False, 4, 0, 0, 4), 'S'): -1.098360655737705,
#   ((15, False, 4, 0, 0, 4), 'SE'): -1.0,
#   ((12, False, 4, 0, 0, 4), 'SE'): -1.1,
#   ((16, False, 4, 0, 0, 4), 'E'): -1.098360655737705,
#   ((11, False, 4, 0, 0, 4), 'W'): -1.098360655737705,
#   ((16, False, 4, 0, 0, 4), 'NE'): -1.098360655737705,
#   ((17, False, 4, 0, 0, 4), 'NE'): -1.098360655737705,
#   ((3, False, 4, 0, 0, 4), 'NW'): -1.098360655737705,
#   ((1, False, 4, 0, 0, 4), 'SE'): -1.098360655737705,
#   ((3, False, 4, 0, 0, 4), 'NE'): -1.0967741935483872,
#   ((4, False, 4, 0, 0, 4), 'NW'): -1.098360655737705,
#   ((2, False, 4, 0, 0, 4), 'SE'): -1.098360655737705,
#   ((4, False, 4, 0, 0, 4), 'SW'): -1.098360655737705,
#   ((3, False, 4, 0, 0, 4), 'SW'): -1.0,
#   ((17, False, 4, 0, 0, 4), 'SW'): -1.1,
#   ((4, False, 4, 0, 0, 4), 'NE'): -1.098360655737705,
#   ((5, False, 4, 0, 0, 4), 'NE'): -1.0,
#   ((6, False, 4, 0, 0, 4), 'SW'): -1.0,
#   ((5, False, 4, 0, 0, 4), 'SW'): -1.1,
#   ((6, False, 4, 0, 0, 4), 'S'): -1.0,
#   ((9, False, 4, 0, 0, 4), 'N'): -1.0,
#   ((6, False, 4, 0, 0, 4), 'E'): -1.0,
#   ((7, False, 4, 0, 0, 4), 'Pick'): 30.0,
#   ((7, True, 3, 0, 0, 4), 'W'): -1.0,
#   ((6, True, 3, 0, 0, 4), 'Deliver'): 30.0,
#   ((6, False, 3, 0, 1, 4), 'SW'): -1.0,
#   ((5, False, 3, 0, 1, 4), 'NE'): -1.0,
#   ((6, False, 3, 0, 1, 4), 'S'): -1.0,
#   ((9, False, 3, 0, 1, 4), 'N'): -1.0,
#   ((6, False, 3, 0, 1, 4), 'E'): -1.0,
#   ((7, False, 3, 0, 1, 4), 'Pick'): 30.0,
#   ((7, True, 2, 0, 1, 4), 'W'): -1.0,
#   ((6, True, 2, 0, 1, 4), 'Deliver'): 30.0,
#   ((6, False, 2, 0, 2, 4), 'SW'): -1.0,
#   ((5, False, 2, 0, 2, 4), 'NE'): -1.0,
#   ((6, False, 2, 0, 2, 4), 'S'): -1.0,
#   ((9, False, 2, 0, 2, 4), 'N'): -1.0,
#   ((6, False, 2, 0, 2, 4), 'E'): -1.0,
#   ((7, False, 2, 0, 2, 4), 'Pick'): 30.0,
#   ((7, True, 1, 0, 2, 4), 'W'): -1.0,
#   ((6, True, 1, 0, 2, 4), 'Deliver'): 30.0,
#   ((6, False, 1, 0, 3, 4), 'SW'): -1.0,
#   ((5, False, 1, 0, 3, 4), 'NE'): -1.0,
#   ((6, False, 1, 0, 3, 4), 'S'): -1.0,
#   ((9, False, 1, 0, 3, 4), 'N'): -1.0,
#   ((6, False, 1, 0, 3, 4), 'E'): -1.0,
#   ((7, False, 1, 0, 3, 4), 'Pick'): 30.0,
#   ((7, True, 0, 0, 3, 4), 'W'): -1.0,
#   ((6, True, 0, 0, 3, 4), 'Deliver'): 30.0,
#   ((6, False, 0, 0, 4, 4), 'SW'): 50.0,
#   ((16, False, 4, 4, 0, 0), 'NE'): -1.1,
#   ((15, False, 4, 4, 0, 0), 'SE'): -1.0,
#   ((12, False, 4, 4, 0, 0), 'NW'): -1.1,
#   ((12, False, 4, 4, 0, 0), 'SE'): -2.9986061776061774,
#   ((13, False, 4, 4, 0, 0), 'NW'): -1.11},
#  {((1, False, 4, 4, 0, 0), 'SE'): 1270,
#   ((3, False, 4, 4, 0, 0), 'NW'): 1,
#   ((3, False, 4, 4, 0, 0), 'NE'): 1269,
#   ((4, False, 4, 4, 0, 0), 'NW'): 3729236,
#   ((2, False, 4, 4, 0, 0), 'SE'): 3729236,
#   ((4, False, 4, 4, 0, 0), 'SW'): 2,
#   ((3, False, 4, 4, 0, 0), 'SW'): 3,
#   ((17, False, 4, 4, 0, 0), 'NE'): 1,
#   ((4, False, 4, 4, 0, 0), 'NE'): 2,
#   ((5, False, 4, 4, 0, 0), 'NE'): 2,
#   ((6, False, 4, 4, 0, 0), 'SW'): 1,
#   ((5, False, 4, 4, 0, 0), 'SW'): 1,
#   ((6, False, 4, 4, 0, 0), 'S'): 1,
#   ((9, False, 4, 4, 0, 0), 'N'): 1,
#   ((6, False, 4, 4, 0, 0), 'E'): 1,
#   ((7, False, 4, 4, 0, 0), 'Pick'): 1,
#   ((7, True, 3, 4, 0, 0), 'W'): 1,
#   ((6, True, 3, 4, 0, 0), 'Deliver'): 1,
#   ((6, False, 3, 4, 1, 0), 'SW'): 1,
#   ((5, False, 3, 4, 1, 0), 'NE'): 1,
#   ((6, False, 3, 4, 1, 0), 'S'): 1,
#   ((9, False, 3, 4, 1, 0), 'N'): 1,
#   ((6, False, 3, 4, 1, 0), 'E'): 1,
#   ((7, False, 3, 4, 1, 0), 'Pick'): 1,
#   ((7, True, 2, 4, 1, 0), 'W'): 1,
#   ((6, True, 2, 4, 1, 0), 'Deliver'): 1,
#   ((6, False, 2, 4, 2, 0), 'SW'): 1,
#   ((5, False, 2, 4, 2, 0), 'NE'): 1,
#   ((6, False, 2, 4, 2, 0), 'S'): 1,
#   ((9, False, 2, 4, 2, 0), 'N'): 1,
#   ((6, False, 2, 4, 2, 0), 'E'): 1,
#   ((7, False, 2, 4, 2, 0), 'Pick'): 1,
#   ((7, True, 1, 4, 2, 0), 'W'): 1,
#   ((6, True, 1, 4, 2, 0), 'Deliver'): 1,
#   ((6, False, 1, 4, 3, 0), 'SW'): 1,
#   ((5, False, 1, 4, 3, 0), 'NE'): 1,
#   ((6, False, 1, 4, 3, 0), 'S'): 1,
#   ((9, False, 1, 4, 3, 0), 'N'): 1,
#   ((6, False, 1, 4, 3, 0), 'E'): 1,
#   ((7, False, 1, 4, 3, 0), 'Pick'): 1,
#   ((7, True, 0, 4, 3, 0), 'W'): 1,
#   ((6, True, 0, 4, 3, 0), 'Deliver'): 1,
#   ((6, False, 0, 4, 4, 0), 'SW'): 3,
#   ((5, False, 0, 4, 4, 0), 'NE'): 2,
#   ((6, False, 0, 4, 4, 0), 'S'): 1,
#   ((9, False, 0, 4, 4, 0), 'N'): 1,
#   ((6, False, 0, 4, 4, 0), 'E'): 1,
#   ((7, False, 0, 4, 4, 0), 'W'): 1,
#   ((5, False, 0, 4, 4, 0), 'SW'): 2,
#   ((4, False, 0, 4, 4, 0), 'NW'): 2,
#   ((2, False, 0, 4, 4, 0), 'SE'): 2,
#   ((4, False, 0, 4, 4, 0), 'SW'): 3,
#   ((3, False, 0, 4, 4, 0), 'NW'): 2,
#   ((1, False, 0, 4, 4, 0), 'SE'): 2,
#   ((3, False, 0, 4, 4, 0), 'NE'): 2,
#   ((4, False, 0, 4, 4, 0), 'NE'): 1,
#   ((3, False, 0, 4, 4, 0), 'SW'): 2,
#   ((17, False, 0, 4, 4, 0), 'NE'): 1,
#   ((17, False, 0, 4, 4, 0), 'SW'): 1,
#   ((16, False, 0, 4, 4, 0), 'S'): 1,
#   ((15, False, 0, 4, 4, 0), 'N'): 1,
#   ((16, False, 0, 4, 4, 0), 'E'): 1,
#   ((11, False, 0, 4, 4, 0), 'Pick'): 1,
#   ((11, True, 0, 3, 4, 0), 'W'): 2,
#   ((16, True, 0, 3, 4, 0), 'S'): 3,
#   ((15, True, 0, 3, 4, 0), 'N'): 2,
#   ((16, True, 0, 3, 4, 0), 'E'): 1,
#   ((16, True, 0, 3, 4, 0), 'NE'): 1,
#   ((17, True, 0, 3, 4, 0), 'NE'): 1,
#   ((3, True, 0, 3, 4, 0), 'NW'): 1,
#   ((1, True, 0, 3, 4, 0), 'SE'): 1,
#   ((3, True, 0, 3, 4, 0), 'NE'): 1,
#   ((4, True, 0, 3, 4, 0), 'NW'): 1,
#   ((2, True, 0, 3, 4, 0), 'SE'): 1,
#   ((4, True, 0, 3, 4, 0), 'SW'): 1,
#   ((3, True, 0, 3, 4, 0), 'SW'): 1,
#   ((17, True, 0, 3, 4, 0), 'SW'): 1,
#   ((15, True, 0, 3, 4, 0), 'SE'): 2,
#   ((12, True, 0, 3, 4, 0), 'NW'): 1,
#   ((12, True, 0, 3, 4, 0), 'SE'): 1,
#   ((13, True, 0, 3, 4, 0), 'Deliver'): 1,
#   ((13, False, 0, 3, 4, 1), 'NW'): 2,
#   ((12, False, 0, 3, 4, 1), 'NW'): 2,
#   ((15, False, 0, 3, 4, 1), 'N'): 2,
#   ((16, False, 0, 3, 4, 1), 'S'): 1,
#   ((15, False, 0, 3, 4, 1), 'SE'): 1,
#   ((12, False, 0, 3, 4, 1), 'SE'): 1,
#   ((16, False, 0, 3, 4, 1), 'E'): 1,
#   ((11, False, 0, 3, 4, 1), 'Pick'): 1,
#   ((11, True, 0, 2, 4, 1), 'W'): 2,
#   ((16, True, 0, 2, 4, 1), 'S'): 3,
#   ((15, True, 0, 2, 4, 1), 'N'): 2,
#   ((16, True, 0, 2, 4, 1), 'E'): 1,
#   ((16, True, 0, 2, 4, 1), 'NE'): 1,
#   ((17, True, 0, 2, 4, 1), 'NE'): 1,
#   ((3, True, 0, 2, 4, 1), 'NW'): 1,
#   ((1, True, 0, 2, 4, 1), 'SE'): 1,
#   ((3, True, 0, 2, 4, 1), 'NE'): 1,
#   ((4, True, 0, 2, 4, 1), 'NW'): 1,
#   ((2, True, 0, 2, 4, 1), 'SE'): 1,
#   ((4, True, 0, 2, 4, 1), 'SW'): 1,
#   ((3, True, 0, 2, 4, 1), 'SW'): 1,
#   ((17, True, 0, 2, 4, 1), 'SW'): 1,
#   ((15, True, 0, 2, 4, 1), 'SE'): 2,
#   ((12, True, 0, 2, 4, 1), 'NW'): 1,
#   ((12, True, 0, 2, 4, 1), 'SE'): 1,
#   ((13, True, 0, 2, 4, 1), 'Deliver'): 1,
#   ((13, False, 0, 2, 4, 2), 'NW'): 2,
#   ((12, False, 0, 2, 4, 2), 'NW'): 2,
#   ((15, False, 0, 2, 4, 2), 'N'): 2,
#   ((16, False, 0, 2, 4, 2), 'S'): 1,
#   ((15, False, 0, 2, 4, 2), 'SE'): 1,
#   ((12, False, 0, 2, 4, 2), 'SE'): 1,
#   ((16, False, 0, 2, 4, 2), 'E'): 1,
#   ((11, False, 0, 2, 4, 2), 'Pick'): 1,
#   ((11, True, 0, 1, 4, 2), 'W'): 2,
#   ((16, True, 0, 1, 4, 2), 'S'): 3,
#   ((15, True, 0, 1, 4, 2), 'N'): 2,
#   ((16, True, 0, 1, 4, 2), 'E'): 1,
#   ((16, True, 0, 1, 4, 2), 'NE'): 1,
#   ((17, True, 0, 1, 4, 2), 'NE'): 1,
#   ((3, True, 0, 1, 4, 2), 'NW'): 1,
#   ((1, True, 0, 1, 4, 2), 'SE'): 1,
#   ((3, True, 0, 1, 4, 2), 'NE'): 1,
#   ((4, True, 0, 1, 4, 2), 'NW'): 1,
#   ((2, True, 0, 1, 4, 2), 'SE'): 1,
#   ((4, True, 0, 1, 4, 2), 'SW'): 1,
#   ((3, True, 0, 1, 4, 2), 'SW'): 1,
#   ((17, True, 0, 1, 4, 2), 'SW'): 1,
#   ((15, True, 0, 1, 4, 2), 'SE'): 2,
#   ((12, True, 0, 1, 4, 2), 'NW'): 1,
#   ((12, True, 0, 1, 4, 2), 'SE'): 1,
#   ((13, True, 0, 1, 4, 2), 'Deliver'): 1,
#   ((13, False, 0, 1, 4, 3), 'NW'): 2,
#   ((12, False, 0, 1, 4, 3), 'NW'): 2,
#   ((15, False, 0, 1, 4, 3), 'N'): 2,
#   ((16, False, 0, 1, 4, 3), 'S'): 1,
#   ((15, False, 0, 1, 4, 3), 'SE'): 1,
#   ((12, False, 0, 1, 4, 3), 'SE'): 1,
#   ((16, False, 0, 1, 4, 3), 'E'): 1,
#   ((11, False, 0, 1, 4, 3), 'Pick'): 1,
#   ((11, True, 0, 0, 4, 3), 'W'): 2,
#   ((16, True, 0, 0, 4, 3), 'S'): 3,
#   ((15, True, 0, 0, 4, 3), 'N'): 2,
#   ((16, True, 0, 0, 4, 3), 'E'): 1,
#   ((16, True, 0, 0, 4, 3), 'NE'): 1,
#   ((17, True, 0, 0, 4, 3), 'NE'): 1,
#   ((3, True, 0, 0, 4, 3), 'NW'): 1,
#   ((1, True, 0, 0, 4, 3), 'SE'): 1,
#   ((3, True, 0, 0, 4, 3), 'NE'): 1,
#   ((4, True, 0, 0, 4, 3), 'NW'): 1,
#   ((2, True, 0, 0, 4, 3), 'SE'): 1,
#   ((4, True, 0, 0, 4, 3), 'SW'): 1,
#   ((3, True, 0, 0, 4, 3), 'SW'): 1,
#   ((17, True, 0, 0, 4, 3), 'SW'): 1,
#   ((15, True, 0, 0, 4, 3), 'SE'): 2,
#   ((12, True, 0, 0, 4, 3), 'NW'): 1,
#   ((12, True, 0, 0, 4, 3), 'SE'): 1,
#   ((13, True, 0, 0, 4, 3), 'Deliver'): 1,
#   ((13, False, 0, 0, 4, 4), 'NW'): 1,
#   ((17, False, 4, 4, 0, 0), 'SW'): 3,
#   ((16, False, 4, 4, 0, 0), 'S'): 3,
#   ((15, False, 4, 4, 0, 0), 'N'): 2,
#   ((16, False, 4, 4, 0, 0), 'E'): 1,
#   ((11, False, 4, 4, 0, 0), 'Pick'): 1,
#   ((11, True, 4, 3, 0, 0), 'W'): 2,
#   ((16, True, 4, 3, 0, 0), 'S'): 3,
#   ((15, True, 4, 3, 0, 0), 'N'): 2,
#   ((16, True, 4, 3, 0, 0), 'E'): 1,
#   ((16, True, 4, 3, 0, 0), 'NE'): 1,
#   ((17, True, 4, 3, 0, 0), 'NE'): 1,
#   ((3, True, 4, 3, 0, 0), 'NW'): 1,
#   ((1, True, 4, 3, 0, 0), 'SE'): 1,
#   ((3, True, 4, 3, 0, 0), 'NE'): 1,
#   ((4, True, 4, 3, 0, 0), 'NW'): 1,
#   ((2, True, 4, 3, 0, 0), 'SE'): 1,
#   ((4, True, 4, 3, 0, 0), 'SW'): 1,
#   ((3, True, 4, 3, 0, 0), 'SW'): 1,
#   ((17, True, 4, 3, 0, 0), 'SW'): 1,
#   ((15, True, 4, 3, 0, 0), 'SE'): 2,
#   ((12, True, 4, 3, 0, 0), 'NW'): 1,
#   ((12, True, 4, 3, 0, 0), 'SE'): 1,
#   ((13, True, 4, 3, 0, 0), 'Deliver'): 1,
#   ((13, False, 4, 3, 0, 1), 'NW'): 2,
#   ((12, False, 4, 3, 0, 1), 'NW'): 2,
#   ((15, False, 4, 3, 0, 1), 'N'): 2,
#   ((16, False, 4, 3, 0, 1), 'S'): 1,
#   ((15, False, 4, 3, 0, 1), 'SE'): 1,
#   ((12, False, 4, 3, 0, 1), 'SE'): 1,
#   ((16, False, 4, 3, 0, 1), 'E'): 1,
#   ((11, False, 4, 3, 0, 1), 'Pick'): 1,
#   ((11, True, 4, 2, 0, 1), 'W'): 2,
#   ((16, True, 4, 2, 0, 1), 'S'): 3,
#   ((15, True, 4, 2, 0, 1), 'N'): 2,
#   ((16, True, 4, 2, 0, 1), 'E'): 1,
#   ((16, True, 4, 2, 0, 1), 'NE'): 1,
#   ((17, True, 4, 2, 0, 1), 'NE'): 1,
#   ((3, True, 4, 2, 0, 1), 'NW'): 1,
#   ((1, True, 4, 2, 0, 1), 'SE'): 1,
#   ((3, True, 4, 2, 0, 1), 'NE'): 1,
#   ((4, True, 4, 2, 0, 1), 'NW'): 1,
#   ((2, True, 4, 2, 0, 1), 'SE'): 1,
#   ((4, True, 4, 2, 0, 1), 'SW'): 1,
#   ((3, True, 4, 2, 0, 1), 'SW'): 1,
#   ((17, True, 4, 2, 0, 1), 'SW'): 1,
#   ((15, True, 4, 2, 0, 1), 'SE'): 2,
#   ((12, True, 4, 2, 0, 1), 'NW'): 1,
#   ((12, True, 4, 2, 0, 1), 'SE'): 1,
#   ((13, True, 4, 2, 0, 1), 'Deliver'): 1,
#   ((13, False, 4, 2, 0, 2), 'NW'): 2,
#   ((12, False, 4, 2, 0, 2), 'NW'): 2,
#   ((15, False, 4, 2, 0, 2), 'N'): 2,
#   ((16, False, 4, 2, 0, 2), 'S'): 1,
#   ((15, False, 4, 2, 0, 2), 'SE'): 1,
#   ((12, False, 4, 2, 0, 2), 'SE'): 1,
#   ((16, False, 4, 2, 0, 2), 'E'): 1,
#   ((11, False, 4, 2, 0, 2), 'Pick'): 1,
#   ((11, True, 4, 1, 0, 2), 'W'): 2,
#   ((16, True, 4, 1, 0, 2), 'S'): 3,
#   ((15, True, 4, 1, 0, 2), 'N'): 2,
#   ((16, True, 4, 1, 0, 2), 'E'): 1,
#   ((16, True, 4, 1, 0, 2), 'NE'): 1,
#   ((17, True, 4, 1, 0, 2), 'NE'): 1,
#   ((3, True, 4, 1, 0, 2), 'NW'): 1,
#   ((1, True, 4, 1, 0, 2), 'SE'): 1,
#   ((3, True, 4, 1, 0, 2), 'NE'): 1,
#   ((4, True, 4, 1, 0, 2), 'NW'): 1,
#   ((2, True, 4, 1, 0, 2), 'SE'): 1,
#   ((4, True, 4, 1, 0, 2), 'SW'): 1,
#   ((3, True, 4, 1, 0, 2), 'SW'): 1,
#   ((17, True, 4, 1, 0, 2), 'SW'): 1,
#   ((15, True, 4, 1, 0, 2), 'SE'): 2,
#   ((12, True, 4, 1, 0, 2), 'NW'): 1,
#   ((12, True, 4, 1, 0, 2), 'SE'): 1,
#   ((13, True, 4, 1, 0, 2), 'Deliver'): 1,
#   ((13, False, 4, 1, 0, 3), 'NW'): 2,
#   ((12, False, 4, 1, 0, 3), 'NW'): 2,
#   ((15, False, 4, 1, 0, 3), 'N'): 2,
#   ((16, False, 4, 1, 0, 3), 'S'): 1,
#   ((15, False, 4, 1, 0, 3), 'SE'): 1,
#   ((12, False, 4, 1, 0, 3), 'SE'): 1,
#   ((16, False, 4, 1, 0, 3), 'E'): 1,
#   ((11, False, 4, 1, 0, 3), 'Pick'): 1,
#   ((11, True, 4, 0, 0, 3), 'W'): 2,
#   ((16, True, 4, 0, 0, 3), 'S'): 3,
#   ((15, True, 4, 0, 0, 3), 'N'): 2,
#   ((16, True, 4, 0, 0, 3), 'E'): 1,
#   ((16, True, 4, 0, 0, 3), 'NE'): 1,
#   ((17, True, 4, 0, 0, 3), 'NE'): 1,
#   ((3, True, 4, 0, 0, 3), 'NW'): 1,
#   ((1, True, 4, 0, 0, 3), 'SE'): 1,
#   ((3, True, 4, 0, 0, 3), 'NE'): 1,
#   ((4, True, 4, 0, 0, 3), 'NW'): 1,
#   ((2, True, 4, 0, 0, 3), 'SE'): 1,
#   ((4, True, 4, 0, 0, 3), 'SW'): 1,
#   ((3, True, 4, 0, 0, 3), 'SW'): 1,
#   ((17, True, 4, 0, 0, 3), 'SW'): 1,
#   ((15, True, 4, 0, 0, 3), 'SE'): 2,
#   ((12, True, 4, 0, 0, 3), 'NW'): 1,
#   ((12, True, 4, 0, 0, 3), 'SE'): 1,
#   ((13, True, 4, 0, 0, 3), 'Deliver'): 1,
#   ((13, False, 4, 0, 0, 4), 'NW'): 2,
#   ((12, False, 4, 0, 0, 4), 'NW'): 2,
#   ((15, False, 4, 0, 0, 4), 'N'): 3,
#   ((16, False, 4, 0, 0, 4), 'S'): 2,
#   ((15, False, 4, 0, 0, 4), 'SE'): 1,
#   ((12, False, 4, 0, 0, 4), 'SE'): 1,
#   ((16, False, 4, 0, 0, 4), 'E'): 2,
#   ((11, False, 4, 0, 0, 4), 'W'): 2,
#   ((16, False, 4, 0, 0, 4), 'NE'): 2,
#   ((17, False, 4, 0, 0, 4), 'NE'): 2,
#   ((3, False, 4, 0, 0, 4), 'NW'): 2,
#   ((1, False, 4, 0, 0, 4), 'SE'): 2,
#   ((3, False, 4, 0, 0, 4), 'NE'): 3,
#   ((4, False, 4, 0, 0, 4), 'NW'): 2,
#   ((2, False, 4, 0, 0, 4), 'SE'): 2,
#   ((4, False, 4, 0, 0, 4), 'SW'): 2,
#   ((3, False, 4, 0, 0, 4), 'SW'): 1,
#   ((17, False, 4, 0, 0, 4), 'SW'): 1,
#   ((4, False, 4, 0, 0, 4), 'NE'): 2,
#   ((5, False, 4, 0, 0, 4), 'NE'): 2,
#   ((6, False, 4, 0, 0, 4), 'SW'): 1,
#   ((5, False, 4, 0, 0, 4), 'SW'): 1,
#   ((6, False, 4, 0, 0, 4), 'S'): 1,
#   ((9, False, 4, 0, 0, 4), 'N'): 1,
#   ((6, False, 4, 0, 0, 4), 'E'): 1,
#   ((7, False, 4, 0, 0, 4), 'Pick'): 1,
#   ((7, True, 3, 0, 0, 4), 'W'): 1,
#   ((6, True, 3, 0, 0, 4), 'Deliver'): 1,
#   ((6, False, 3, 0, 1, 4), 'SW'): 1,
#   ((5, False, 3, 0, 1, 4), 'NE'): 1,
#   ((6, False, 3, 0, 1, 4), 'S'): 1,
#   ((9, False, 3, 0, 1, 4), 'N'): 1,
#   ((6, False, 3, 0, 1, 4), 'E'): 1,
#   ((7, False, 3, 0, 1, 4), 'Pick'): 1,
#   ((7, True, 2, 0, 1, 4), 'W'): 1,
#   ((6, True, 2, 0, 1, 4), 'Deliver'): 1,
#   ((6, False, 2, 0, 2, 4), 'SW'): 1,
#   ((5, False, 2, 0, 2, 4), 'NE'): 1,
#   ((6, False, 2, 0, 2, 4), 'S'): 1,
#   ((9, False, 2, 0, 2, 4), 'N'): 1,
#   ((6, False, 2, 0, 2, 4), 'E'): 1,
#   ((7, False, 2, 0, 2, 4), 'Pick'): 1,
#   ((7, True, 1, 0, 2, 4), 'W'): 1,
#   ((6, True, 1, 0, 2, 4), 'Deliver'): 1,
#   ((6, False, 1, 0, 3, 4), 'SW'): 1,
#   ((5, False, 1, 0, 3, 4), 'NE'): 1,
#   ((6, False, 1, 0, 3, 4), 'S'): 1,
#   ((9, False, 1, 0, 3, 4), 'N'): 1,
#   ((6, False, 1, 0, 3, 4), 'E'): 1,
#   ((7, False, 1, 0, 3, 4), 'Pick'): 1,
#   ((7, True, 0, 0, 3, 4), 'W'): 1,
#   ((6, True, 0, 0, 3, 4), 'Deliver'): 1,
#   ((6, False, 0, 0, 4, 4), 'SW'): 1,
#   ((16, False, 4, 4, 0, 0), 'NE'): 1,
#   ((15, False, 4, 4, 0, 0), 'SE'): 2,
#   ((12, False, 4, 4, 0, 0), 'NW'): 1,
#   ((12, False, 4, 4, 0, 0), 'SE'): 1495,
#   ((13, False, 4, 4, 0, 0), 'NW'): 1494})

# %% [markdown]
# #Greedy Q-Learning

# %%
q, n = {}, {}
simulate(lambda: ZCRobot(50,0.1,30,3000), duration=60, q=q, n=n, f=lambda q, n: q)
simulate(lambda: ZCRobot(50,0.1,30,3000), n_iterations=1, q=q, n=n, verbose=True, f=lambda q, n: q)
# Out:
# Frontier at step 1
#
# (2, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2
#
# (4, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 3
#
# (5, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 4
#
# (6, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 5
#
# (7, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 6
#
# (7, True, 3, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 7
#
# (6, True, 3, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 8
#
# (6, False, 3, 4, 1, 0)
# --------------------------------------------------------------------------------
# Frontier at step 9
#
# (7, False, 3, 4, 1, 0)
# --------------------------------------------------------------------------------
# Frontier at step 10
#
# (7, True, 2, 4, 1, 0)
# --------------------------------------------------------------------------------
# Frontier at step 11
#
# (6, True, 2, 4, 1, 0)
# --------------------------------------------------------------------------------
# Frontier at step 12
#
# (6, False, 2, 4, 2, 0)
# --------------------------------------------------------------------------------
# Frontier at step 13
#
# (7, False, 2, 4, 2, 0)
# --------------------------------------------------------------------------------
# Frontier at step 14
#
# (7, True, 1, 4, 2, 0)
# --------------------------------------------------------------------------------
# Frontier at step 15
#
# (6, True, 1, 4, 2, 0)
# --------------------------------------------------------------------------------
# Frontier at step 16
#
# (6, False, 1, 4, 3, 0)
# --------------------------------------------------------------------------------
# Frontier at step 17
#
# (7, False, 1, 4, 3, 0)
# --------------------------------------------------------------------------------
# Frontier at step 18
#
# (7, True, 0, 4, 3, 0)
# --------------------------------------------------------------------------------
# Frontier at step 19
#
# (6, True, 0, 4, 3, 0)
# --------------------------------------------------------------------------------
# Frontier at step 20
#
# (6, False, 0, 4, 4, 0)
# --------------------------------------------------------------------------------
# Frontier at step 21
#
# (5, False, 0, 4, 4, 0)
# --------------------------------------------------------------------------------
# Frontier at step 22
#
# (4, False, 0, 4, 4, 0)
# --------------------------------------------------------------------------------
# Frontier at step 23
#
# (3, False, 0, 4, 4, 0)
# --------------------------------------------------------------------------------
# Frontier at step 24
#
# (17, False, 0, 4, 4, 0)
# --------------------------------------------------------------------------------
# Frontier at step 25
#
# (16, False, 0, 4, 4, 0)
# --------------------------------------------------------------------------------
# Frontier at step 26
#
# (11, False, 0, 4, 4, 0)
# --------------------------------------------------------------------------------
# Frontier at step 27
#
# (11, True, 0, 3, 4, 0)
# --------------------------------------------------------------------------------
# Frontier at step 28
#
# (16, True, 0, 3, 4, 0)
# --------------------------------------------------------------------------------
# Frontier at step 29
#
# (15, True, 0, 3, 4, 0)
# --------------------------------------------------------------------------------
# Frontier at step 30
#
# (12, True, 0, 3, 4, 0)
# --------------------------------------------------------------------------------
# Frontier at step 31
#
# (13, True, 0, 3, 4, 0)
# --------------------------------------------------------------------------------
# Frontier at step 32
#
# (13, False, 0, 3, 4, 1)
# --------------------------------------------------------------------------------
# Frontier at step 33
#
# (12, False, 0, 3, 4, 1)
# --------------------------------------------------------------------------------
# Frontier at step 34
#
# (15, False, 0, 3, 4, 1)
# --------------------------------------------------------------------------------
# Frontier at step 35
#
# (16, False, 0, 3, 4, 1)
# --------------------------------------------------------------------------------
# Frontier at step 36
#
# (11, False, 0, 3, 4, 1)
# --------------------------------------------------------------------------------
# Frontier at step 37
#
# (11, True, 0, 2, 4, 1)
# --------------------------------------------------------------------------------
# Frontier at step 38
#
# (16, True, 0, 2, 4, 1)
# --------------------------------------------------------------------------------
# Frontier at step 39
#
# (15, True, 0, 2, 4, 1)
# --------------------------------------------------------------------------------
# Frontier at step 40
#
# (12, True, 0, 2, 4, 1)
# --------------------------------------------------------------------------------
# Frontier at step 41
#
# (13, True, 0, 2, 4, 1)
# --------------------------------------------------------------------------------
# Frontier at step 42
#
# (13, False, 0, 2, 4, 2)
# --------------------------------------------------------------------------------
# Frontier at step 43
#
# (12, False, 0, 2, 4, 2)
# --------------------------------------------------------------------------------
# Frontier at step 44
#
# (15, False, 0, 2, 4, 2)
# --------------------------------------------------------------------------------
# Frontier at step 45
#
# (16, False, 0, 2, 4, 2)
# --------------------------------------------------------------------------------
# Frontier at step 46
#
# (11, False, 0, 2, 4, 2)
# --------------------------------------------------------------------------------
# Frontier at step 47
#
# (11, True, 0, 1, 4, 2)
# --------------------------------------------------------------------------------
# Frontier at step 48
#
# (16, True, 0, 1, 4, 2)
# --------------------------------------------------------------------------------
# Frontier at step 49
#
# (15, True, 0, 1, 4, 2)
# --------------------------------------------------------------------------------
# Frontier at step 50
#
# (12, True, 0, 1, 4, 2)
# --------------------------------------------------------------------------------
# Frontier at step 51
#
# (13, True, 0, 1, 4, 2)
# --------------------------------------------------------------------------------
# Frontier at step 52
#
# (13, False, 0, 1, 4, 3)
# --------------------------------------------------------------------------------
# Frontier at step 53
#
# (12, False, 0, 1, 4, 3)
# --------------------------------------------------------------------------------
# Frontier at step 54
#
# (15, False, 0, 1, 4, 3)
# --------------------------------------------------------------------------------
# Frontier at step 55
#
# (16, False, 0, 1, 4, 3)
# --------------------------------------------------------------------------------
# Frontier at step 56
#
# (11, False, 0, 1, 4, 3)
# --------------------------------------------------------------------------------
# Frontier at step 57
#
# (11, True, 0, 0, 4, 3)
# --------------------------------------------------------------------------------
# Frontier at step 58
#
# (16, True, 0, 0, 4, 3)
# --------------------------------------------------------------------------------
# Frontier at step 59
#
# (15, True, 0, 0, 4, 3)
# --------------------------------------------------------------------------------
# Frontier at step 60
#
# (12, True, 0, 0, 4, 3)
# --------------------------------------------------------------------------------
# Frontier at step 61
#
# (13, True, 0, 0, 4, 3)
# --------------------------------------------------------------------------------
# Frontier at step 62
#
# (13, False, 0, 0, 4, 4)
# --------------------------------------------------------------------------------
# ({((2, False, 4, 4, 0, 0), 'SE'): -1.107979797979798,
#   ((4, False, 4, 4, 0, 0), 'NW'): -1.1108194824871533,
#   ((4, False, 4, 4, 0, 0), 'SW'): -1.1102150537634408,
#   ((3, False, 4, 4, 0, 0), 'NW'): -1.110574001217066,
#   ((1, False, 4, 4, 0, 0), 'SE'): -1.1080110801108012,
#   ((3, False, 4, 4, 0, 0), 'NE'): -1.1096096718143424,
#   ((4, False, 4, 4, 0, 0), 'NE'): -1.0797979797979798,
#   ((5, False, 4, 4, 0, 0), 'NE'): -0.797979797979798,
#   ((6, False, 4, 4, 0, 0), 'SW'): -1.1078794288736118,
#   ((5, False, 4, 4, 0, 0), 'SW'): -1.1,
#   ((3, False, 4, 4, 0, 0), 'SW'): -1.0801108011080112,
#   ((17, False, 4, 4, 0, 0), 'NE'): -1.1,
#   ((17, False, 4, 4, 0, 0), 'SW'): -0.8011080110801108,
#   ((16, False, 4, 4, 0, 0), 'S'): -1.0967741935483872,
#   ((15, False, 4, 4, 0, 0), 'N'): -1.0999471179270228,
#   ((16, False, 4, 4, 0, 0), 'E'): 1.988919889198892,
#   ((11, False, 4, 4, 0, 0), 'Pick'): 29.88919889198892,
#   ((11, True, 4, 3, 0, 0), 'W'): -1.1080110801108012,
#   ((16, True, 4, 3, 0, 0), 'S'): -1.0801108011080112,
#   ((15, True, 4, 3, 0, 0), 'N'): -1.098360655737705,
#   ((16, True, 4, 3, 0, 0), 'E'): -1.1108193993460485,
#   ((16, True, 4, 3, 0, 0), 'NE'): -1.1094658910629296,
#   ((17, True, 4, 3, 0, 0), 'NE'): -1.1092140716677998,
#   ((3, True, 4, 3, 0, 0), 'NW'): -1.098360655737705,
#   ((1, True, 4, 3, 0, 0), 'SE'): -1.098360655737705,
#   ((3, True, 4, 3, 0, 0), 'NE'): -1.099846390168971,
#   ((4, True, 4, 3, 0, 0), 'NW'): -1.098360655737705,
#   ((2, True, 4, 3, 0, 0), 'SE'): -1.098360655737705,
#   ((4, True, 4, 3, 0, 0), 'SW'): -1.098360655737705,
#   ((3, True, 4, 3, 0, 0), 'SW'): -1.1081915197961005,
#   ((17, True, 4, 3, 0, 0), 'SW'): -1.1,
#   ((15, True, 4, 3, 0, 0), 'SE'): -0.8011080110801108,
#   ((12, True, 4, 3, 0, 0), 'NW'): -1.1,
#   ((12, True, 4, 3, 0, 0), 'SE'): 1.988919889198892,
#   ((13, True, 4, 3, 0, 0), 'Deliver'): 29.88919889198892,
#   ((13, False, 4, 3, 0, 1), 'NW'): -1.1080110801108012,
#   ((12, False, 4, 3, 0, 1), 'NW'): -1.0801108011080112,
#   ((15, False, 4, 3, 0, 1), 'N'): -0.8011080110801108,
#   ((16, False, 4, 3, 0, 1), 'S'): -1.098360655737705,
#   ((15, False, 4, 3, 0, 1), 'SE'): -1.108196473620267,
#   ((12, False, 4, 3, 0, 1), 'SE'): -1.1108194848146713,
#   ((16, False, 4, 3, 0, 1), 'E'): 1.988919889198892,
#   ((11, False, 4, 3, 0, 1), 'Pick'): 29.88919889198892,
#   ((11, True, 4, 2, 0, 1), 'W'): -1.1080110801108012,
#   ((16, True, 4, 2, 0, 1), 'S'): -1.0801108011080112,
#   ((15, True, 4, 2, 0, 1), 'N'): -1.098360655737705,
#   ((16, True, 4, 2, 0, 1), 'E'): -1.1108193993460485,
#   ((16, True, 4, 2, 0, 1), 'NE'): -1.1094658910629296,
#   ((17, True, 4, 2, 0, 1), 'NE'): -1.1092140716677998,
#   ((3, True, 4, 2, 0, 1), 'NW'): -1.098360655737705,
#   ((1, True, 4, 2, 0, 1), 'SE'): -1.098360655737705,
#   ((3, True, 4, 2, 0, 1), 'NE'): -1.099846390168971,
#   ((4, True, 4, 2, 0, 1), 'NW'): -1.098360655737705,
#   ((2, True, 4, 2, 0, 1), 'SE'): -1.098360655737705,
#   ((4, True, 4, 2, 0, 1), 'SW'): -1.098360655737705,
#   ((3, True, 4, 2, 0, 1), 'SW'): -1.1081915197961005,
#   ((17, True, 4, 2, 0, 1), 'SW'): -1.1,
#   ((15, True, 4, 2, 0, 1), 'SE'): -0.8011080110801108,
#   ((12, True, 4, 2, 0, 1), 'NW'): -1.1,
#   ((12, True, 4, 2, 0, 1), 'SE'): 1.988919889198892,
#   ((13, True, 4, 2, 0, 1), 'Deliver'): 29.88919889198892,
#   ((13, False, 4, 2, 0, 2), 'NW'): -1.1080110801108012,
#   ((12, False, 4, 2, 0, 2), 'NW'): -1.0801108011080112,
#   ((15, False, 4, 2, 0, 2), 'N'): -0.8011080110801108,
#   ((16, False, 4, 2, 0, 2), 'S'): -1.098360655737705,
#   ((15, False, 4, 2, 0, 2), 'SE'): -1.108196473620267,
#   ((12, False, 4, 2, 0, 2), 'SE'): -1.1108194848146713,
#   ((16, False, 4, 2, 0, 2), 'E'): 1.988919889198892,
#   ((11, False, 4, 2, 0, 2), 'Pick'): 29.88919889198892,
#   ((11, True, 4, 1, 0, 2), 'W'): -1.1080110801108012,
#   ((16, True, 4, 1, 0, 2), 'S'): -1.0801108011080112,
#   ((15, True, 4, 1, 0, 2), 'N'): -1.098360655737705,
#   ((16, True, 4, 1, 0, 2), 'E'): -1.1108193993460485,
#   ((16, True, 4, 1, 0, 2), 'NE'): -1.1094658910629296,
#   ((17, True, 4, 1, 0, 2), 'NE'): -1.1092140716677998,
#   ((3, True, 4, 1, 0, 2), 'NW'): -1.098360655737705,
#   ((1, True, 4, 1, 0, 2), 'SE'): -1.098360655737705,
#   ((3, True, 4, 1, 0, 2), 'NE'): -1.099846390168971,
#   ((4, True, 4, 1, 0, 2), 'NW'): -1.098360655737705,
#   ((2, True, 4, 1, 0, 2), 'SE'): -1.098360655737705,
#   ((4, True, 4, 1, 0, 2), 'SW'): -1.098360655737705,
#   ((3, True, 4, 1, 0, 2), 'SW'): -1.1081915197961005,
#   ((17, True, 4, 1, 0, 2), 'SW'): -1.1,
#   ((15, True, 4, 1, 0, 2), 'SE'): -0.8011080110801111,
#   ((12, True, 4, 1, 0, 2), 'NW'): -1.1,
#   ((12, True, 4, 1, 0, 2), 'SE'): 1.9889198891988893,
#   ((13, True, 4, 1, 0, 2), 'Deliver'): 29.88919889198889,
#   ((13, False, 4, 1, 0, 3), 'NW'): -1.1080110801111112,
#   ((12, False, 4, 1, 0, 3), 'NW'): -1.0801108011111111,
#   ((15, False, 4, 1, 0, 3), 'N'): -0.8011080111111107,
#   ((16, False, 4, 1, 0, 3), 'S'): -1.098360655737705,
#   ((15, False, 4, 1, 0, 3), 'SE'): -1.108196473620267,
#   ((12, False, 4, 1, 0, 3), 'SE'): -1.1108194848146713,
#   ((16, False, 4, 1, 0, 3), 'E'): 1.9889198888888924,
#   ((11, False, 4, 1, 0, 3), 'Pick'): 29.88919888888892,
#   ((11, True, 4, 0, 0, 3), 'W'): -1.108011111110798,
#   ((16, True, 4, 0, 0, 3), 'S'): -1.0801111111079797,
#   ((15, True, 4, 0, 0, 3), 'N'): -1.098360655737705,
#   ((16, True, 4, 0, 0, 3), 'E'): -1.1108193993460485,
#   ((16, True, 4, 0, 0, 3), 'NE'): -1.1094658910629296,
#   ((17, True, 4, 0, 0, 3), 'NE'): -1.1092140716677998,
#   ((3, True, 4, 0, 0, 3), 'NW'): -1.098360655737705,
#   ((1, True, 4, 0, 0, 3), 'SE'): -1.098360655737705,
#   ((3, True, 4, 0, 0, 3), 'NE'): -1.099846390168971,
#   ((4, True, 4, 0, 0, 3), 'NW'): -1.098360655737705,
#   ((2, True, 4, 0, 0, 3), 'SE'): -1.098360655737705,
#   ((4, True, 4, 0, 0, 3), 'SW'): -1.098360655737705,
#   ((3, True, 4, 0, 0, 3), 'SW'): -1.1081915197961005,
#   ((17, True, 4, 0, 0, 3), 'SW'): -1.1,
#   ((15, True, 4, 0, 0, 3), 'SE'): -0.8011111110797979,
#   ((12, True, 4, 0, 0, 3), 'NW'): -1.1,
#   ((12, True, 4, 0, 0, 3), 'SE'): 1.9888888892020202,
#   ((13, True, 4, 0, 0, 3), 'Deliver'): 29.8888888920202,
#   ((13, False, 4, 0, 0, 4), 'NW'): -1.1111110797979797,
#   ((12, False, 4, 0, 0, 4), 'NW'): -1.111110797979798,
#   ((15, False, 4, 0, 0, 4), 'N'): -1.1111079797979797,
#   ((16, False, 4, 0, 0, 4), 'S'): -1.1111097646294097,
#   ((15, False, 4, 0, 0, 4), 'SE'): -1.1111110439169931,
#   ((12, False, 4, 0, 0, 4), 'SE'): -1.1111111021150146,
#   ((16, False, 4, 0, 0, 4), 'E'): -1.1111101591477839,
#   ((11, False, 4, 0, 0, 4), 'W'): -1.1111102512014344,
#   ((16, False, 4, 0, 0, 4), 'NE'): -1.111079797979798,
#   ((17, False, 4, 0, 0, 4), 'NE'): -1.11079797979798,
#   ((3, False, 4, 0, 0, 4), 'NW'): -1.1109666867176695,
#   ((1, False, 4, 0, 0, 4), 'SE'): -1.1109529355673027,
#   ((3, False, 4, 0, 0, 4), 'NE'): -1.107979797979798,
#   ((4, False, 4, 0, 0, 4), 'NW'): -1.1108760796756565,
#   ((2, False, 4, 0, 0, 4), 'SE'): -1.1108760796756565,
#   ((4, False, 4, 0, 0, 4), 'SW'): -1.1110087256258971,
#   ((3, False, 4, 0, 0, 4), 'SW'): -1.111043785681629,
#   ((17, False, 4, 0, 0, 4), 'SW'): -1.1111089824381453,
#   ((4, False, 4, 0, 0, 4), 'NE'): -1.0797979797979798,
#   ((5, False, 4, 0, 0, 4), 'NE'): -0.7979797979797975,
#   ((6, False, 4, 0, 0, 4), 'SW'): -1.1078794288736118,
#   ((5, False, 4, 0, 0, 4), 'SW'): -1.1,
#   ((6, False, 4, 0, 0, 4), 'S'): -1.098360655737705,
#   ((9, False, 4, 0, 0, 4), 'N'): -1.098360655737705,
#   ((6, False, 4, 0, 0, 4), 'E'): 2.020202020202025,
#   ((7, False, 4, 0, 0, 4), 'Pick'): 30.20202020202025,
#   ((7, True, 3, 0, 0, 4), 'W'): 2.0202020202025004,
#   ((6, True, 3, 0, 0, 4), 'Deliver'): 30.202020202025,
#   ((6, False, 3, 0, 1, 4), 'SW'): -1.1080354743348562,
#   ((5, False, 3, 0, 1, 4), 'NE'): -1.0999471179270228,
#   ((6, False, 3, 0, 1, 4), 'S'): -1.098360655737705,
#   ((9, False, 3, 0, 1, 4), 'N'): -1.098360655737705,
#   ((6, False, 3, 0, 1, 4), 'E'): 2.02020202025,
#   ((7, False, 3, 0, 1, 4), 'Pick'): 30.2020202025,
#   ((7, True, 2, 0, 1, 4), 'W'): 2.020202025,
#   ((6, True, 2, 0, 1, 4), 'Deliver'): 30.20202025,
#   ((6, False, 2, 0, 2, 4), 'SW'): -1.0967741935483872,
#   ((5, False, 2, 0, 2, 4), 'NE'): -0.8144342877288409,
#   ((6, False, 2, 0, 2, 4), 'S'): -1.098360655737705,
#   ((9, False, 2, 0, 2, 4), 'N'): -1.098360655737705,
#   ((6, False, 2, 0, 2, 4), 'E'): 2.0202025,
#   ((7, False, 2, 0, 2, 4), 'Pick'): 30.202025,
#   ((7, True, 1, 0, 2, 4), 'W'): 2.0202500000000003,
#   ((6, True, 1, 0, 2, 4), 'Deliver'): 30.2025,
#   ((6, False, 1, 0, 3, 4), 'SW'): -1.0967741935483872,
#   ((5, False, 1, 0, 3, 4), 'NE'): -0.8119025093388543,
#   ((6, False, 1, 0, 3, 4), 'S'): -1.098360655737705,
#   ((9, False, 1, 0, 3, 4), 'N'): -1.098360655737705,
#   ((6, False, 1, 0, 3, 4), 'E'): 2.0250000000000004,
#   ((7, False, 1, 0, 3, 4), 'Pick'): 30.25,
#   ((7, True, 0, 0, 3, 4), 'W'): 2.5,
#   ((6, True, 0, 0, 3, 4), 'Deliver'): 35.0,
#   ((6, False, 0, 0, 4, 4), 'SW'): 50.0,
#   ((6, False, 4, 4, 0, 0), 'S'): -1.098360655737705,
#   ((9, False, 4, 4, 0, 0), 'N'): -1.098360655737705,
#   ((6, False, 4, 4, 0, 0), 'E'): 2.0202020202020203,
#   ((7, False, 4, 4, 0, 0), 'Pick'): 30.2020202020202,
#   ((7, True, 3, 4, 0, 0), 'W'): 2.020202020201989,
#   ((6, True, 3, 4, 0, 0), 'Deliver'): 30.202020202019888,
#   ((6, False, 3, 4, 1, 0), 'SW'): -1.0967741935483872,
#   ((5, False, 3, 4, 1, 0), 'NE'): -1.098360655737705,
#   ((6, False, 3, 4, 1, 0), 'S'): -1.098360655737705,
#   ((9, False, 3, 4, 1, 0), 'N'): -1.098360655737705,
#   ((6, False, 3, 4, 1, 0), 'E'): 2.020202020198889,
#   ((7, False, 3, 4, 1, 0), 'Pick'): 30.20202020198889,
#   ((7, True, 2, 4, 1, 0), 'W'): 2.020202019888892,
#   ((6, True, 2, 4, 1, 0), 'Deliver'): 30.20202019888892,
#   ((6, False, 2, 4, 2, 0), 'SW'): -1.0967741935483872,
#   ((5, False, 2, 4, 2, 0), 'NE'): -1.098360655737705,
#   ((6, False, 2, 4, 2, 0), 'S'): -1.098360655737705,
#   ((9, False, 2, 4, 2, 0), 'N'): -1.098360655737705,
#   ((6, False, 2, 4, 2, 0), 'E'): 2.020201988889199,
#   ((7, False, 2, 4, 2, 0), 'Pick'): 30.20201988889199,
#   ((7, True, 1, 4, 2, 0), 'W'): 2.0201988889198894,
#   ((6, True, 1, 4, 2, 0), 'Deliver'): 30.20198888919889,
#   ((6, False, 1, 4, 3, 0), 'SW'): -1.0967741935483872,
#   ((5, False, 1, 4, 3, 0), 'NE'): -1.098360655737705,
#   ((6, False, 1, 4, 3, 0), 'S'): -1.098360655737705,
#   ((9, False, 1, 4, 3, 0), 'N'): -1.098360655737705,
#   ((6, False, 1, 4, 3, 0), 'E'): 2.01988889198892,
#   ((7, False, 1, 4, 3, 0), 'Pick'): 30.1988889198892,
#   ((7, True, 0, 4, 3, 0), 'W'): 1.9888891988919895,
#   ((6, True, 0, 4, 3, 0), 'Deliver'): 29.88889198891989,
#   ((6, False, 0, 4, 4, 0), 'SW'): -1.111080110801108,
#   ((5, False, 0, 4, 4, 0), 'NE'): -1.1111027789295718,
#   ((6, False, 0, 4, 4, 0), 'S'): -1.111107017714821,
#   ((9, False, 0, 4, 4, 0), 'N'): -1.1111070918830355,
#   ((6, False, 0, 4, 4, 0), 'E'): -1.1111061354395737,
#   ((7, False, 0, 4, 4, 0), 'W'): -1.1111092577630142,
#   ((5, False, 0, 4, 4, 0), 'SW'): -1.11080110801108,
#   ((4, False, 0, 4, 4, 0), 'NW'): -1.1108897730805531,
#   ((2, False, 0, 4, 4, 0), 'SE'): -1.110912517463071,
#   ((4, False, 0, 4, 4, 0), 'SW'): -1.1080110801108012,
#   ((3, False, 0, 4, 4, 0), 'NW'): -1.1094658910629296,
#   ((1, False, 0, 4, 4, 0), 'SE'): -1.1094658910629296,
#   ((3, False, 0, 4, 4, 0), 'NE'): -1.1105405912556932,
#   ((4, False, 0, 4, 4, 0), 'NE'): -1.1108185110286708,
#   ((3, False, 0, 4, 4, 0), 'SW'): -1.0801108011080112,
#   ((17, False, 0, 4, 4, 0), 'NE'): -1.1,
#   ((17, False, 0, 4, 4, 0), 'SW'): -0.8011080110801108,
#   ((16, False, 0, 4, 4, 0), 'S'): -1.0967741935483872,
#   ((15, False, 0, 4, 4, 0), 'N'): -1.0999471179270228,
#   ((16, False, 0, 4, 4, 0), 'E'): 1.988919889198892,
#   ((11, False, 0, 4, 4, 0), 'Pick'): 29.88919889198892,
#   ((11, True, 0, 3, 4, 0), 'W'): -1.1080110801108012,
#   ((16, True, 0, 3, 4, 0), 'S'): -1.0801108011080112,
#   ((15, True, 0, 3, 4, 0), 'N'): -1.098360655737705,
#   ((16, True, 0, 3, 4, 0), 'E'): -1.110818066187092,
#   ((16, True, 0, 3, 4, 0), 'NE'): -1.1094658910629296,
#   ((17, True, 0, 3, 4, 0), 'NE'): -1.1092140716677998,
#   ((3, True, 0, 3, 4, 0), 'NW'): -1.1094658910629296,
#   ((1, True, 0, 3, 4, 0), 'SE'): -1.1104172650040647,
#   ((3, True, 0, 3, 4, 0), 'NE'): -1.1092140716677998,
#   ((4, True, 0, 3, 4, 0), 'NW'): -1.1094658910629296,
#   ((2, True, 0, 3, 4, 0), 'SE'): -1.1094658910629296,
#   ((4, True, 0, 3, 4, 0), 'SW'): -1.1094658910629296,
#   ((3, True, 0, 3, 4, 0), 'SW'): -1.1099416619289066,
#   ((17, True, 0, 3, 4, 0), 'SW'): -1.1098209564100627,
#   ((15, True, 0, 3, 4, 0), 'SE'): -0.8011080110801108,
#   ((12, True, 0, 3, 4, 0), 'NW'): -1.1,
#   ((12, True, 0, 3, 4, 0), 'SE'): 1.988919889198892,
#   ((13, True, 0, 3, 4, 0), 'Deliver'): 29.88919889198892,
#   ((13, False, 0, 3, 4, 1), 'NW'): -1.1080110801108012,
#   ((12, False, 0, 3, 4, 1), 'NW'): -1.0801108011080112,
#   ((15, False, 0, 3, 4, 1), 'N'): -0.8011080110801108,
#   ((16, False, 0, 3, 4, 1), 'S'): -1.098360655737705,
#   ((15, False, 0, 3, 4, 1), 'SE'): -1.1081915197961005,
#   ((12, False, 0, 3, 4, 1), 'SE'): -1.1108171704499434,
#   ((16, False, 0, 3, 4, 1), 'E'): 1.988919889198892,
#   ((11, False, 0, 3, 4, 1), 'Pick'): 29.88919889198892,
#   ((11, True, 0, 2, 4, 1), 'W'): -1.1080110801108012,
#   ((16, True, 0, 2, 4, 1), 'S'): -1.0801108011080112,
#   ((15, True, 0, 2, 4, 1), 'N'): -1.098360655737705,
#   ((16, True, 0, 2, 4, 1), 'E'): -1.110818066187092,
#   ((16, True, 0, 2, 4, 1), 'NE'): -1.1094658910629296,
#   ((17, True, 0, 2, 4, 1), 'NE'): -1.1092140716677998,
#   ((3, True, 0, 2, 4, 1), 'NW'): -1.1094658910629296,
#   ((1, True, 0, 2, 4, 1), 'SE'): -1.1104172650040647,
#   ((3, True, 0, 2, 4, 1), 'NE'): -1.1092140716677998,
#   ((4, True, 0, 2, 4, 1), 'NW'): -1.1094658910629296,
#   ((2, True, 0, 2, 4, 1), 'SE'): -1.1094658910629296,
#   ((4, True, 0, 2, 4, 1), 'SW'): -1.1094658910629296,
#   ((3, True, 0, 2, 4, 1), 'SW'): -1.1099416619289066,
#   ((17, True, 0, 2, 4, 1), 'SW'): -1.1098209564100627,
#   ((15, True, 0, 2, 4, 1), 'SE'): -0.8011080110801108,
#   ((12, True, 0, 2, 4, 1), 'NW'): -1.1,
#   ((12, True, 0, 2, 4, 1), 'SE'): 1.988919889198892,
#   ((13, True, 0, 2, 4, 1), 'Deliver'): 29.88919889198892,
#   ((13, False, 0, 2, 4, 2), 'NW'): -1.1080110801108012,
#   ((12, False, 0, 2, 4, 2), 'NW'): -1.0801108011080112,
#   ((15, False, 0, 2, 4, 2), 'N'): -0.8011080110801108,
#   ((16, False, 0, 2, 4, 2), 'S'): -1.098360655737705,
#   ((15, False, 0, 2, 4, 2), 'SE'): -1.1081915197961005,
#   ((12, False, 0, 2, 4, 2), 'SE'): -1.1108171704499434,
#   ((16, False, 0, 2, 4, 2), 'E'): 1.9889198891988928,
#   ((11, False, 0, 2, 4, 2), 'Pick'): 29.889198891988926,
#   ((11, True, 0, 1, 4, 2), 'W'): -1.10801108011075,
#   ((16, True, 0, 1, 4, 2), 'S'): -1.0801108011075,
#   ((15, True, 0, 1, 4, 2), 'N'): -1.098360655737705,
#   ((16, True, 0, 1, 4, 2), 'E'): -1.110818066187092,
#   ((16, True, 0, 1, 4, 2), 'NE'): -1.1094658910629296,
#   ((17, True, 0, 1, 4, 2), 'NE'): -1.1092140716677998,
#   ((3, True, 0, 1, 4, 2), 'NW'): -1.1094658910629296,
#   ((1, True, 0, 1, 4, 2), 'SE'): -1.1104172650040647,
#   ((3, True, 0, 1, 4, 2), 'NE'): -1.1092140716677998,
#   ((4, True, 0, 1, 4, 2), 'NW'): -1.1094658910629296,
#   ((2, True, 0, 1, 4, 2), 'SE'): -1.1094658910629296,
#   ((4, True, 0, 1, 4, 2), 'SW'): -1.1094658910629296,
#   ((3, True, 0, 1, 4, 2), 'SW'): -1.1099416619289066,
#   ((17, True, 0, 1, 4, 2), 'SW'): -1.1098209564100627,
#   ((15, True, 0, 1, 4, 2), 'SE'): -0.801108011075,
#   ((12, True, 0, 1, 4, 2), 'NW'): -1.1,
#   ((12, True, 0, 1, 4, 2), 'SE'): 1.9889198892500004,
#   ((13, True, 0, 1, 4, 2), 'Deliver'): 29.8891988925,
#   ((13, False, 0, 1, 4, 3), 'NW'): -1.108011075,
#   ((12, False, 0, 1, 4, 3), 'NW'): -1.08011075,
#   ((15, False, 0, 1, 4, 3), 'N'): -0.8011075,
#   ((16, False, 0, 1, 4, 3), 'S'): -1.098360655737705,
#   ((15, False, 0, 1, 4, 3), 'SE'): -1.1081915197961005,
#   ((12, False, 0, 1, 4, 3), 'SE'): -1.1108171704499434,
#   ((16, False, 0, 1, 4, 3), 'E'): 1.988925,
#   ((11, False, 0, 1, 4, 3), 'Pick'): 29.88925,
#   ((11, True, 0, 0, 4, 3), 'W'): -1.1075,
#   ((16, True, 0, 0, 4, 3), 'S'): -1.075,
#   ((15, True, 0, 0, 4, 3), 'N'): -1.098360655737705,
#   ((16, True, 0, 0, 4, 3), 'E'): -1.110818066187092,
#   ((16, True, 0, 0, 4, 3), 'NE'): -1.1094658910629296,
#   ((17, True, 0, 0, 4, 3), 'NE'): -1.1092140716677998,
#   ((3, True, 0, 0, 4, 3), 'NW'): -1.1094658910629296,
#   ((1, True, 0, 0, 4, 3), 'SE'): -1.1104172650040647,
#   ((3, True, 0, 0, 4, 3), 'NE'): -1.1092140716677998,
#   ((4, True, 0, 0, 4, 3), 'NW'): -1.1094658910629296,
#   ((2, True, 0, 0, 4, 3), 'SE'): -1.1094658910629296,
#   ((4, True, 0, 0, 4, 3), 'SW'): -1.1094658910629296,
#   ((3, True, 0, 0, 4, 3), 'SW'): -1.1099416619289066,
#   ((17, True, 0, 0, 4, 3), 'SW'): -1.1098209564100627,
#   ((15, True, 0, 0, 4, 3), 'SE'): -0.75,
#   ((12, True, 0, 0, 4, 3), 'NW'): -1.1,
#   ((12, True, 0, 0, 4, 3), 'SE'): 2.5,
#   ((13, True, 0, 0, 4, 3), 'Deliver'): 35.0,
#   ((13, False, 0, 0, 4, 4), 'NW'): 50.0,
#   ((16, False, 4, 4, 0, 0), 'NE'): -1.1,
#   ((15, False, 4, 4, 0, 0), 'SE'): -1.1064516129032258,
#   ((12, False, 4, 4, 0, 0), 'NW'): -1.1095187731359069,
#   ((12, False, 4, 4, 0, 0), 'SE'): -1.1081967213114754,
#   ((13, False, 4, 4, 0, 0), 'NW'): -1.1098360655737707,
#   ((4, True, 4, 3, 0, 0), 'NE'): -1.0967741935483872,
#   ((5, True, 4, 3, 0, 0), 'NE'): 1.9508196721311473,
#   ((6, True, 4, 3, 0, 0), 'Deliver'): 29.901639344262293,
#   ((6, False, 4, 3, 1, 0), 'SW'): -1.0967741935483872,
#   ((5, False, 4, 3, 1, 0), 'NE'): -1.098360655737705,
#   ((6, False, 4, 3, 1, 0), 'S'): -1.0,
#   ((9, False, 4, 3, 1, 0), 'N'): -1.0,
#   ((6, False, 4, 3, 1, 0), 'E'): -1.0,
#   ((7, False, 4, 3, 1, 0), 'Pick'): 30.0,
#   ((7, True, 3, 3, 1, 0), 'W'): -1.0,
#   ((6, True, 3, 3, 1, 0), 'Deliver'): 30.0,
#   ((6, False, 3, 3, 2, 0), 'SW'): -1.0,
#   ((5, False, 3, 3, 2, 0), 'NE'): -1.0,
#   ((6, False, 3, 3, 2, 0), 'S'): -1.0,
#   ((9, False, 3, 3, 2, 0), 'N'): -1.0,
#   ((6, False, 3, 3, 2, 0), 'E'): -1.0,
#   ((7, False, 3, 3, 2, 0), 'Pick'): 30.0,
#   ((7, True, 2, 3, 2, 0), 'W'): -1.0,
#   ((6, True, 2, 3, 2, 0), 'Deliver'): 30.0,
#   ((6, False, 2, 3, 3, 0), 'SW'): -1.0,
#   ((5, False, 2, 3, 3, 0), 'NE'): -1.0,
#   ((6, False, 2, 3, 3, 0), 'S'): -1.0,
#   ((9, False, 2, 3, 3, 0), 'N'): -1.0,
#   ((6, False, 2, 3, 3, 0), 'E'): -1.0,
#   ((7, False, 2, 3, 3, 0), 'Pick'): 30.0,
#   ((7, True, 1, 3, 3, 0), 'W'): -1.0,
#   ((6, True, 1, 3, 3, 0), 'Deliver'): 30.0,
#   ((6, False, 1, 3, 4, 0), 'SW'): -1.0,
#   ((5, False, 1, 3, 4, 0), 'NE'): -1.0,
#   ((6, False, 1, 3, 4, 0), 'S'): -1.0,
#   ((9, False, 1, 3, 4, 0), 'N'): -1.0,
#   ((6, False, 1, 3, 4, 0), 'E'): -1.0,
#   ((7, False, 1, 3, 4, 0), 'Pick'): 30.0,
#   ((7, True, 0, 3, 4, 0), 'W'): -1.0,
#   ((6, True, 0, 3, 4, 0), 'SW'): -1.0,
#   ((5, True, 0, 3, 4, 0), 'NE'): -1.0,
#   ((6, True, 0, 3, 4, 0), 'S'): -1.0,
#   ((9, True, 0, 3, 4, 0), 'Deliver'): 30.0,
#   ((9, False, 0, 3, 4, 1), 'N'): -1.1110226857797587,
#   ((6, False, 0, 3, 4, 1), 'SW'): -1.1109686481203302,
#   ((5, False, 0, 3, 4, 1), 'NE'): -1.1109632416791966,
#   ((6, False, 0, 3, 4, 1), 'S'): -1.1110091764766954,
#   ((6, False, 0, 3, 4, 1), 'E'): -1.1110595143662965,
#   ((7, False, 0, 3, 4, 1), 'W'): -1.111075711196565,
#   ((5, False, 0, 3, 4, 1), 'SW'): -1.1108517933513689,
#   ((4, False, 0, 3, 4, 1), 'NW'): -1.1094658910629296,
#   ((2, False, 0, 3, 4, 1), 'SE'): -1.1096096718143424,
#   ((4, False, 0, 3, 4, 1), 'SW'): -1.1105202516063173,
#   ((3, False, 0, 3, 4, 1), 'NW'): -1.1094658910629296,
#   ((1, False, 0, 3, 4, 1), 'SE'): -1.1094658910629296,
#   ((3, False, 0, 3, 4, 1), 'NE'): -1.1096245372818616,
#   ((4, False, 0, 3, 4, 1), 'NE'): -1.1107827413719864,
#   ((3, False, 0, 3, 4, 1), 'SW'): -1.0826219435420916,
#   ((17, False, 0, 3, 4, 1), 'NE'): -1.1,
#   ((17, False, 0, 3, 4, 1), 'SW'): -0.8017425902142983,
#   ((16, False, 0, 3, 4, 1), 'NE'): -1.1,
#   ((4, True, 0, 2, 4, 1), 'NE'): -1.098360655737705,
#   ((5, True, 0, 2, 4, 1), 'NE'): -1.0,
#   ((6, True, 0, 2, 4, 1), 'SW'): -1.0,
#   ((5, True, 0, 2, 4, 1), 'SW'): -1.1,
#   ((6, True, 0, 2, 4, 1), 'S'): -1.0,
#   ((9, True, 0, 2, 4, 1), 'Deliver'): 30.0,
#   ((9, False, 0, 2, 4, 2), 'N'): -1.1110548545187844,
#   ((6, False, 0, 2, 4, 2), 'SW'): -1.1109686481203302,
#   ((5, False, 0, 2, 4, 2), 'NE'): -1.110928961748634,
#   ((6, False, 0, 2, 4, 2), 'S'): -1.1110250051243893,
#   ((6, False, 0, 2, 4, 2), 'E'): -1.1110107824111173,
#   ((7, False, 0, 2, 4, 2), 'W'): -1.1110187473543973,
#   ((5, False, 0, 2, 4, 2), 'SW'): -1.1108517933513689,
#   ((4, False, 0, 2, 4, 2), 'NW'): -1.1094658910629296,
#   ((2, False, 0, 2, 4, 2), 'SE'): -1.1096096718143424,
#   ((4, False, 0, 2, 4, 2), 'SW'): -1.1105202516063173,
#   ((3, False, 0, 2, 4, 2), 'NW'): -1.1094658910629296,
#   ((1, False, 0, 2, 4, 2), 'SE'): -1.1094658910629296,
#   ((3, False, 0, 2, 4, 2), 'NE'): -1.1096245372818616,
#   ((4, False, 0, 2, 4, 2), 'NE'): -1.1107827413719864,
#   ((3, False, 0, 2, 4, 2), 'SW'): -1.0826219435420916,
#   ((17, False, 0, 2, 4, 2), 'NE'): -1.1,
#   ((17, False, 0, 2, 4, 2), 'SW'): -0.8017425902142983,
#   ((16, False, 0, 2, 4, 2), 'NE'): -1.1,
#   ((4, True, 0, 1, 4, 2), 'NE'): -1.098360655737705,
#   ((5, True, 0, 1, 4, 2), 'NE'): -1.0,
#   ((6, True, 0, 1, 4, 2), 'SW'): -1.0,
#   ((5, True, 0, 1, 4, 2), 'SW'): -1.1,
#   ((6, True, 0, 1, 4, 2), 'S'): -1.0,
#   ((9, True, 0, 1, 4, 2), 'Deliver'): 30.0,
#   ((9, False, 0, 1, 4, 3), 'N'): -1.1106116693107704,
#   ((6, False, 0, 1, 4, 3), 'SW'): -1.1097971909546474,
#   ((5, False, 0, 1, 4, 3), 'NE'): -1.1096245372818616,
#   ((6, False, 0, 1, 4, 3), 'S'): -1.1103017689906347,
#   ((6, False, 0, 1, 4, 3), 'E'): -1.1099418297197252,
#   ((7, False, 0, 1, 4, 3), 'W'): -1.1108473041844067,
#   ((5, False, 0, 1, 4, 3), 'SW'): -1.1093123624639634,
#   ((4, False, 0, 1, 4, 3), 'NW'): -1.098360655737705,
#   ((2, False, 0, 1, 4, 3), 'SE'): -1.098360655737705,
#   ((4, False, 0, 1, 4, 3), 'SW'): -1.099846390168971,
#   ((3, False, 0, 1, 4, 3), 'NW'): -1.098360655737705,
#   ((1, False, 0, 1, 4, 3), 'SE'): -1.098360655737705,
#   ((3, False, 0, 1, 4, 3), 'NE'): -1.098360655737705,
#   ((4, False, 0, 1, 4, 3), 'NE'): -1.1,
#   ((3, False, 0, 1, 4, 3), 'SW'): -1.106292966684294,
#   ((17, False, 0, 1, 4, 3), 'NE'): -1.1,
#   ((17, False, 0, 1, 4, 3), 'SW'): -0.8106992374746251,
#   ((16, False, 0, 1, 4, 3), 'NE'): -1.1,
#   ((4, True, 0, 0, 4, 3), 'NE'): -1.098360655737705,
#   ((5, True, 0, 0, 4, 3), 'NE'): -1.0967741935483872,
#   ((6, True, 0, 0, 4, 3), 'SW'): -1.098360655737705,
#   ((5, True, 0, 0, 4, 3), 'SW'): -1.1,
#   ((6, True, 0, 0, 4, 3), 'S'): 1.9508196721311473,
#   ((9, True, 0, 0, 4, 3), 'Deliver'): 34.91803278688525,
#   ((9, False, 0, 0, 4, 4), 'N'): 50.0,
#   ((16, False, 4, 3, 0, 1), 'NE'): -1.0,
#   ((17, False, 4, 3, 0, 1), 'NE'): -1.0,
#   ((3, False, 4, 3, 0, 1), 'NW'): -1.0,
#   ((1, False, 4, 3, 0, 1), 'SE'): -1.0,
#   ((3, False, 4, 3, 0, 1), 'NE'): -1.0,
#   ((4, False, 4, 3, 0, 1), 'NW'): -1.0,
#   ((2, False, 4, 3, 0, 1), 'SE'): -1.0,
#   ((4, False, 4, 3, 0, 1), 'SW'): -1.0,
#   ((3, False, 4, 3, 0, 1), 'SW'): -1.0,
#   ((17, False, 4, 3, 0, 1), 'SW'): -1.1,
#   ((4, True, 4, 2, 0, 1), 'NE'): -1.0967741935483872,
#   ((5, True, 4, 2, 0, 1), 'NE'): 1.9508196721311473,
#   ((6, True, 4, 2, 0, 1), 'Deliver'): 29.901639344262293,
#   ((6, False, 4, 2, 1, 1), 'SW'): -1.0967741935483872,
#   ((5, False, 4, 2, 1, 1), 'NE'): -1.098360655737705,
#   ((6, False, 4, 2, 1, 1), 'S'): -1.0,
#   ((9, False, 4, 2, 1, 1), 'N'): -1.0,
#   ((6, False, 4, 2, 1, 1), 'E'): -1.0,
#   ((7, False, 4, 2, 1, 1), 'Pick'): 30.0,
#   ((7, True, 3, 2, 1, 1), 'W'): -1.0,
#   ((6, True, 3, 2, 1, 1), 'Deliver'): 30.0,
#   ((6, False, 3, 2, 2, 1), 'SW'): -1.0,
#   ((5, False, 3, 2, 2, 1), 'NE'): -1.0,
#   ((6, False, 3, 2, 2, 1), 'S'): -1.0,
#   ((9, False, 3, 2, 2, 1), 'N'): -1.0,
#   ((6, False, 3, 2, 2, 1), 'E'): -1.0,
#   ((7, False, 3, 2, 2, 1), 'Pick'): 30.0,
#   ((7, True, 2, 2, 2, 1), 'W'): -1.0,
#   ((6, True, 2, 2, 2, 1), 'Deliver'): 30.0,
#   ((6, False, 2, 2, 3, 1), 'SW'): -1.0,
#   ((5, False, 2, 2, 3, 1), 'NE'): -1.0,
#   ((6, False, 2, 2, 3, 1), 'S'): -1.0,
#   ((9, False, 2, 2, 3, 1), 'N'): -1.0,
#   ((6, False, 2, 2, 3, 1), 'E'): -1.0,
#   ((7, False, 2, 2, 3, 1), 'Pick'): 30.0,
#   ((7, True, 1, 2, 3, 1), 'W'): -1.0,
#   ((6, True, 1, 2, 3, 1), 'Deliver'): 30.0,
#   ((6, False, 1, 2, 4, 1), 'SW'): -1.0,
#   ((5, False, 1, 2, 4, 1), 'NE'): -1.0,
#   ((6, False, 1, 2, 4, 1), 'S'): -1.0,
#   ((9, False, 1, 2, 4, 1), 'N'): -1.0,
#   ((6, False, 1, 2, 4, 1), 'E'): -1.0,
#   ((7, False, 1, 2, 4, 1), 'Pick'): 30.0,
#   ((7, True, 0, 2, 4, 1), 'W'): -1.0,
#   ((6, True, 0, 2, 4, 1), 'E'): -1.0,
#   ((7, True, 0, 2, 4, 1), 'SW'): -1.0,
#   ((8, True, 0, 2, 4, 1), 'Deliver'): 30.0,
#   ((8, False, 0, 2, 4, 2), 'NE'): -1.1110734643845706,
#   ((7, False, 0, 2, 4, 2), 'SW'): -1.1110705397283347,
#   ((7, True, 3, 4, 0, 0), 'SW'): -1.0,
#   ((8, True, 3, 4, 0, 0), 'Deliver'): 30.0,
#   ((8, False, 3, 4, 0, 1), 'NE'): -1.0,
#   ((7, False, 3, 4, 0, 1), 'Pick'): 30.0,
#   ((7, True, 2, 4, 0, 1), 'W'): -1.0,
#   ((6, True, 2, 4, 0, 1), 'Deliver'): 30.0,
#   ((6, False, 2, 4, 1, 1), 'SW'): -1.0,
#   ((5, False, 2, 4, 1, 1), 'NE'): -1.0,
#   ((6, False, 2, 4, 1, 1), 'S'): -1.0,
#   ((9, False, 2, 4, 1, 1), 'N'): -1.0,
#   ((6, False, 2, 4, 1, 1), 'E'): -1.0,
#   ((7, False, 2, 4, 1, 1), 'Pick'): 30.0,
#   ((7, True, 1, 4, 1, 1), 'W'): -1.0,
#   ((6, True, 1, 4, 1, 1), 'Deliver'): 30.0,
#   ((6, False, 1, 4, 2, 1), 'SW'): -1.0,
#   ((5, False, 1, 4, 2, 1), 'NE'): -1.0,
#   ((6, False, 1, 4, 2, 1), 'S'): -1.0,
#   ((9, False, 1, 4, 2, 1), 'N'): -1.0,
#   ((6, False, 1, 4, 2, 1), 'E'): -1.0,
#   ((7, False, 1, 4, 2, 1), 'Pick'): 30.0,
#   ((7, True, 0, 4, 2, 1), 'W'): -1.0,
#   ((6, True, 0, 4, 2, 1), 'Deliver'): 30.0,
#   ((6, False, 0, 4, 3, 1), 'SW'): -1.1097971909546474,
#   ((5, False, 0, 4, 3, 1), 'NE'): -1.1094658910629296,
#   ((6, False, 0, 4, 3, 1), 'S'): -1.1094658910629296,
#   ((9, False, 0, 4, 3, 1), 'N'): -1.1104177683765204,
#   ((6, False, 0, 4, 3, 1), 'E'): -1.1099418297197252,
#   ((7, False, 0, 4, 3, 1), 'W'): -1.1108473041844067,
#   ((5, False, 0, 4, 3, 1), 'SW'): -1.1093123624639634,
#   ((4, False, 0, 4, 3, 1), 'NW'): -1.098360655737705,
#   ((2, False, 0, 4, 3, 1), 'SE'): -1.098360655737705,
#   ((4, False, 0, 4, 3, 1), 'SW'): -1.099846390168971,
#   ((3, False, 0, 4, 3, 1), 'NW'): -1.098360655737705,
#   ((1, False, 0, 4, 3, 1), 'SE'): -1.098360655737705,
#   ((3, False, 0, 4, 3, 1), 'NE'): -1.098360655737705,
#   ((4, False, 0, 4, 3, 1), 'NE'): -1.1,
#   ((3, False, 0, 4, 3, 1), 'SW'): -1.0967741935483872,
#   ((17, False, 0, 4, 3, 1), 'NE'): -1.1,
#   ((17, False, 0, 4, 3, 1), 'SW'): -1.0967741935483872,
#   ((16, False, 0, 4, 3, 1), 'S'): -1.0967741935483872,
#   ((15, False, 0, 4, 3, 1), 'N'): -1.0999471179270228,
#   ((16, False, 0, 4, 3, 1), 'E'): 1.9508196721311473,
#   ((11, False, 0, 4, 3, 1), 'Pick'): 29.901639344262293,
#   ((11, True, 0, 3, 3, 1), 'W'): -1.0967741935483872,
#   ((16, True, 0, 3, 3, 1), 'S'): -1.0967741935483872,
#   ((15, True, 0, 3, 3, 1), 'N'): -1.098360655737705,
#   ((16, True, 0, 3, 3, 1), 'E'): -1.1,
#   ((16, True, 0, 3, 3, 1), 'NE'): -1.098360655737705,
#   ((17, True, 0, 3, 3, 1), 'NE'): -1.098360655737705,
#   ((3, True, 0, 3, 3, 1), 'NW'): -1.098360655737705,
#   ((1, True, 0, 3, 3, 1), 'SE'): -1.098360655737705,
#   ((3, True, 0, 3, 3, 1), 'NE'): -1.0,
#   ((4, True, 0, 3, 3, 1), 'NW'): -1.0,
#   ((2, True, 0, 3, 3, 1), 'SE'): -1.0,
#   ((4, True, 0, 3, 3, 1), 'SW'): -1.0,
#   ((3, True, 0, 3, 3, 1), 'SW'): -1.0,
#   ((17, True, 0, 3, 3, 1), 'SW'): -1.1,
#   ((15, True, 0, 3, 3, 1), 'SE'): -1.0,
#   ((12, True, 0, 3, 3, 1), 'NW'): -1.1,
#   ((12, True, 0, 3, 3, 1), 'SE'): -1.0,
#   ((13, True, 0, 3, 3, 1), 'Deliver'): 30.0,
#   ((13, False, 0, 3, 3, 2), 'NW'): -1.098360655737705,
#   ((12, False, 0, 3, 3, 2), 'NW'): -1.098360655737705,
#   ((15, False, 0, 3, 3, 2), 'N'): -1.0967741935483872,
#   ((16, False, 0, 3, 3, 2), 'S'): -1.098360655737705,
#   ((15, False, 0, 3, 3, 2), 'SE'): -1.0,
#   ((12, False, 0, 3, 3, 2), 'SE'): -1.1,
#   ((16, False, 0, 3, 3, 2), 'E'): 1.9508196721311473,
#   ((11, False, 0, 3, 3, 2), 'Pick'): 29.901639344262293,
#   ((11, True, 0, 2, 3, 2), 'W'): -1.0967741935483872,
#   ((16, True, 0, 2, 3, 2), 'S'): -1.0967741935483872,
#   ((15, True, 0, 2, 3, 2), 'N'): -1.098360655737705,
#   ((16, True, 0, 2, 3, 2), 'E'): -1.1,
#   ((16, True, 0, 2, 3, 2), 'NE'): -1.098360655737705,
#   ((17, True, 0, 2, 3, 2), 'NE'): -1.098360655737705,
#   ((3, True, 0, 2, 3, 2), 'NW'): -1.098360655737705,
#   ((1, True, 0, 2, 3, 2), 'SE'): -1.098360655737705,
#   ((3, True, 0, 2, 3, 2), 'NE'): -1.0,
#   ((4, True, 0, 2, 3, 2), 'NW'): -1.0,
#   ((2, True, 0, 2, 3, 2), 'SE'): -1.0,
#   ((4, True, 0, 2, 3, 2), 'SW'): -1.0,
#   ((3, True, 0, 2, 3, 2), 'SW'): -1.0,
#   ((17, True, 0, 2, 3, 2), 'SW'): -1.1,
#   ((15, True, 0, 2, 3, 2), 'SE'): -1.0,
#   ((12, True, 0, 2, 3, 2), 'NW'): -1.1,
#   ((12, True, 0, 2, 3, 2), 'SE'): -1.0,
#   ((13, True, 0, 2, 3, 2), 'Deliver'): 30.0,
#   ((13, False, 0, 2, 3, 3), 'NW'): -1.098360655737705,
#   ((12, False, 0, 2, 3, 3), 'NW'): -1.098360655737705,
#   ((15, False, 0, 2, 3, 3), 'N'): -1.0,
#   ((16, False, 0, 2, 3, 3), 'S'): -1.0,
#   ((15, False, 0, 2, 3, 3), 'SE'): -1.0,
#   ((12, False, 0, 2, 3, 3), 'SE'): -1.1,
#   ((16, False, 0, 2, 3, 3), 'E'): -1.0,
#   ((11, False, 0, 2, 3, 3), 'Pick'): 30.0,
#   ((11, True, 0, 1, 3, 3), 'W'): -1.0,
#   ((16, True, 0, 1, 3, 3), 'S'): -1.0967741935483872,
#   ((15, True, 0, 1, 3, 3), 'N'): -1.098360655737705,
#   ((16, True, 0, 1, 3, 3), 'E'): -1.1,
#   ((16, True, 0, 1, 3, 3), 'NE'): -1.0,
#   ((17, True, 0, 1, 3, 3), 'NE'): -1.0,
#   ((3, True, 0, 1, 3, 3), 'NW'): -1.0,
#   ((1, True, 0, 1, 3, 3), 'SE'): -1.0,
#   ((3, True, 0, 1, 3, 3), 'NE'): -1.0,
#   ((4, True, 0, 1, 3, 3), 'NW'): -1.0,
#   ((2, True, 0, 1, 3, 3), 'SE'): -1.0,
#   ((4, True, 0, 1, 3, 3), 'SW'): -1.0,
#   ((3, True, 0, 1, 3, 3), 'SW'): -1.0,
#   ((17, True, 0, 1, 3, 3), 'SW'): -1.1,
#   ((15, True, 0, 1, 3, 3), 'SE'): -1.0,
#   ((12, True, 0, 1, 3, 3), 'NW'): -1.1,
#   ((12, True, 0, 1, 3, 3), 'SE'): -1.0,
#   ((13, True, 0, 1, 3, 3), 'Deliver'): 30.0,
#   ((13, False, 0, 1, 3, 4), 'NW'): -1.098360655737705,
#   ((12, False, 0, 1, 3, 4), 'NW'): -1.098360655737705,
#   ((15, False, 0, 1, 3, 4), 'N'): -1.0967741935483872,
#   ((16, False, 0, 1, 3, 4), 'S'): -1.098360655737705,
#   ((15, False, 0, 1, 3, 4), 'SE'): -1.0,
#   ((12, False, 0, 1, 3, 4), 'SE'): -1.1,
#   ((16, False, 0, 1, 3, 4), 'E'): 1.9508196721311473,
#   ((11, False, 0, 1, 3, 4), 'Pick'): 29.901639344262293,
#   ((11, True, 0, 0, 3, 4), 'W'): -1.1061394380853278,
#   ((16, True, 0, 0, 3, 4), 'S'): -1.1093651633048778,
#   ((15, True, 0, 0, 3, 4), 'N'): -1.1093651633048778,
#   ((16, True, 0, 0, 3, 4), 'E'): -1.1,
#   ((16, True, 0, 0, 3, 4), 'NE'): -1.1094658910629296,
#   ((17, True, 0, 0, 3, 4), 'NE'): -1.1092140716677998,
#   ((3, True, 0, 0, 3, 4), 'NW'): -1.098360655737705,
#   ((1, True, 0, 0, 3, 4), 'SE'): -1.098360655737705,
#   ((3, True, 0, 0, 3, 4), 'NE'): -1.099846390168971,
#   ((4, True, 0, 0, 3, 4), 'NW'): -1.098360655737705,
#   ((2, True, 0, 0, 3, 4), 'SE'): -1.098360655737705,
#   ((4, True, 0, 0, 3, 4), 'SW'): -1.098360655737705,
#   ((3, True, 0, 0, 3, 4), 'SW'): -1.1081915197961005,
#   ((17, True, 0, 0, 3, 4), 'SW'): -1.1,
#   ((15, True, 0, 0, 3, 4), 'SE'): -1.1064516129032258,
#   ((12, True, 0, 0, 3, 4), 'NW'): -1.1095187731359069,
#   ((12, True, 0, 0, 3, 4), 'SE'): -1.1081967213114754,
#   ((13, True, 0, 0, 3, 4), 'NW'): -1.1098360655737707,
#   ((4, True, 0, 0, 3, 4), 'NE'): -0.8032786885245902,
#   ((5, True, 0, 0, 3, 4), 'NE'): 2.491543202919784,
#   ((5, True, 4, 3, 0, 0), 'SW'): -1.1,
#   ((5, False, 4, 3, 1, 0), 'SW'): -1.098360655737705,
#   ((4, False, 4, 3, 1, 0), 'NW'): -1.098360655737705,
#   ((2, False, 4, 3, 1, 0), 'SE'): -1.098360655737705,
#   ((4, False, 4, 3, 1, 0), 'SW'): -1.0967741935483872,
#   ((3, False, 4, 3, 1, 0), 'NW'): -1.098360655737705,
#   ((1, False, 4, 3, 1, 0), 'SE'): -1.098360655737705,
#   ((3, False, 4, 3, 1, 0), 'NE'): -1.098360655737705,
#   ((4, False, 4, 3, 1, 0), 'NE'): -1.1,
#   ((3, False, 4, 3, 1, 0), 'SW'): -1.0,
#   ((17, False, 4, 3, 1, 0), 'NE'): -1.1,
#   ((17, False, 4, 3, 1, 0), 'SW'): -1.0,
#   ((16, False, 4, 3, 1, 0), 'S'): -1.0,
#   ((15, False, 4, 3, 1, 0), 'N'): -1.0,
#   ((16, False, 4, 3, 1, 0), 'E'): -1.0,
#   ((11, False, 4, 3, 1, 0), 'Pick'): 30.0,
#   ((11, True, 4, 2, 1, 0), 'W'): -1.0,
#   ((16, True, 4, 2, 1, 0), 'S'): -1.0967741935483872,
#   ((15, True, 4, 2, 1, 0), 'N'): -1.098360655737705,
#   ((16, True, 4, 2, 1, 0), 'E'): -1.1,
#   ((16, True, 4, 2, 1, 0), 'NE'): -1.0,
#   ((17, True, 4, 2, 1, 0), 'NE'): -1.0,
#   ((3, True, 4, 2, 1, 0), 'NW'): -1.0,
#   ((1, True, 4, 2, 1, 0), 'SE'): -1.0,
#   ((3, True, 4, 2, 1, 0), 'NE'): -1.0,
#   ((4, True, 4, 2, 1, 0), 'NW'): -1.0,
#   ((2, True, 4, 2, 1, 0), 'SE'): -1.0,
#   ((4, True, 4, 2, 1, 0), 'SW'): -1.0,
#   ((3, True, 4, 2, 1, 0), 'SW'): -1.0,
#   ((17, True, 4, 2, 1, 0), 'SW'): -1.1,
#   ((15, True, 4, 2, 1, 0), 'SE'): -1.0,
#   ((12, True, 4, 2, 1, 0), 'NW'): -1.1,
#   ((12, True, 4, 2, 1, 0), 'SE'): -1.0,
#   ((13, True, 4, 2, 1, 0), 'Deliver'): 30.0,
#   ((13, False, 4, 2, 1, 1), 'NW'): -1.098360655737705,
#   ((12, False, 4, 2, 1, 1), 'NW'): -1.098360655737705,
#   ((15, False, 4, 2, 1, 1), 'N'): -1.0967741935483872,
#   ((16, False, 4, 2, 1, 1), 'S'): -1.098360655737705,
#   ((15, False, 4, 2, 1, 1), 'SE'): -1.0,
#   ((12, False, 4, 2, 1, 1), 'SE'): -1.1,
#   ((16, False, 4, 2, 1, 1), 'E'): 1.9508196721311473,
#   ((11, False, 4, 2, 1, 1), 'Pick'): 29.901639344262293,
#   ((11, True, 4, 1, 1, 1), 'W'): -1.0967741935483872,
#   ((16, True, 4, 1, 1, 1), 'S'): -1.0967741935483872,
#   ((15, True, 4, 1, 1, 1), 'N'): -1.098360655737705,
#   ((16, True, 4, 1, 1, 1), 'E'): -1.1,
#   ((16, True, 4, 1, 1, 1), 'NE'): -1.098360655737705,
#   ((17, True, 4, 1, 1, 1), 'NE'): -1.098360655737705,
#   ((3, True, 4, 1, 1, 1), 'NW'): -1.098360655737705,
#   ((1, True, 4, 1, 1, 1), 'SE'): -1.098360655737705,
#   ((3, True, 4, 1, 1, 1), 'NE'): -1.0,
#   ((4, True, 4, 1, 1, 1), 'NW'): -1.0,
#   ((2, True, 4, 1, 1, 1), 'SE'): -1.0,
#   ((4, True, 4, 1, 1, 1), 'SW'): -1.0,
#   ((3, True, 4, 1, 1, 1), 'SW'): -1.0,
#   ((17, True, 4, 1, 1, 1), 'SW'): -1.1,
#   ((15, True, 4, 1, 1, 1), 'SE'): -1.0,
#   ((12, True, 4, 1, 1, 1), 'NW'): -1.1,
#   ((12, True, 4, 1, 1, 1), 'SE'): -1.0,
#   ((13, True, 4, 1, 1, 1), 'Deliver'): 30.0,
#   ((13, False, 4, 1, 1, 2), 'NW'): -1.098360655737705,
#   ((12, False, 4, 1, 1, 2), 'NW'): -1.098360655737705,
#   ((15, False, 4, 1, 1, 2), 'N'): -1.0967741935483872,
#   ((16, False, 4, 1, 1, 2), 'S'): -1.098360655737705,
#   ((15, False, 4, 1, 1, 2), 'SE'): -1.0,
#   ((12, False, 4, 1, 1, 2), 'SE'): -1.1,
#   ((16, False, 4, 1, 1, 2), 'E'): 1.9508196721311473,
#   ((11, False, 4, 1, 1, 2), 'Pick'): 29.901639344262293,
#   ((11, True, 4, 0, 1, 2), 'W'): -1.0967741935483872,
#   ((16, True, 4, 0, 1, 2), 'S'): -1.0967741935483872,
#   ((15, True, 4, 0, 1, 2), 'N'): -1.098360655737705,
#   ((16, True, 4, 0, 1, 2), 'E'): -1.1,
#   ((16, True, 4, 0, 1, 2), 'NE'): -1.098360655737705,
#   ((17, True, 4, 0, 1, 2), 'NE'): -1.098360655737705,
#   ((3, True, 4, 0, 1, 2), 'NW'): -1.098360655737705,
#   ((1, True, 4, 0, 1, 2), 'SE'): -1.098360655737705,
#   ((3, True, 4, 0, 1, 2), 'NE'): -1.0,
#   ((4, True, 4, 0, 1, 2), 'NW'): -1.0,
#   ((2, True, 4, 0, 1, 2), 'SE'): -1.0,
#   ((4, True, 4, 0, 1, 2), 'SW'): -1.0,
#   ((3, True, 4, 0, 1, 2), 'SW'): -1.0,
#   ((17, True, 4, 0, 1, 2), 'SW'): -1.1,
#   ((15, True, 4, 0, 1, 2), 'SE'): -1.0,
#   ((12, True, 4, 0, 1, 2), 'NW'): -1.1,
#   ((12, True, 4, 0, 1, 2), 'SE'): -1.0,
#   ((13, True, 4, 0, 1, 2), 'Deliver'): 30.0,
#   ((13, False, 4, 0, 1, 3), 'NW'): -1.098360655737705,
#   ((12, False, 4, 0, 1, 3), 'NW'): -1.098360655737705,
#   ((15, False, 4, 0, 1, 3), 'N'): -1.0967741935483872,
#   ((16, False, 4, 0, 1, 3), 'S'): -1.098360655737705,
#   ((15, False, 4, 0, 1, 3), 'SE'): -1.0,
#   ((12, False, 4, 0, 1, 3), 'SE'): -1.1,
#   ((16, False, 4, 0, 1, 3), 'E'): -1.098360655737705,
#   ((11, False, 4, 0, 1, 3), 'W'): -1.098360655737705,
#   ((16, False, 4, 0, 1, 3), 'NE'): -1.098360655737705,
#   ((17, False, 4, 0, 1, 3), 'NE'): -1.098360655737705,
#   ((3, False, 4, 0, 1, 3), 'NW'): -1.098360655737705,
#   ((1, False, 4, 0, 1, 3), 'SE'): -1.098360655737705,
#   ((3, False, 4, 0, 1, 3), 'NE'): -1.0967741935483872,
#   ((4, False, 4, 0, 1, 3), 'NW'): -1.098360655737705,
#   ((2, False, 4, 0, 1, 3), 'SE'): -1.098360655737705,
#   ((4, False, 4, 0, 1, 3), 'SW'): -1.098360655737705,
#   ((3, False, 4, 0, 1, 3), 'SW'): -1.0,
#   ((17, False, 4, 0, 1, 3), 'SW'): -1.1,
#   ((4, False, 4, 0, 1, 3), 'NE'): -1.098360655737705,
#   ((5, False, 4, 0, 1, 3), 'NE'): -1.0967741935483872,
#   ((6, False, 4, 0, 1, 3), 'SW'): -1.098360655737705,
#   ((5, False, 4, 0, 1, 3), 'SW'): -1.1,
#   ((6, False, 4, 0, 1, 3), 'S'): -1.098360655737705,
#   ((9, False, 4, 0, 1, 3), 'N'): -1.098360655737705,
#   ((6, False, 4, 0, 1, 3), 'E'): 1.9984135378106822,
#   ((7, False, 4, 0, 1, 3), 'Pick'): 29.903225806451612,
#   ((7, True, 3, 0, 1, 3), 'W'): 1.9508196721311473,
#   ((6, True, 3, 0, 1, 3), 'Deliver'): 29.901639344262293,
#   ((6, False, 3, 0, 2, 3), 'SW'): -1.0967741935483872,
#   ((5, False, 3, 0, 2, 3), 'NE'): -1.0999471179270228,
#   ((6, False, 3, 0, 2, 3), 'S'): -1.098360655737705,
#   ((9, False, 3, 0, 2, 3), 'N'): -1.098360655737705,
#   ((6, False, 3, 0, 2, 3), 'E'): 1.9508196721311473,
#   ((7, False, 3, 0, 2, 3), 'Pick'): 30.0,
#   ((7, True, 2, 0, 2, 3), 'W'): -1.0,
#   ((6, True, 2, 0, 2, 3), 'Deliver'): 30.0,
#   ((6, False, 2, 0, 3, 3), 'SW'): -1.0,
#   ((5, False, 2, 0, 3, 3), 'NE'): -1.0,
#   ((6, False, 2, 0, 3, 3), 'S'): -1.0,
#   ((9, False, 2, 0, 3, 3), 'N'): -1.0,
#   ((6, False, 2, 0, 3, 3), 'E'): -1.0,
#   ((7, False, 2, 0, 3, 3), 'Pick'): 30.0,
#   ((7, True, 1, 0, 3, 3), 'W'): -1.0,
#   ((6, True, 1, 0, 3, 3), 'Deliver'): 30.0,
#   ((6, False, 1, 0, 4, 3), 'SW'): -1.1080354743348562,
#   ((5, False, 1, 0, 4, 3), 'NE'): -1.0999471179270228,
#   ((6, False, 1, 0, 4, 3), 'S'): -1.098360655737705,
#   ((9, False, 1, 0, 4, 3), 'N'): -0.814383923849815,
#   ((6, False, 1, 0, 4, 3), 'E'): 1.9888947646747754,
#   ((7, False, 1, 0, 4, 3), 'Pick'): 29.900052882072977,
#   ((7, True, 0, 0, 4, 3), 'W'): -1.098360655737705,
#   ((6, True, 0, 0, 4, 3), 'E'): -1.0,
#   ((7, True, 0, 0, 4, 3), 'SW'): 1.9508196721311473,
#   ((8, True, 0, 0, 4, 3), 'Deliver'): 34.91803278688525,
#   ((8, False, 0, 0, 4, 4), 'NE'): 50.0,
#   ((5, False, 3, 4, 1, 0), 'SW'): -1.098360655737705,
#   ((4, False, 3, 4, 1, 0), 'NW'): -1.098360655737705,
#   ((2, False, 3, 4, 1, 0), 'SE'): -1.098360655737705,
#   ((4, False, 3, 4, 1, 0), 'SW'): -1.0967741935483872,
#   ((3, False, 3, 4, 1, 0), 'NW'): -1.098360655737705,
#   ((1, False, 3, 4, 1, 0), 'SE'): -1.098360655737705,
#   ((3, False, 3, 4, 1, 0), 'NE'): -1.098360655737705,
#   ((4, False, 3, 4, 1, 0), 'NE'): -1.1,
#   ((3, False, 3, 4, 1, 0), 'SW'): -1.0,
#   ((17, False, 3, 4, 1, 0), 'NE'): -1.1,
#   ((17, False, 3, 4, 1, 0), 'SW'): -1.0,
#   ((16, False, 3, 4, 1, 0), 'S'): -1.0,
#   ((15, False, 3, 4, 1, 0), 'N'): -1.0,
#   ((16, False, 3, 4, 1, 0), 'E'): -1.0,
#   ((11, False, 3, 4, 1, 0), 'Pick'): 30.0,
#   ((11, True, 3, 3, 1, 0), 'W'): -1.0,
#   ((16, True, 3, 3, 1, 0), 'S'): -1.0967741935483872,
#   ((15, True, 3, 3, 1, 0), 'N'): -1.098360655737705,
#   ((16, True, 3, 3, 1, 0), 'E'): -1.1,
#   ((16, True, 3, 3, 1, 0), 'NE'): -1.0,
#   ((17, True, 3, 3, 1, 0), 'NE'): -1.0,
#   ((3, True, 3, 3, 1, 0), 'NW'): -1.0,
#   ((1, True, 3, 3, 1, 0), 'SE'): -1.0,
#   ((3, True, 3, 3, 1, 0), 'NE'): -1.0,
#   ((4, True, 3, 3, 1, 0), 'NW'): -1.0,
#   ((2, True, 3, 3, 1, 0), 'SE'): -1.0,
#   ((4, True, 3, 3, 1, 0), 'SW'): -1.0,
#   ((3, True, 3, 3, 1, 0), 'SW'): -1.0,
#   ((17, True, 3, 3, 1, 0), 'SW'): -1.1,
#   ((15, True, 3, 3, 1, 0), 'SE'): -1.0,
#   ((12, True, 3, 3, 1, 0), 'NW'): -1.1,
#   ((12, True, 3, 3, 1, 0), 'SE'): -1.0,
#   ((13, True, 3, 3, 1, 0), 'Deliver'): 30.0,
#   ((13, False, 3, 3, 1, 1), 'NW'): -1.098360655737705,
#   ((12, False, 3, 3, 1, 1), 'NW'): -1.098360655737705,
#   ((15, False, 3, 3, 1, 1), 'N'): -1.0,
#   ((16, False, 3, 3, 1, 1), 'S'): -1.0,
#   ((15, False, 3, 3, 1, 1), 'SE'): -1.0,
#   ((12, False, 3, 3, 1, 1), 'SE'): -1.1,
#   ((16, False, 3, 3, 1, 1), 'E'): -1.0,
#   ((11, False, 3, 3, 1, 1), 'Pick'): 30.0,
#   ((11, True, 3, 2, 1, 1), 'W'): -1.0,
#   ((16, True, 3, 2, 1, 1), 'S'): -1.0967741935483872,
#   ((15, True, 3, 2, 1, 1), 'N'): -1.098360655737705,
#   ((16, True, 3, 2, 1, 1), 'E'): -1.1,
#   ((16, True, 3, 2, 1, 1), 'NE'): -1.0,
#   ((17, True, 3, 2, 1, 1), 'NE'): -1.0,
#   ((3, True, 3, 2, 1, 1), 'NW'): -1.0,
#   ((1, True, 3, 2, 1, 1), 'SE'): -1.0,
#   ((3, True, 3, 2, 1, 1), 'NE'): -1.0,
#   ((4, True, 3, 2, 1, 1), 'NW'): -1.0,
#   ((2, True, 3, 2, 1, 1), 'SE'): -1.0,
#   ((4, True, 3, 2, 1, 1), 'SW'): -1.0,
#   ((3, True, 3, 2, 1, 1), 'SW'): -1.0,
#   ((17, True, 3, 2, 1, 1), 'SW'): -1.1,
#   ((15, True, 3, 2, 1, 1), 'SE'): -1.0,
#   ((12, True, 3, 2, 1, 1), 'NW'): -1.1,
#   ((12, True, 3, 2, 1, 1), 'SE'): -1.0,
#   ((13, True, 3, 2, 1, 1), 'Deliver'): 30.0,
#   ((13, False, 3, 2, 1, 2), 'NW'): -1.098360655737705,
#   ((12, False, 3, 2, 1, 2), 'NW'): -1.098360655737705,
#   ((15, False, 3, 2, 1, 2), 'N'): -1.0,
# ...
#   ((16, False, 0, 2, 3, 3), 'S'): 1,
#   ((15, False, 0, 2, 3, 3), 'SE'): 1,
#   ((12, False, 0, 2, 3, 3), 'SE'): 1,
#   ((16, False, 0, 2, 3, 3), 'E'): 1,
#   ((11, False, 0, 2, 3, 3), 'Pick'): 1,
#   ((11, True, 0, 1, 3, 3), 'W'): 2,
#   ((16, True, 0, 1, 3, 3), 'S'): 3,
#   ((15, True, 0, 1, 3, 3), 'N'): 2,
#   ((16, True, 0, 1, 3, 3), 'E'): 1,
#   ((16, True, 0, 1, 3, 3), 'NE'): 1,
#   ((17, True, 0, 1, 3, 3), 'NE'): 1,
#   ((3, True, 0, 1, 3, 3), 'NW'): 1,
#   ((1, True, 0, 1, 3, 3), 'SE'): 1,
#   ((3, True, 0, 1, 3, 3), 'NE'): 1,
#   ((4, True, 0, 1, 3, 3), 'NW'): 1,
#   ((2, True, 0, 1, 3, 3), 'SE'): 1,
#   ((4, True, 0, 1, 3, 3), 'SW'): 1,
#   ((3, True, 0, 1, 3, 3), 'SW'): 1,
#   ((17, True, 0, 1, 3, 3), 'SW'): 1,
#   ((15, True, 0, 1, 3, 3), 'SE'): 2,
#   ((12, True, 0, 1, 3, 3), 'NW'): 1,
#   ((12, True, 0, 1, 3, 3), 'SE'): 1,
#   ((13, True, 0, 1, 3, 3), 'Deliver'): 1,
#   ((13, False, 0, 1, 3, 4), 'NW'): 2,
#   ((12, False, 0, 1, 3, 4), 'NW'): 2,
#   ((15, False, 0, 1, 3, 4), 'N'): 3,
#   ((16, False, 0, 1, 3, 4), 'S'): 2,
#   ((15, False, 0, 1, 3, 4), 'SE'): 1,
#   ((12, False, 0, 1, 3, 4), 'SE'): 1,
#   ((16, False, 0, 1, 3, 4), 'E'): 2,
#   ((11, False, 0, 1, 3, 4), 'Pick'): 2,
#   ((11, True, 0, 0, 3, 4), 'W'): 3,
#   ((16, True, 0, 0, 3, 4), 'S'): 4,
#   ((15, True, 0, 0, 3, 4), 'N'): 4,
#   ((16, True, 0, 0, 3, 4), 'E'): 1,
#   ((16, True, 0, 0, 3, 4), 'NE'): 3,
#   ((17, True, 0, 0, 3, 4), 'NE'): 4,
#   ((3, True, 0, 0, 3, 4), 'NW'): 2,
#   ((1, True, 0, 0, 3, 4), 'SE'): 2,
#   ((3, True, 0, 0, 3, 4), 'NE'): 4,
#   ((4, True, 0, 0, 3, 4), 'NW'): 2,
#   ((2, True, 0, 0, 3, 4), 'SE'): 2,
#   ((4, True, 0, 0, 3, 4), 'SW'): 2,
#   ((3, True, 0, 0, 3, 4), 'SW'): 2,
#   ((17, True, 0, 0, 3, 4), 'SW'): 1,
#   ((15, True, 0, 0, 3, 4), 'SE'): 3,
#   ((12, True, 0, 0, 3, 4), 'NW'): 3,
#   ((12, True, 0, 0, 3, 4), 'SE'): 2,
#   ((13, True, 0, 0, 3, 4), 'NW'): 2,
#   ((4, True, 0, 0, 3, 4), 'NE'): 2,
#   ((5, True, 0, 0, 3, 4), 'NE'): 2,
#   ((5, True, 4, 3, 0, 0), 'SW'): 1,
#   ((5, False, 4, 3, 1, 0), 'SW'): 2,
#   ((4, False, 4, 3, 1, 0), 'NW'): 2,
#   ((2, False, 4, 3, 1, 0), 'SE'): 2,
#   ((4, False, 4, 3, 1, 0), 'SW'): 3,
#   ((3, False, 4, 3, 1, 0), 'NW'): 2,
#   ((1, False, 4, 3, 1, 0), 'SE'): 2,
#   ((3, False, 4, 3, 1, 0), 'NE'): 2,
#   ((4, False, 4, 3, 1, 0), 'NE'): 1,
#   ((3, False, 4, 3, 1, 0), 'SW'): 2,
#   ((17, False, 4, 3, 1, 0), 'NE'): 1,
#   ((17, False, 4, 3, 1, 0), 'SW'): 1,
#   ((16, False, 4, 3, 1, 0), 'S'): 1,
#   ((15, False, 4, 3, 1, 0), 'N'): 1,
#   ((16, False, 4, 3, 1, 0), 'E'): 1,
#   ((11, False, 4, 3, 1, 0), 'Pick'): 1,
#   ((11, True, 4, 2, 1, 0), 'W'): 2,
#   ((16, True, 4, 2, 1, 0), 'S'): 3,
#   ((15, True, 4, 2, 1, 0), 'N'): 2,
#   ((16, True, 4, 2, 1, 0), 'E'): 1,
#   ((16, True, 4, 2, 1, 0), 'NE'): 1,
#   ((17, True, 4, 2, 1, 0), 'NE'): 1,
#   ((3, True, 4, 2, 1, 0), 'NW'): 1,
#   ((1, True, 4, 2, 1, 0), 'SE'): 1,
#   ((3, True, 4, 2, 1, 0), 'NE'): 1,
#   ((4, True, 4, 2, 1, 0), 'NW'): 1,
#   ((2, True, 4, 2, 1, 0), 'SE'): 1,
#   ((4, True, 4, 2, 1, 0), 'SW'): 1,
#   ((3, True, 4, 2, 1, 0), 'SW'): 1,
#   ((17, True, 4, 2, 1, 0), 'SW'): 1,
#   ((15, True, 4, 2, 1, 0), 'SE'): 2,
#   ((12, True, 4, 2, 1, 0), 'NW'): 1,
#   ((12, True, 4, 2, 1, 0), 'SE'): 1,
#   ((13, True, 4, 2, 1, 0), 'Deliver'): 1,
#   ((13, False, 4, 2, 1, 1), 'NW'): 2,
#   ((12, False, 4, 2, 1, 1), 'NW'): 2,
#   ((15, False, 4, 2, 1, 1), 'N'): 3,
#   ((16, False, 4, 2, 1, 1), 'S'): 2,
#   ((15, False, 4, 2, 1, 1), 'SE'): 1,
#   ((12, False, 4, 2, 1, 1), 'SE'): 1,
#   ((16, False, 4, 2, 1, 1), 'E'): 2,
#   ((11, False, 4, 2, 1, 1), 'Pick'): 2,
#   ((11, True, 4, 1, 1, 1), 'W'): 3,
#   ((16, True, 4, 1, 1, 1), 'S'): 3,
#   ((15, True, 4, 1, 1, 1), 'N'): 2,
#   ((16, True, 4, 1, 1, 1), 'E'): 1,
#   ((16, True, 4, 1, 1, 1), 'NE'): 2,
#   ((17, True, 4, 1, 1, 1), 'NE'): 2,
#   ((3, True, 4, 1, 1, 1), 'NW'): 2,
#   ((1, True, 4, 1, 1, 1), 'SE'): 2,
#   ((3, True, 4, 1, 1, 1), 'NE'): 2,
#   ((4, True, 4, 1, 1, 1), 'NW'): 1,
#   ((2, True, 4, 1, 1, 1), 'SE'): 1,
#   ((4, True, 4, 1, 1, 1), 'SW'): 1,
#   ((3, True, 4, 1, 1, 1), 'SW'): 1,
#   ((17, True, 4, 1, 1, 1), 'SW'): 1,
#   ((15, True, 4, 1, 1, 1), 'SE'): 2,
#   ((12, True, 4, 1, 1, 1), 'NW'): 1,
#   ((12, True, 4, 1, 1, 1), 'SE'): 1,
#   ((13, True, 4, 1, 1, 1), 'Deliver'): 1,
#   ((13, False, 4, 1, 1, 2), 'NW'): 2,
#   ((12, False, 4, 1, 1, 2), 'NW'): 2,
#   ((15, False, 4, 1, 1, 2), 'N'): 3,
#   ((16, False, 4, 1, 1, 2), 'S'): 2,
#   ((15, False, 4, 1, 1, 2), 'SE'): 1,
#   ((12, False, 4, 1, 1, 2), 'SE'): 1,
#   ((16, False, 4, 1, 1, 2), 'E'): 2,
#   ((11, False, 4, 1, 1, 2), 'Pick'): 2,
#   ((11, True, 4, 0, 1, 2), 'W'): 3,
#   ((16, True, 4, 0, 1, 2), 'S'): 3,
#   ((15, True, 4, 0, 1, 2), 'N'): 2,
#   ((16, True, 4, 0, 1, 2), 'E'): 1,
#   ((16, True, 4, 0, 1, 2), 'NE'): 2,
#   ((17, True, 4, 0, 1, 2), 'NE'): 2,
#   ((3, True, 4, 0, 1, 2), 'NW'): 2,
#   ((1, True, 4, 0, 1, 2), 'SE'): 2,
#   ((3, True, 4, 0, 1, 2), 'NE'): 2,
#   ((4, True, 4, 0, 1, 2), 'NW'): 1,
#   ((2, True, 4, 0, 1, 2), 'SE'): 1,
#   ((4, True, 4, 0, 1, 2), 'SW'): 1,
#   ((3, True, 4, 0, 1, 2), 'SW'): 1,
#   ((17, True, 4, 0, 1, 2), 'SW'): 1,
#   ((15, True, 4, 0, 1, 2), 'SE'): 2,
#   ((12, True, 4, 0, 1, 2), 'NW'): 1,
#   ((12, True, 4, 0, 1, 2), 'SE'): 1,
#   ((13, True, 4, 0, 1, 2), 'Deliver'): 1,
#   ((13, False, 4, 0, 1, 3), 'NW'): 2,
#   ((12, False, 4, 0, 1, 3), 'NW'): 2,
#   ((15, False, 4, 0, 1, 3), 'N'): 3,
#   ((16, False, 4, 0, 1, 3), 'S'): 2,
#   ((15, False, 4, 0, 1, 3), 'SE'): 1,
#   ((12, False, 4, 0, 1, 3), 'SE'): 1,
#   ((16, False, 4, 0, 1, 3), 'E'): 2,
#   ((11, False, 4, 0, 1, 3), 'W'): 2,
#   ((16, False, 4, 0, 1, 3), 'NE'): 2,
#   ((17, False, 4, 0, 1, 3), 'NE'): 2,
#   ((3, False, 4, 0, 1, 3), 'NW'): 2,
#   ((1, False, 4, 0, 1, 3), 'SE'): 2,
#   ((3, False, 4, 0, 1, 3), 'NE'): 3,
#   ((4, False, 4, 0, 1, 3), 'NW'): 2,
#   ((2, False, 4, 0, 1, 3), 'SE'): 2,
#   ((4, False, 4, 0, 1, 3), 'SW'): 2,
#   ((3, False, 4, 0, 1, 3), 'SW'): 1,
#   ((17, False, 4, 0, 1, 3), 'SW'): 1,
#   ((4, False, 4, 0, 1, 3), 'NE'): 2,
#   ((5, False, 4, 0, 1, 3), 'NE'): 3,
#   ((6, False, 4, 0, 1, 3), 'SW'): 2,
#   ((5, False, 4, 0, 1, 3), 'SW'): 1,
#   ((6, False, 4, 0, 1, 3), 'S'): 2,
#   ((9, False, 4, 0, 1, 3), 'N'): 2,
#   ((6, False, 4, 0, 1, 3), 'E'): 3,
#   ((7, False, 4, 0, 1, 3), 'Pick'): 3,
#   ((7, True, 3, 0, 1, 3), 'W'): 2,
#   ((6, True, 3, 0, 1, 3), 'Deliver'): 2,
#   ((6, False, 3, 0, 2, 3), 'SW'): 3,
#   ((5, False, 3, 0, 2, 3), 'NE'): 3,
#   ((6, False, 3, 0, 2, 3), 'S'): 2,
#   ((9, False, 3, 0, 2, 3), 'N'): 2,
#   ((6, False, 3, 0, 2, 3), 'E'): 2,
#   ((7, False, 3, 0, 2, 3), 'Pick'): 2,
#   ((7, True, 2, 0, 2, 3), 'W'): 1,
#   ((6, True, 2, 0, 2, 3), 'Deliver'): 1,
#   ((6, False, 2, 0, 3, 3), 'SW'): 1,
#   ((5, False, 2, 0, 3, 3), 'NE'): 1,
#   ((6, False, 2, 0, 3, 3), 'S'): 1,
#   ((9, False, 2, 0, 3, 3), 'N'): 1,
#   ((6, False, 2, 0, 3, 3), 'E'): 1,
#   ((7, False, 2, 0, 3, 3), 'Pick'): 1,
#   ((7, True, 1, 0, 3, 3), 'W'): 1,
#   ((6, True, 1, 0, 3, 3), 'Deliver'): 1,
#   ((6, False, 1, 0, 4, 3), 'SW'): 2,
#   ((5, False, 1, 0, 4, 3), 'NE'): 3,
#   ((6, False, 1, 0, 4, 3), 'S'): 2,
#   ((9, False, 1, 0, 4, 3), 'N'): 3,
#   ((6, False, 1, 0, 4, 3), 'E'): 3,
#   ((7, False, 1, 0, 4, 3), 'Pick'): 3,
#   ((7, True, 0, 0, 4, 3), 'W'): 2,
#   ((6, True, 0, 0, 4, 3), 'E'): 1,
#   ((7, True, 0, 0, 4, 3), 'SW'): 2,
#   ((8, True, 0, 0, 4, 3), 'Deliver'): 2,
#   ((8, False, 0, 0, 4, 4), 'NE'): 2,
#   ((5, False, 3, 4, 1, 0), 'SW'): 2,
#   ((4, False, 3, 4, 1, 0), 'NW'): 2,
#   ((2, False, 3, 4, 1, 0), 'SE'): 2,
#   ((4, False, 3, 4, 1, 0), 'SW'): 3,
#   ((3, False, 3, 4, 1, 0), 'NW'): 2,
#   ((1, False, 3, 4, 1, 0), 'SE'): 2,
#   ((3, False, 3, 4, 1, 0), 'NE'): 2,
#   ((4, False, 3, 4, 1, 0), 'NE'): 1,
#   ((3, False, 3, 4, 1, 0), 'SW'): 2,
#   ((17, False, 3, 4, 1, 0), 'NE'): 1,
#   ((17, False, 3, 4, 1, 0), 'SW'): 1,
#   ((16, False, 3, 4, 1, 0), 'S'): 1,
#   ((15, False, 3, 4, 1, 0), 'N'): 1,
#   ((16, False, 3, 4, 1, 0), 'E'): 1,
#   ((11, False, 3, 4, 1, 0), 'Pick'): 1,
#   ((11, True, 3, 3, 1, 0), 'W'): 2,
#   ((16, True, 3, 3, 1, 0), 'S'): 3,
#   ((15, True, 3, 3, 1, 0), 'N'): 2,
#   ((16, True, 3, 3, 1, 0), 'E'): 1,
#   ((16, True, 3, 3, 1, 0), 'NE'): 1,
#   ((17, True, 3, 3, 1, 0), 'NE'): 1,
#   ((3, True, 3, 3, 1, 0), 'NW'): 1,
#   ((1, True, 3, 3, 1, 0), 'SE'): 1,
#   ((3, True, 3, 3, 1, 0), 'NE'): 1,
#   ((4, True, 3, 3, 1, 0), 'NW'): 1,
#   ((2, True, 3, 3, 1, 0), 'SE'): 1,
#   ((4, True, 3, 3, 1, 0), 'SW'): 1,
#   ((3, True, 3, 3, 1, 0), 'SW'): 1,
#   ((17, True, 3, 3, 1, 0), 'SW'): 1,
#   ((15, True, 3, 3, 1, 0), 'SE'): 2,
#   ((12, True, 3, 3, 1, 0), 'NW'): 1,
#   ((12, True, 3, 3, 1, 0), 'SE'): 1,
#   ((13, True, 3, 3, 1, 0), 'Deliver'): 1,
#   ((13, False, 3, 3, 1, 1), 'NW'): 2,
#   ((12, False, 3, 3, 1, 1), 'NW'): 2,
#   ((15, False, 3, 3, 1, 1), 'N'): 2,
#   ((16, False, 3, 3, 1, 1), 'S'): 1,
#   ((15, False, 3, 3, 1, 1), 'SE'): 1,
#   ((12, False, 3, 3, 1, 1), 'SE'): 1,
#   ((16, False, 3, 3, 1, 1), 'E'): 1,
#   ((11, False, 3, 3, 1, 1), 'Pick'): 1,
#   ((11, True, 3, 2, 1, 1), 'W'): 2,
#   ((16, True, 3, 2, 1, 1), 'S'): 3,
#   ((15, True, 3, 2, 1, 1), 'N'): 2,
#   ((16, True, 3, 2, 1, 1), 'E'): 1,
#   ((16, True, 3, 2, 1, 1), 'NE'): 1,
#   ((17, True, 3, 2, 1, 1), 'NE'): 1,
#   ((3, True, 3, 2, 1, 1), 'NW'): 1,
#   ((1, True, 3, 2, 1, 1), 'SE'): 1,
#   ((3, True, 3, 2, 1, 1), 'NE'): 1,
#   ((4, True, 3, 2, 1, 1), 'NW'): 1,
#   ((2, True, 3, 2, 1, 1), 'SE'): 1,
#   ((4, True, 3, 2, 1, 1), 'SW'): 1,
#   ((3, True, 3, 2, 1, 1), 'SW'): 1,
#   ((17, True, 3, 2, 1, 1), 'SW'): 1,
#   ((15, True, 3, 2, 1, 1), 'SE'): 2,
#   ((12, True, 3, 2, 1, 1), 'NW'): 1,
#   ((12, True, 3, 2, 1, 1), 'SE'): 1,
#   ((13, True, 3, 2, 1, 1), 'Deliver'): 1,
#   ((13, False, 3, 2, 1, 2), 'NW'): 2,
#   ((12, False, 3, 2, 1, 2), 'NW'): 2,
#   ((15, False, 3, 2, 1, 2), 'N'): 2,
#   ((16, False, 3, 2, 1, 2), 'S'): 1,
#   ((15, False, 3, 2, 1, 2), 'SE'): 1,
#   ((12, False, 3, 2, 1, 2), 'SE'): 1,
#   ((16, False, 3, 2, 1, 2), 'E'): 1,
#   ((11, False, 3, 2, 1, 2), 'Pick'): 1,
#   ((11, True, 3, 1, 1, 2), 'W'): 2,
#   ((16, True, 3, 1, 1, 2), 'S'): 3,
#   ((15, True, 3, 1, 1, 2), 'N'): 2,
#   ((16, True, 3, 1, 1, 2), 'E'): 1,
#   ((16, True, 3, 1, 1, 2), 'NE'): 1,
#   ((17, True, 3, 1, 1, 2), 'NE'): 1,
#   ((3, True, 3, 1, 1, 2), 'NW'): 1,
#   ((1, True, 3, 1, 1, 2), 'SE'): 1,
#   ((3, True, 3, 1, 1, 2), 'NE'): 1,
#   ((4, True, 3, 1, 1, 2), 'NW'): 1,
#   ((2, True, 3, 1, 1, 2), 'SE'): 1,
#   ((4, True, 3, 1, 1, 2), 'SW'): 1,
#   ((3, True, 3, 1, 1, 2), 'SW'): 1,
#   ((17, True, 3, 1, 1, 2), 'SW'): 1,
#   ((15, True, 3, 1, 1, 2), 'SE'): 2,
#   ((12, True, 3, 1, 1, 2), 'NW'): 1,
#   ((12, True, 3, 1, 1, 2), 'SE'): 1,
#   ((13, True, 3, 1, 1, 2), 'Deliver'): 1,
#   ((13, False, 3, 1, 1, 3), 'NW'): 2,
#   ((12, False, 3, 1, 1, 3), 'NW'): 2,
#   ((15, False, 3, 1, 1, 3), 'N'): 2,
#   ((16, False, 3, 1, 1, 3), 'S'): 1,
#   ((15, False, 3, 1, 1, 3), 'SE'): 1,
#   ((12, False, 3, 1, 1, 3), 'SE'): 1,
#   ((16, False, 3, 1, 1, 3), 'E'): 1,
#   ((11, False, 3, 1, 1, 3), 'Pick'): 1,
#   ((11, True, 3, 0, 1, 3), 'W'): 2,
#   ((16, True, 3, 0, 1, 3), 'S'): 3,
#   ((15, True, 3, 0, 1, 3), 'N'): 2,
#   ((16, True, 3, 0, 1, 3), 'E'): 1,
#   ((16, True, 3, 0, 1, 3), 'NE'): 1,
#   ((17, True, 3, 0, 1, 3), 'NE'): 1,
#   ((3, True, 3, 0, 1, 3), 'NW'): 1,
#   ((1, True, 3, 0, 1, 3), 'SE'): 1,
#   ((3, True, 3, 0, 1, 3), 'NE'): 1,
#   ((4, True, 3, 0, 1, 3), 'NW'): 1,
#   ((2, True, 3, 0, 1, 3), 'SE'): 1,
#   ((4, True, 3, 0, 1, 3), 'SW'): 1,
#   ((3, True, 3, 0, 1, 3), 'SW'): 1,
#   ((17, True, 3, 0, 1, 3), 'SW'): 1,
#   ((15, True, 3, 0, 1, 3), 'SE'): 2,
#   ((12, True, 3, 0, 1, 3), 'NW'): 1,
#   ((12, True, 3, 0, 1, 3), 'SE'): 1,
#   ((13, True, 3, 0, 1, 3), 'Deliver'): 1,
#   ((13, False, 3, 0, 1, 4), 'NW'): 2,
#   ((12, False, 3, 0, 1, 4), 'NW'): 2,
#   ((15, False, 3, 0, 1, 4), 'N'): 3,
#   ((16, False, 3, 0, 1, 4), 'S'): 2,
#   ((15, False, 3, 0, 1, 4), 'SE'): 1,
#   ((12, False, 3, 0, 1, 4), 'SE'): 1,
#   ((16, False, 3, 0, 1, 4), 'E'): 2,
#   ((11, False, 3, 0, 1, 4), 'W'): 2,
#   ((16, False, 3, 0, 1, 4), 'NE'): 2,
#   ((17, False, 3, 0, 1, 4), 'NE'): 2,
#   ((3, False, 3, 0, 1, 4), 'NW'): 2,
#   ((1, False, 3, 0, 1, 4), 'SE'): 2,
#   ((3, False, 3, 0, 1, 4), 'NE'): 3,
#   ((4, False, 3, 0, 1, 4), 'NW'): 2,
#   ((2, False, 3, 0, 1, 4), 'SE'): 2,
#   ((4, False, 3, 0, 1, 4), 'SW'): 2,
#   ((3, False, 3, 0, 1, 4), 'SW'): 1,
#   ((17, False, 3, 0, 1, 4), 'SW'): 1,
#   ((4, False, 3, 0, 1, 4), 'NE'): 2,
#   ((5, False, 3, 0, 1, 4), 'SW'): 1,
#   ((7, True, 2, 0, 1, 4), 'SW'): 1,
#   ((8, True, 2, 0, 1, 4), 'NE'): 1,
#   ((5, False, 2, 0, 2, 4), 'SW'): 3,
#   ((4, False, 2, 0, 2, 4), 'NW'): 4,
#   ((2, False, 2, 0, 2, 4), 'SE'): 4,
#   ((4, False, 2, 0, 2, 4), 'SW'): 4,
#   ((3, False, 2, 0, 2, 4), 'NW'): 4,
#   ((1, False, 2, 0, 2, 4), 'SE'): 4,
#   ((3, False, 2, 0, 2, 4), 'NE'): 5,
#   ((4, False, 2, 0, 2, 4), 'NE'): 4,
#   ((3, False, 2, 0, 2, 4), 'SW'): 4,
#   ((17, False, 2, 0, 2, 4), 'NE'): 5,
#   ((17, False, 2, 0, 2, 4), 'SW'): 4,
#   ((16, False, 2, 0, 2, 4), 'S'): 6,
#   ((15, False, 2, 0, 2, 4), 'N'): 7,
#   ((16, False, 2, 0, 2, 4), 'E'): 5,
#   ((11, False, 2, 0, 2, 4), 'W'): 5,
#   ((16, False, 2, 0, 2, 4), 'NE'): 5,
#   ((15, False, 2, 0, 2, 4), 'SE'): 5,
#   ((12, False, 2, 0, 2, 4), 'NW'): 6,
#   ((12, False, 2, 0, 2, 4), 'SE'): 4,
#   ((13, False, 2, 0, 2, 4), 'NW'): 5,
#   ((7, True, 1, 0, 2, 4), 'SW'): 1,
#   ((8, True, 1, 0, 2, 4), 'NE'): 1,
#   ((5, False, 1, 0, 3, 4), 'SW'): 3,
#   ((4, False, 1, 0, 3, 4), 'NW'): 4,
#   ((2, False, 1, 0, 3, 4), 'SE'): 4,
#   ((4, False, 1, 0, 3, 4), 'SW'): 4,
#   ((3, False, 1, 0, 3, 4), 'NW'): 4,
#   ((1, False, 1, 0, 3, 4), 'SE'): 4,
#   ((3, False, 1, 0, 3, 4), 'NE'): 5,
#   ((4, False, 1, 0, 3, 4), 'NE'): 4,
#   ((3, False, 1, 0, 3, 4), 'SW'): 4,
#   ((17, False, 1, 0, 3, 4), 'NE'): 5,
#   ((17, False, 1, 0, 3, 4), 'SW'): 4,
#   ((16, False, 1, 0, 3, 4), 'S'): 6,
#   ((15, False, 1, 0, 3, 4), 'N'): 7,
#   ((16, False, 1, 0, 3, 4), 'E'): 5,
#   ((11, False, 1, 0, 3, 4), 'W'): 5,
#   ((16, False, 1, 0, 3, 4), 'NE'): 5,
#   ((15, False, 1, 0, 3, 4), 'SE'): 5,
#   ((12, False, 1, 0, 3, 4), 'NW'): 6,
#   ((12, False, 1, 0, 3, 4), 'SE'): 4,
#   ((13, False, 1, 0, 3, 4), 'NW'): 5,
#   ((7, True, 0, 0, 3, 4), 'SW'): 1,
#   ((8, True, 0, 0, 3, 4), 'NE'): 1,
#   ((16, False, 4, 2, 0, 2), 'NE'): 1,
#   ((17, False, 4, 2, 0, 2), 'NE'): 1,
#   ((3, False, 4, 2, 0, 2), 'NW'): 1,
#   ((1, False, 4, 2, 0, 2), 'SE'): 1,
#   ((3, False, 4, 2, 0, 2), 'NE'): 1,
#   ((4, False, 4, 2, 0, 2), 'NW'): 1,
#   ((2, False, 4, 2, 0, 2), 'SE'): 1,
#   ((4, False, 4, 2, 0, 2), 'SW'): 1,
#   ((3, False, 4, 2, 0, 2), 'SW'): 1,
#   ((17, False, 4, 2, 0, 2), 'SW'): 1,
#   ((4, True, 4, 1, 0, 2), 'NE'): 3,
#   ((5, True, 4, 1, 0, 2), 'NE'): 2,
#   ((6, True, 4, 1, 0, 2), 'Deliver'): 2,
#   ((6, False, 4, 1, 1, 2), 'SW'): 3,
#   ((5, False, 4, 1, 1, 2), 'NE'): 2,
#   ((6, False, 4, 1, 1, 2), 'S'): 1,
#   ((9, False, 4, 1, 1, 2), 'N'): 1,
#   ((6, False, 4, 1, 1, 2), 'E'): 1,
#   ((7, False, 4, 1, 1, 2), 'Pick'): 1,
#   ((7, True, 3, 1, 1, 2), 'W'): 1,
#   ((6, True, 3, 1, 1, 2), 'Deliver'): 1,
#   ((6, False, 3, 1, 2, 2), 'SW'): 1,
#   ((5, False, 3, 1, 2, 2), 'NE'): 1,
#   ((6, False, 3, 1, 2, 2), 'S'): 1,
#   ((9, False, 3, 1, 2, 2), 'N'): 1,
#   ((6, False, 3, 1, 2, 2), 'E'): 1,
#   ((7, False, 3, 1, 2, 2), 'Pick'): 1,
#   ((7, True, 2, 1, 2, 2), 'W'): 1,
#   ((6, True, 2, 1, 2, 2), 'Deliver'): 1,
#   ((6, False, 2, 1, 3, 2), 'SW'): 1,
#   ((5, False, 2, 1, 3, 2), 'NE'): 1,
#   ((6, False, 2, 1, 3, 2), 'S'): 1,
#   ((9, False, 2, 1, 3, 2), 'N'): 1,
#   ((6, False, 2, 1, 3, 2), 'E'): 1,
#   ((7, False, 2, 1, 3, 2), 'Pick'): 1,
#   ((7, True, 1, 1, 3, 2), 'W'): 1,
#   ((6, True, 1, 1, 3, 2), 'Deliver'): 1,
#   ((6, False, 1, 1, 4, 2), 'SW'): 3,
#   ((5, False, 1, 1, 4, 2), 'NE'): 2,
#   ((6, False, 1, 1, 4, 2), 'S'): 1,
#   ((9, False, 1, 1, 4, 2), 'N'): 2,
#   ((6, False, 1, 1, 4, 2), 'E'): 1,
#   ((7, False, 1, 1, 4, 2), 'Pick'): 1,
#   ((7, True, 0, 1, 4, 2), 'W'): 1,
#   ((6, True, 0, 1, 4, 2), 'E'): 1,
#   ((7, True, 0, 1, 4, 2), 'SW'): 1,
#   ((8, True, 0, 1, 4, 2), 'Deliver'): 1,
#   ((8, False, 0, 1, 4, 3), 'NE'): 3,
#   ((7, False, 0, 1, 4, 3), 'SW'): 2,
#   ((5, True, 4, 2, 0, 1), 'SW'): 1,
#   ((5, False, 4, 2, 1, 1), 'SW'): 2,
#   ((4, False, 4, 2, 1, 1), 'NW'): 2,
#   ((2, False, 4, 2, 1, 1), 'SE'): 2,
#   ((4, False, 4, 2, 1, 1), 'SW'): 3,
#   ((3, False, 4, 2, 1, 1), 'NW'): 2,
#   ((1, False, 4, 2, 1, 1), 'SE'): 2,
#   ((3, False, 4, 2, 1, 1), 'NE'): 2,
#   ((4, False, 4, 2, 1, 1), 'NE'): 1,
#   ((3, False, 4, 2, 1, 1), 'SW'): 2,
#   ((17, False, 4, 2, 1, 1), 'NE'): 1,
#   ((17, False, 4, 2, 1, 1), 'SW'): 2,
#   ((16, False, 4, 2, 1, 1), 'NE'): 1,
#   ...})

# %% [markdown]
# #Exploring Q-Learning

# %%
q, n = {}, {}
simulate(lambda: ZCRobot(50,0.1,30,3000), duration=60, q=q, n=n, f=lambda q, n: 1/(n+1))
simulate(lambda: ZCRobot(50,0.1,30,3000), n_iterations=1, q=q, n=n, verbose=True, f=lambda q, n: q)
# Out:
# Frontier at step 1
#
# (1, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 2
#
# (3, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 3
#
# (17, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 4
#
# (16, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 5
#
# (11, False, 4, 4, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 6
#
# (11, True, 4, 3, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 7
#
# (16, True, 4, 3, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 8
#
# (15, True, 4, 3, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 9
#
# (12, True, 4, 3, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 10
#
# (13, True, 4, 3, 0, 0)
# --------------------------------------------------------------------------------
# Frontier at step 11
#
# (13, False, 4, 3, 0, 1)
# --------------------------------------------------------------------------------
# Frontier at step 12
#
# (12, False, 4, 3, 0, 1)
# --------------------------------------------------------------------------------
# Frontier at step 13
#
# (15, False, 4, 3, 0, 1)
# --------------------------------------------------------------------------------
# Frontier at step 14
#
# (16, False, 4, 3, 0, 1)
# --------------------------------------------------------------------------------
# Frontier at step 15
#
# (11, False, 4, 3, 0, 1)
# --------------------------------------------------------------------------------
# Frontier at step 16
#
# (11, True, 4, 2, 0, 1)
# --------------------------------------------------------------------------------
# Frontier at step 17
#
# (16, True, 4, 2, 0, 1)
# --------------------------------------------------------------------------------
# Frontier at step 18
#
# (15, True, 4, 2, 0, 1)
# --------------------------------------------------------------------------------
# Frontier at step 19
#
# (12, True, 4, 2, 0, 1)
# --------------------------------------------------------------------------------
# Frontier at step 20
#
# (13, True, 4, 2, 0, 1)
# --------------------------------------------------------------------------------
# Frontier at step 21
#
# (13, False, 4, 2, 0, 2)
# --------------------------------------------------------------------------------
# Frontier at step 22
#
# (12, False, 4, 2, 0, 2)
# --------------------------------------------------------------------------------
# Frontier at step 23
#
# (15, False, 4, 2, 0, 2)
# --------------------------------------------------------------------------------
# Frontier at step 24
#
# (16, False, 4, 2, 0, 2)
# --------------------------------------------------------------------------------
# Frontier at step 25
#
# (11, False, 4, 2, 0, 2)
# --------------------------------------------------------------------------------
# Frontier at step 26
#
# (11, True, 4, 1, 0, 2)
# --------------------------------------------------------------------------------
# Frontier at step 27
#
# (16, True, 4, 1, 0, 2)
# --------------------------------------------------------------------------------
# Frontier at step 28
#
# (15, True, 4, 1, 0, 2)
# --------------------------------------------------------------------------------
# Frontier at step 29
#
# (12, True, 4, 1, 0, 2)
# --------------------------------------------------------------------------------
# Frontier at step 30
#
# (13, True, 4, 1, 0, 2)
# --------------------------------------------------------------------------------
# Frontier at step 31
#
# (13, False, 4, 1, 0, 3)
# --------------------------------------------------------------------------------
# Frontier at step 32
#
# (12, False, 4, 1, 0, 3)
# --------------------------------------------------------------------------------
# Frontier at step 33
#
# (15, False, 4, 1, 0, 3)
# --------------------------------------------------------------------------------
# Frontier at step 34
#
# (16, False, 4, 1, 0, 3)
# --------------------------------------------------------------------------------
# Frontier at step 35
#
# (11, False, 4, 1, 0, 3)
# --------------------------------------------------------------------------------
# Frontier at step 36
#
# (11, True, 4, 0, 0, 3)
# --------------------------------------------------------------------------------
# Frontier at step 37
#
# (16, True, 4, 0, 0, 3)
# --------------------------------------------------------------------------------
# Frontier at step 38
#
# (15, True, 4, 0, 0, 3)
# --------------------------------------------------------------------------------
# Frontier at step 39
#
# (12, True, 4, 0, 0, 3)
# --------------------------------------------------------------------------------
# Frontier at step 40
#
# (13, True, 4, 0, 0, 3)
# --------------------------------------------------------------------------------
# Frontier at step 41
#
# (13, False, 4, 0, 0, 4)
# --------------------------------------------------------------------------------
# Frontier at step 42
#
# (12, False, 4, 0, 0, 4)
# --------------------------------------------------------------------------------
# Frontier at step 43
#
# (15, False, 4, 0, 0, 4)
# --------------------------------------------------------------------------------
# Frontier at step 44
#
# (16, False, 4, 0, 0, 4)
# --------------------------------------------------------------------------------
# Frontier at step 45
#
# (17, False, 4, 0, 0, 4)
# --------------------------------------------------------------------------------
# Frontier at step 46
#
# (3, False, 4, 0, 0, 4)
# --------------------------------------------------------------------------------
# Frontier at step 47
#
# (4, False, 4, 0, 0, 4)
# --------------------------------------------------------------------------------
# Frontier at step 48
#
# (5, False, 4, 0, 0, 4)
# --------------------------------------------------------------------------------
# Frontier at step 49
#
# (6, False, 4, 0, 0, 4)
# --------------------------------------------------------------------------------
# Frontier at step 50
#
# (7, False, 4, 0, 0, 4)
# --------------------------------------------------------------------------------
# Frontier at step 51
#
# (7, True, 3, 0, 0, 4)
# --------------------------------------------------------------------------------
# Frontier at step 52
#
# (6, True, 3, 0, 0, 4)
# --------------------------------------------------------------------------------
# Frontier at step 53
#
# (6, False, 3, 0, 1, 4)
# --------------------------------------------------------------------------------
# Frontier at step 54
#
# (7, False, 3, 0, 1, 4)
# --------------------------------------------------------------------------------
# Frontier at step 55
#
# (7, True, 2, 0, 1, 4)
# --------------------------------------------------------------------------------
# Frontier at step 56
#
# (6, True, 2, 0, 1, 4)
# --------------------------------------------------------------------------------
# Frontier at step 57
#
# (6, False, 2, 0, 2, 4)
# --------------------------------------------------------------------------------
# Frontier at step 58
#
# (7, False, 2, 0, 2, 4)
# --------------------------------------------------------------------------------
# Frontier at step 59
#
# (7, True, 1, 0, 2, 4)
# --------------------------------------------------------------------------------
# Frontier at step 60
#
# (6, True, 1, 0, 2, 4)
# --------------------------------------------------------------------------------
# Frontier at step 61
#
# (6, False, 1, 0, 3, 4)
# --------------------------------------------------------------------------------
# Frontier at step 62
#
# (7, False, 1, 0, 3, 4)
# --------------------------------------------------------------------------------
# Frontier at step 63
#
# (7, True, 0, 0, 3, 4)
# --------------------------------------------------------------------------------
# Frontier at step 64
#
# (6, True, 0, 0, 3, 4)
# --------------------------------------------------------------------------------
# Frontier at step 65
#
# (6, False, 0, 0, 4, 4)
# --------------------------------------------------------------------------------
# ({((1, False, 4, 4, 0, 0), 'SE'): -1.1080110801108014,
#   ((3, False, 4, 4, 0, 0), 'NW'): -1.1108011080110805,
#   ((3, False, 4, 4, 0, 0), 'NE'): -1.1079797979797985,
#   ((4, False, 4, 4, 0, 0), 'NW'): -1.1107979797979801,
#   ((2, False, 4, 4, 0, 0), 'SE'): -1.1079797979797985,
#   ((4, False, 4, 4, 0, 0), 'SW'): -1.1080110801108014,
#   ((3, False, 4, 4, 0, 0), 'SW'): -1.0801108011080114,
#   ((17, False, 4, 4, 0, 0), 'NE'): -1.1080110801108012,
#   ((4, False, 4, 4, 0, 0), 'NE'): -1.0797979797979802,
#   ((5, False, 4, 4, 0, 0), 'NE'): -0.7979797979797982,
#   ((6, False, 4, 4, 0, 0), 'SW'): -1.07979797979798,
#   ((5, False, 4, 4, 0, 0), 'SW'): -1.1079797979797983,
#   ((17, False, 4, 4, 0, 0), 'SW'): -0.8011080110801109,
#   ((16, False, 4, 4, 0, 0), 'S'): -1.0801108011080112,
#   ((15, False, 4, 4, 0, 0), 'N'): -0.8011080110801108,
#   ((16, False, 4, 4, 0, 0), 'E'): 1.988919889198892,
#   ((11, False, 4, 4, 0, 0), 'Pick'): 29.88919889198892,
#   ((11, True, 4, 3, 0, 0), 'W'): -1.1080110801108014,
#   ((16, True, 4, 3, 0, 0), 'S'): -1.0801108011080114,
#   ((15, True, 4, 3, 0, 0), 'N'): -1.1080110801108012,
#   ((16, True, 4, 3, 0, 0), 'E'): -1.1108011080110805,
#   ((16, True, 4, 3, 0, 0), 'NE'): -1.1107979797979803,
#   ((17, True, 4, 3, 0, 0), 'NE'): -1.1079797979797985,
#   ((3, True, 4, 3, 0, 0), 'NW'): -1.1107979797979801,
#   ((1, True, 4, 3, 0, 0), 'SE'): -1.1079797979797983,
#   ((3, True, 4, 3, 0, 0), 'NE'): -1.07979797979798,
#   ((4, True, 4, 3, 0, 0), 'NW'): -1.1079797979797983,
#   ((2, True, 4, 3, 0, 0), 'SE'): -1.07979797979798,
#   ((4, True, 4, 3, 0, 0), 'SW'): -1.1079797979797983,
#   ((3, True, 4, 3, 0, 0), 'SW'): -1.1107979797979801,
#   ((17, True, 4, 3, 0, 0), 'SW'): -1.1080110801108012,
#   ((15, True, 4, 3, 0, 0), 'SE'): -0.8011080110801108,
#   ((12, True, 4, 3, 0, 0), 'NW'): -1.0801108011080112,
#   ((4, True, 4, 3, 0, 0), 'NE'): -0.7979797979797981,
#   ((5, True, 4, 3, 0, 0), 'NE'): 2.0202020202020203,
#   ((6, True, 4, 3, 0, 0), 'Deliver'): 30.2020202020202,
#   ((6, False, 4, 3, 1, 0), 'SW'): -1.0797979797979798,
#   ((5, False, 4, 3, 1, 0), 'NE'): -0.797979797979798,
#   ((6, False, 4, 3, 1, 0), 'S'): -1.0797979797979798,
#   ((9, False, 4, 3, 1, 0), 'N'): -0.797979797979798,
#   ((6, False, 4, 3, 1, 0), 'E'): 2.02020202020202,
#   ((7, False, 4, 3, 1, 0), 'Pick'): 30.202020202020197,
#   ((7, True, 3, 3, 1, 0), 'W'): 2.020202020201989,
#   ((6, True, 3, 3, 1, 0), 'Deliver'): 30.202020202019888,
#   ((6, False, 3, 3, 2, 0), 'SW'): -1.079797979798011,
#   ((5, False, 3, 3, 2, 0), 'NE'): -0.7979797979801111,
#   ((6, False, 3, 3, 2, 0), 'S'): -1.079797979798011,
#   ((9, False, 3, 3, 2, 0), 'N'): -0.7979797979801111,
#   ((6, False, 3, 3, 2, 0), 'E'): 2.020202020198889,
#   ((7, False, 3, 3, 2, 0), 'Pick'): 30.20202020198889,
#   ((7, True, 2, 3, 2, 0), 'W'): 2.020202019888892,
#   ((6, True, 2, 3, 2, 0), 'Deliver'): 30.20202019888892,
#   ((6, False, 2, 3, 3, 0), 'SW'): -1.079797980111108,
#   ((5, False, 2, 3, 3, 0), 'NE'): -0.7979798011110801,
#   ((6, False, 2, 3, 3, 0), 'S'): -1.079797980111108,
#   ((9, False, 2, 3, 3, 0), 'N'): -0.7979798011110801,
#   ((6, False, 2, 3, 3, 0), 'E'): 2.020201988889199,
#   ((7, False, 2, 3, 3, 0), 'Pick'): 30.20201988889199,
#   ((7, True, 1, 3, 3, 0), 'W'): 2.0201988888891993,
#   ((6, True, 1, 3, 3, 0), 'Deliver'): 30.20198888889199,
#   ((6, False, 1, 3, 4, 0), 'SW'): -1.079801111110801,
#   ((5, False, 1, 3, 4, 0), 'NE'): -0.798011111108011,
#   ((6, False, 1, 3, 4, 0), 'S'): -1.079801111110801,
#   ((9, False, 1, 3, 4, 0), 'N'): -0.798011111108011,
#   ((6, False, 1, 3, 4, 0), 'E'): 2.019888888919889,
#   ((7, False, 1, 3, 4, 0), 'Pick'): 30.19888888919889,
#   ((7, True, 0, 3, 4, 0), 'W'): -0.8011111080110801,
#   ((6, True, 0, 3, 4, 0), 'SW'): -1.080111110801108,
#   ((5, True, 0, 3, 4, 0), 'NE'): -0.8011111080110801,
#   ((6, True, 0, 3, 4, 0), 'S'): 1.9888889198891988,
#   ((9, True, 0, 3, 4, 0), 'Deliver'): 29.888889198891988,
#   ((9, False, 0, 3, 4, 1), 'N'): -1.111108011080111,
#   ((6, False, 0, 3, 4, 1), 'SW'): -1.1110801108011084,
#   ((5, False, 0, 3, 4, 1), 'NE'): -1.111108011080111,
#   ((6, False, 0, 3, 4, 1), 'S'): -1.1111108011080113,
#   ((6, False, 0, 3, 4, 1), 'E'): -1.1111108011080113,
#   ((7, False, 0, 3, 4, 1), 'W'): -1.111108011080111,
#   ((5, False, 0, 3, 4, 1), 'SW'): -1.1108011080110805,
#   ((4, False, 0, 3, 4, 1), 'NW'): -1.1110801108011084,
#   ((2, False, 0, 3, 4, 1), 'SE'): -1.1108011080110805,
#   ((4, False, 0, 3, 4, 1), 'SW'): -1.1080110801108014,
#   ((3, False, 0, 3, 4, 1), 'NW'): -1.11080110801108,
#   ((1, False, 0, 3, 4, 1), 'SE'): -1.1080110801108012,
#   ((3, False, 0, 3, 4, 1), 'NE'): -1.1108011080110802,
#   ((4, False, 0, 3, 4, 1), 'NE'): -1.1110801108011084,
#   ((7, False, 0, 3, 4, 1), 'SW'): -1.1111110801108013,
#   ((8, False, 0, 3, 4, 1), 'NE'): -1.1111108011080113,
#   ((3, False, 0, 3, 4, 1), 'SW'): -1.0801108011080114,
#   ((17, False, 0, 3, 4, 1), 'NE'): -1.1080110801108012,
#   ((17, False, 0, 3, 4, 1), 'SW'): -0.8011080110801108,
#   ((16, False, 0, 3, 4, 1), 'S'): -1.0801108011080112,
#   ((15, False, 0, 3, 4, 1), 'N'): -0.8011080110801108,
#   ((16, False, 0, 3, 4, 1), 'E'): 1.988919889198892,
#   ((11, False, 0, 3, 4, 1), 'Pick'): 29.88919889198892,
#   ((11, True, 0, 2, 4, 1), 'W'): -1.1080110801108014,
#   ((16, True, 0, 2, 4, 1), 'S'): -1.0801108011080112,
#   ((15, True, 0, 2, 4, 1), 'N'): -1.1080110801108012,
#   ((16, True, 0, 2, 4, 1), 'E'): -1.1108011080110802,
#   ((16, True, 0, 2, 4, 1), 'NE'): -1.11080110801108,
#   ((17, True, 0, 2, 4, 1), 'NE'): -1.1108011111080114,
#   ((3, True, 0, 2, 4, 1), 'NW'): -1.111080111110801,
#   ((1, True, 0, 2, 4, 1), 'SE'): -1.1108011111080112,
#   ((3, True, 0, 2, 4, 1), 'NE'): -1.108011111080111,
#   ((4, True, 0, 2, 4, 1), 'NW'): -1.1108011111080112,
#   ((2, True, 0, 2, 4, 1), 'SE'): -1.1080111110801107,
#   ((4, True, 0, 2, 4, 1), 'SW'): -1.1108011111080112,
#   ((3, True, 0, 2, 4, 1), 'SW'): -1.11080110801108,
#   ((17, True, 0, 2, 4, 1), 'SW'): -1.1080110801108012,
#   ((15, True, 0, 2, 4, 1), 'SE'): -0.8011080110801108,
#   ((12, True, 0, 2, 4, 1), 'NW'): -1.0801108011080112,
#   ((4, True, 0, 2, 4, 1), 'NE'): -1.080111110801108,
#   ((5, True, 0, 2, 4, 1), 'NE'): -0.8011111080110801,
#   ((6, True, 0, 2, 4, 1), 'SW'): -1.080111110801108,
#   ((5, True, 0, 2, 4, 1), 'SW'): -1.1080111110801107,
#   ((12, True, 0, 2, 4, 1), 'SE'): 1.988919889198892,
#   ((13, True, 0, 2, 4, 1), 'Deliver'): 29.88919889198892,
#   ((13, False, 0, 2, 4, 2), 'NW'): -1.1080110801108012,
#   ((12, False, 0, 2, 4, 2), 'NW'): -1.0801108011080112,
#   ((15, False, 0, 2, 4, 2), 'N'): -0.8011080110801108,
#   ((16, False, 0, 2, 4, 2), 'S'): -1.0801108011080112,
#   ((15, False, 0, 2, 4, 2), 'SE'): -1.1080110801108012,
#   ((12, False, 0, 2, 4, 2), 'SE'): -1.11080110801108,
#   ((16, False, 0, 2, 4, 2), 'E'): 1.9889198891988928,
#   ((11, False, 0, 2, 4, 2), 'Pick'): 29.889198891988926,
#   ((11, True, 0, 1, 4, 2), 'W'): -1.1080110801107501,
#   ((16, True, 0, 1, 4, 2), 'S'): -1.0801108011075,
#   ((15, True, 0, 1, 4, 2), 'N'): -1.10801108011075,
#   ((16, True, 0, 1, 4, 2), 'E'): -1.1108011080110751,
#   ((16, True, 0, 1, 4, 2), 'NE'): -1.110801108011075,
#   ((17, True, 0, 1, 4, 2), 'NE'): -1.1108011111080114,
#   ((3, True, 0, 1, 4, 2), 'NW'): -1.1110801111108013,
#   ((1, True, 0, 1, 4, 2), 'SE'): -1.1108011111080114,
#   ((3, True, 0, 1, 4, 2), 'NE'): -1.108011111080111,
#   ((4, True, 0, 1, 4, 2), 'NW'): -1.1108011111080112,
#   ((2, True, 0, 1, 4, 2), 'SE'): -1.1080111110801107,
#   ((4, True, 0, 1, 4, 2), 'SW'): -1.1108011111080112,
#   ((3, True, 0, 1, 4, 2), 'SW'): -1.110801108011075,
#   ((17, True, 0, 1, 4, 2), 'SW'): -1.10801108011075,
#   ((15, True, 0, 1, 4, 2), 'SE'): -0.801108011075,
#   ((12, True, 0, 1, 4, 2), 'NW'): -1.0801108011075,
#   ((4, True, 0, 1, 4, 2), 'NE'): -1.0801111108011074,
#   ((5, True, 0, 1, 4, 2), 'NE'): -0.801111108011075,
#   ((6, True, 0, 1, 4, 2), 'SW'): -1.0801111108011074,
#   ((5, True, 0, 1, 4, 2), 'SW'): -1.1080111110801107,
#   ((12, True, 0, 1, 4, 2), 'SE'): 1.9889198892500004,
#   ((13, True, 0, 1, 4, 2), 'Deliver'): 29.8891988925,
#   ((13, False, 0, 1, 4, 3), 'NW'): -1.108011075,
#   ((12, False, 0, 1, 4, 3), 'NW'): -1.08011075,
#   ((15, False, 0, 1, 4, 3), 'N'): -0.8011075,
#   ((16, False, 0, 1, 4, 3), 'S'): -1.08011075,
#   ((15, False, 0, 1, 4, 3), 'SE'): -1.108011075,
#   ((12, False, 0, 1, 4, 3), 'SE'): -1.1108011075,
#   ((16, False, 0, 1, 4, 3), 'E'): 1.988925,
#   ((11, False, 0, 1, 4, 3), 'Pick'): 29.88925,
#   ((11, True, 0, 0, 4, 3), 'W'): -1.1075000000000002,
#   ((16, True, 0, 0, 4, 3), 'S'): -1.075,
#   ((15, True, 0, 0, 4, 3), 'N'): -1.1075,
#   ((16, True, 0, 0, 4, 3), 'E'): -1.11075,
#   ((16, True, 0, 0, 4, 3), 'NE'): -1.11075,
#   ((17, True, 0, 0, 4, 3), 'NE'): -1.1107500000000001,
#   ((3, True, 0, 0, 4, 3), 'NW'): -1.1110750000000003,
#   ((1, True, 0, 0, 4, 3), 'SE'): -1.1107500000000001,
#   ((3, True, 0, 0, 4, 3), 'NE'): -1.1075000000000002,
#   ((4, True, 0, 0, 4, 3), 'NW'): -1.1107500000000001,
#   ((2, True, 0, 0, 4, 3), 'SE'): -1.1075000000000002,
#   ((4, True, 0, 0, 4, 3), 'SW'): -1.1107500000000001,
#   ((3, True, 0, 0, 4, 3), 'SW'): -1.11075,
#   ((17, True, 0, 0, 4, 3), 'SW'): -1.1075,
#   ((15, True, 0, 0, 4, 3), 'SE'): -0.75,
#   ((12, True, 0, 0, 4, 3), 'NW'): -1.075,
#   ((4, True, 0, 0, 4, 3), 'NE'): -1.0750000000000002,
#   ((5, True, 0, 0, 4, 3), 'NE'): -0.75,
#   ((6, True, 0, 0, 4, 3), 'SW'): -1.075,
#   ((5, True, 0, 0, 4, 3), 'SW'): -1.1075,
#   ((12, True, 0, 0, 4, 3), 'SE'): 2.5,
#   ((13, True, 0, 0, 4, 3), 'Deliver'): 35.0,
#   ((13, False, 0, 0, 4, 4), 'NW'): 50.0,
#   ((6, False, 4, 4, 0, 0), 'S'): -1.07979797979798,
#   ((9, False, 4, 4, 0, 0), 'N'): -0.7979797979797981,
#   ((6, False, 4, 4, 0, 0), 'E'): 2.0202020202020194,
#   ((7, False, 4, 4, 0, 0), 'Pick'): 30.202020202020197,
#   ((7, True, 3, 4, 0, 0), 'W'): 2.020202020201989,
#   ((6, True, 3, 4, 0, 0), 'Deliver'): 30.202020202019888,
#   ((6, False, 3, 4, 1, 0), 'SW'): -1.079797979798011,
#   ((5, False, 3, 4, 1, 0), 'NE'): -0.7979797979801111,
#   ((6, False, 3, 4, 1, 0), 'S'): -1.079797979798011,
#   ((9, False, 3, 4, 1, 0), 'N'): -0.7979797979801111,
#   ((6, False, 3, 4, 1, 0), 'E'): 2.020202020198889,
#   ((7, False, 3, 4, 1, 0), 'Pick'): 30.20202020198889,
#   ((7, True, 2, 4, 1, 0), 'W'): 2.020202019888892,
#   ((6, True, 2, 4, 1, 0), 'Deliver'): 30.20202019888892,
#   ((6, False, 2, 4, 2, 0), 'SW'): -1.079797980111108,
#   ((5, False, 2, 4, 2, 0), 'NE'): -0.7979798011110801,
#   ((6, False, 2, 4, 2, 0), 'S'): -1.079797980111108,
#   ((9, False, 2, 4, 2, 0), 'N'): -0.7979798011110801,
#   ((6, False, 2, 4, 2, 0), 'E'): 2.020201988889199,
#   ((7, False, 2, 4, 2, 0), 'Pick'): 30.20201988889199,
#   ((7, True, 1, 4, 2, 0), 'W'): 2.0201988889198894,
#   ((6, True, 1, 4, 2, 0), 'Deliver'): 30.20198888919889,
#   ((6, False, 1, 4, 3, 0), 'SW'): -1.079801111080111,
#   ((5, False, 1, 4, 3, 0), 'NE'): -0.798011110801108,
#   ((6, False, 1, 4, 3, 0), 'S'): -1.079801111080111,
#   ((9, False, 1, 4, 3, 0), 'N'): -0.798011110801108,
#   ((6, False, 1, 4, 3, 0), 'E'): 2.01988889198892,
#   ((7, False, 1, 4, 3, 0), 'Pick'): 30.1988889198892,
#   ((7, True, 0, 4, 3, 0), 'W'): 1.988889198891989,
#   ((6, True, 0, 4, 3, 0), 'Deliver'): 29.888891988919887,
#   ((6, False, 0, 4, 4, 0), 'SW'): -1.1110801108011084,
#   ((5, False, 0, 4, 4, 0), 'NE'): -1.111108011080111,
#   ((6, False, 0, 4, 4, 0), 'S'): -1.1111108011080113,
#   ((9, False, 0, 4, 4, 0), 'N'): -1.111108011080111,
#   ((6, False, 0, 4, 4, 0), 'E'): -1.1111108011080113,
#   ((7, False, 0, 4, 4, 0), 'W'): -1.111108011080111,
#   ((5, False, 0, 4, 4, 0), 'SW'): -1.1108011080110805,
#   ((4, False, 0, 4, 4, 0), 'NW'): -1.1110801108011084,
#   ((2, False, 0, 4, 4, 0), 'SE'): -1.1108011080110805,
#   ((4, False, 0, 4, 4, 0), 'SW'): -1.1080110801108014,
#   ((3, False, 0, 4, 4, 0), 'NW'): -1.1108011080110805,
#   ((1, False, 0, 4, 4, 0), 'SE'): -1.1080110801108014,
#   ((3, False, 0, 4, 4, 0), 'NE'): -1.1108011080110802,
#   ((4, False, 0, 4, 4, 0), 'NE'): -1.1110801108011084,
#   ((7, False, 0, 4, 4, 0), 'SW'): -1.1111110801108013,
#   ((8, False, 0, 4, 4, 0), 'NE'): -1.1111108011080113,
#   ((3, False, 0, 4, 4, 0), 'SW'): -1.0801108011080114,
#   ((17, False, 0, 4, 4, 0), 'NE'): -1.1080110801108012,
#   ((17, False, 0, 4, 4, 0), 'SW'): -0.8011080110801108,
#   ((16, False, 0, 4, 4, 0), 'S'): -1.0801108011080112,
#   ((15, False, 0, 4, 4, 0), 'N'): -0.8011080110801108,
#   ((16, False, 0, 4, 4, 0), 'E'): 1.988919889198892,
#   ((11, False, 0, 4, 4, 0), 'Pick'): 29.88919889198892,
#   ((11, True, 0, 3, 4, 0), 'W'): -1.1080110801108014,
#   ((16, True, 0, 3, 4, 0), 'S'): -1.0801108011080112,
#   ((15, True, 0, 3, 4, 0), 'N'): -1.1080110801108012,
#   ((16, True, 0, 3, 4, 0), 'E'): -1.1108011080110802,
#   ((16, True, 0, 3, 4, 0), 'NE'): -1.11080110801108,
#   ((17, True, 0, 3, 4, 0), 'NE'): -1.1108011111080112,
#   ((3, True, 0, 3, 4, 0), 'NW'): -1.111080111110801,
#   ((1, True, 0, 3, 4, 0), 'SE'): -1.1108011111080112,
#   ((3, True, 0, 3, 4, 0), 'NE'): -1.1080111110801107,
#   ((4, True, 0, 3, 4, 0), 'NW'): -1.1108011111080112,
#   ((2, True, 0, 3, 4, 0), 'SE'): -1.1080111110801107,
#   ((4, True, 0, 3, 4, 0), 'SW'): -1.1108011111080112,
#   ((3, True, 0, 3, 4, 0), 'SW'): -1.11080110801108,
#   ((17, True, 0, 3, 4, 0), 'SW'): -1.1080110801108012,
#   ((15, True, 0, 3, 4, 0), 'SE'): -0.8011080110801108,
#   ((12, True, 0, 3, 4, 0), 'NW'): -1.0801108011080112,
#   ((4, True, 0, 3, 4, 0), 'NE'): -1.080111110801108,
#   ((5, True, 0, 3, 4, 0), 'SW'): -1.1080111110801107,
#   ((12, True, 0, 3, 4, 0), 'SE'): 1.988919889198892,
#   ((13, True, 0, 3, 4, 0), 'Deliver'): 29.88919889198892,
#   ((13, False, 0, 3, 4, 1), 'NW'): -1.1080110801108012,
#   ((12, False, 0, 3, 4, 1), 'NW'): -1.0801108011080112,
#   ((15, False, 0, 3, 4, 1), 'SE'): -1.1080110801108012,
#   ((12, False, 0, 3, 4, 1), 'SE'): -1.11080110801108,
#   ((16, False, 0, 3, 4, 1), 'NE'): -1.0801108011080112,
#   ((6, True, 0, 2, 4, 1), 'S'): 1.9888889198891988,
#   ((9, True, 0, 2, 4, 1), 'Deliver'): 29.888889198891988,
#   ((9, False, 0, 2, 4, 2), 'N'): -1.111108011080111,
#   ((6, False, 0, 2, 4, 2), 'SW'): -1.1110801108011084,
#   ((5, False, 0, 2, 4, 2), 'NE'): -1.111108011080111,
#   ((6, False, 0, 2, 4, 2), 'S'): -1.1111108011080113,
#   ((6, False, 0, 2, 4, 2), 'E'): -1.1111108011080113,
#   ((7, False, 0, 2, 4, 2), 'W'): -1.111108011080111,
#   ((5, False, 0, 2, 4, 2), 'SW'): -1.1108011080110805,
#   ((4, False, 0, 2, 4, 2), 'NW'): -1.1110801108011081,
#   ((2, False, 0, 2, 4, 2), 'SE'): -1.1108011080110805,
#   ((4, False, 0, 2, 4, 2), 'SW'): -1.1080110801108014,
#   ((3, False, 0, 2, 4, 2), 'NW'): -1.11080110801108,
#   ((1, False, 0, 2, 4, 2), 'SE'): -1.1080110801108012,
#   ((3, False, 0, 2, 4, 2), 'NE'): -1.1108011080110802,
#   ((4, False, 0, 2, 4, 2), 'NE'): -1.1110801108011081,
#   ((7, False, 0, 2, 4, 2), 'SW'): -1.1111110801108013,
#   ((8, False, 0, 2, 4, 2), 'NE'): -1.1111108011080113,
#   ((3, False, 0, 2, 4, 2), 'SW'): -1.0801108011080112,
#   ((17, False, 0, 2, 4, 2), 'NE'): -1.1080110801108012,
#   ((17, False, 0, 2, 4, 2), 'SW'): -0.8011080110801108,
#   ((16, False, 0, 2, 4, 2), 'NE'): -1.0801108011080112,
#   ((6, True, 0, 1, 4, 2), 'S'): 1.9888889198892503,
#   ((9, True, 0, 1, 4, 2), 'Deliver'): 29.8888891988925,
#   ((9, False, 0, 1, 4, 3), 'N'): -1.1111080110750002,
#   ((6, False, 0, 1, 4, 3), 'SW'): -1.1110801107500003,
#   ((5, False, 0, 1, 4, 3), 'NE'): -1.1111080110750002,
#   ((6, False, 0, 1, 4, 3), 'S'): -1.1111108011075002,
#   ((6, False, 0, 1, 4, 3), 'E'): -1.1111108011075002,
#   ((7, False, 0, 1, 4, 3), 'W'): -1.1111080110750002,
#   ((5, False, 0, 1, 4, 3), 'SW'): -1.1108011075000002,
#   ((4, False, 0, 1, 4, 3), 'NW'): -1.1110801107500001,
#   ((2, False, 0, 1, 4, 3), 'SE'): -1.1108011075000002,
#   ((4, False, 0, 1, 4, 3), 'SW'): -1.1080110750000003,
#   ((3, False, 0, 1, 4, 3), 'NW'): -1.1108011075,
#   ((1, False, 0, 1, 4, 3), 'SE'): -1.108011075,
#   ((3, False, 0, 1, 4, 3), 'NE'): -1.1108011075,
#   ((4, False, 0, 1, 4, 3), 'NE'): -1.1110801107500001,
#   ((7, False, 0, 1, 4, 3), 'SW'): -1.1111110801107502,
#   ((8, False, 0, 1, 4, 3), 'NE'): -1.1111108011075002,
#   ((3, False, 0, 1, 4, 3), 'SW'): -1.08011075,
#   ((17, False, 0, 1, 4, 3), 'NE'): -1.108011075,
#   ((17, False, 0, 1, 4, 3), 'SW'): -0.8011075,
#   ((16, False, 0, 1, 4, 3), 'NE'): -1.08011075,
#   ((6, True, 0, 0, 4, 3), 'S'): 2.5,
#   ((9, True, 0, 0, 4, 3), 'Deliver'): 35.0,
#   ((9, False, 0, 0, 4, 4), 'N'): 50.0,
#   ((16, False, 4, 4, 0, 0), 'NE'): -1.0801108011080112,
#   ((15, False, 4, 4, 0, 0), 'SE'): -1.1080110801108012,
#   ((12, False, 4, 4, 0, 0), 'NW'): -1.0801108011080112,
#   ((12, True, 4, 3, 0, 0), 'SE'): 1.988919889198892,
#   ((13, True, 4, 3, 0, 0), 'Deliver'): 29.88919889198892,
#   ((13, False, 4, 3, 0, 1), 'NW'): -1.1080110801108014,
#   ((12, False, 4, 3, 0, 1), 'NW'): -1.0801108011080114,
#   ((15, False, 4, 3, 0, 1), 'N'): -0.8011080110801109,
#   ((16, False, 4, 3, 0, 1), 'S'): -1.0801108011080112,
#   ((15, False, 4, 3, 0, 1), 'SE'): -1.1080110801108012,
#   ((12, False, 4, 3, 0, 1), 'SE'): -1.1108011080110805,
#   ((16, False, 4, 3, 0, 1), 'E'): 1.988919889198892,
#   ((11, False, 4, 3, 0, 1), 'Pick'): 29.88919889198892,
#   ((11, True, 4, 2, 0, 1), 'W'): -1.1080110801108014,
#   ((16, True, 4, 2, 0, 1), 'S'): -1.0801108011080114,
#   ((15, True, 4, 2, 0, 1), 'N'): -1.1080110801108012,
#   ((16, True, 4, 2, 0, 1), 'E'): -1.1108011080110805,
#   ((16, True, 4, 2, 0, 1), 'NE'): -1.1107979797979803,
#   ((17, True, 4, 2, 0, 1), 'NE'): -1.1079797979797983,
#   ((3, True, 4, 2, 0, 1), 'NW'): -1.1107979797979801,
#   ((1, True, 4, 2, 0, 1), 'SE'): -1.1079797979797983,
#   ((3, True, 4, 2, 0, 1), 'NE'): -1.07979797979798,
#   ((4, True, 4, 2, 0, 1), 'NW'): -1.1079797979797983,
#   ((2, True, 4, 2, 0, 1), 'SE'): -1.07979797979798,
#   ((4, True, 4, 2, 0, 1), 'SW'): -1.1079797979797983,
#   ((3, True, 4, 2, 0, 1), 'SW'): -1.1107979797979801,
#   ((17, True, 4, 2, 0, 1), 'SW'): -1.1080110801108012,
#   ((15, True, 4, 2, 0, 1), 'SE'): -0.8011080110801108,
#   ((12, True, 4, 2, 0, 1), 'NW'): -1.0801108011080112,
#   ((4, True, 4, 2, 0, 1), 'NE'): -0.7979797979797981,
#   ((5, True, 4, 2, 0, 1), 'NE'): 2.0202020202020203,
#   ((6, True, 4, 2, 0, 1), 'Deliver'): 30.2020202020202,
#   ((6, False, 4, 2, 1, 1), 'SW'): -1.0797979797979798,
#   ((5, False, 4, 2, 1, 1), 'NE'): -0.797979797979798,
#   ((6, False, 4, 2, 1, 1), 'S'): -1.0797979797979798,
#   ((9, False, 4, 2, 1, 1), 'N'): -0.797979797979798,
#   ((6, False, 4, 2, 1, 1), 'E'): 2.02020202020202,
#   ((7, False, 4, 2, 1, 1), 'Pick'): 30.202020202020197,
#   ((7, True, 3, 2, 1, 1), 'W'): 2.020202020201989,
#   ((6, True, 3, 2, 1, 1), 'Deliver'): 30.202020202019888,
#   ((6, False, 3, 2, 2, 1), 'SW'): -1.079797979798011,
#   ((5, False, 3, 2, 2, 1), 'NE'): -0.7979797979801111,
#   ((6, False, 3, 2, 2, 1), 'S'): -1.079797979798011,
#   ((9, False, 3, 2, 2, 1), 'N'): -0.7979797979801111,
#   ((6, False, 3, 2, 2, 1), 'E'): 2.020202020198889,
#   ((7, False, 3, 2, 2, 1), 'Pick'): 30.20202020198889,
#   ((7, True, 2, 2, 2, 1), 'W'): 2.020202019888892,
#   ((6, True, 2, 2, 2, 1), 'Deliver'): 30.20202019888892,
#   ((6, False, 2, 2, 3, 1), 'SW'): -1.079797980111108,
#   ((5, False, 2, 2, 3, 1), 'NE'): -0.7979798011110801,
#   ((6, False, 2, 2, 3, 1), 'S'): -1.079797980111108,
#   ((9, False, 2, 2, 3, 1), 'N'): -0.7979798011110801,
#   ((6, False, 2, 2, 3, 1), 'E'): 2.020201988889199,
#   ((7, False, 2, 2, 3, 1), 'Pick'): 30.20201988889199,
#   ((7, True, 1, 2, 3, 1), 'W'): 2.0201988888891993,
#   ((6, True, 1, 2, 3, 1), 'Deliver'): 30.20198888889199,
#   ((6, False, 1, 2, 4, 1), 'SW'): -1.079801111110801,
#   ((5, False, 1, 2, 4, 1), 'NE'): -0.798011111108011,
#   ((6, False, 1, 2, 4, 1), 'S'): -1.079801111110801,
#   ((9, False, 1, 2, 4, 1), 'N'): -0.798011111108011,
#   ((6, False, 1, 2, 4, 1), 'E'): 2.019888888919889,
#   ((7, False, 1, 2, 4, 1), 'Pick'): 30.19888888919889,
#   ((7, True, 0, 2, 4, 1), 'W'): -0.8011111080110801,
#   ((6, True, 0, 2, 4, 1), 'E'): -0.801111110801108,
#   ((7, True, 0, 2, 4, 1), 'SW'): 1.9888888919889198,
#   ((8, True, 0, 2, 4, 1), 'Deliver'): 29.888888919889197,
#   ((7, True, 3, 4, 0, 0), 'SW'): 2.020202020201989,
#   ((8, True, 3, 4, 0, 0), 'Deliver'): 30.202020202019888,
#   ((8, False, 3, 4, 0, 1), 'NE'): 2.020202020198889,
#   ((7, False, 3, 4, 0, 1), 'Pick'): 30.20202020198889,
#   ((7, True, 2, 4, 0, 1), 'W'): 2.020202019888892,
#   ((6, True, 2, 4, 0, 1), 'Deliver'): 30.20202019888892,
#   ((6, False, 2, 4, 1, 1), 'SW'): -1.079797980111108,
#   ((5, False, 2, 4, 1, 1), 'NE'): -0.7979798011110801,
#   ((6, False, 2, 4, 1, 1), 'S'): -1.079797980111108,
#   ((9, False, 2, 4, 1, 1), 'N'): -0.7979798011110801,
#   ((6, False, 2, 4, 1, 1), 'E'): 2.020201988889199,
#   ((7, False, 2, 4, 1, 1), 'Pick'): 30.20201988889199,
#   ((7, True, 1, 4, 1, 1), 'W'): 2.0201988889198894,
#   ((6, True, 1, 4, 1, 1), 'Deliver'): 30.20198888919889,
#   ((6, False, 1, 4, 2, 1), 'SW'): -1.079801111080111,
#   ((5, False, 1, 4, 2, 1), 'NE'): -0.798011110801108,
#   ((6, False, 1, 4, 2, 1), 'S'): -1.079801111080111,
#   ((9, False, 1, 4, 2, 1), 'N'): -0.798011110801108,
#   ((6, False, 1, 4, 2, 1), 'E'): 2.01988889198892,
#   ((7, False, 1, 4, 2, 1), 'Pick'): 30.1988889198892,
#   ((7, True, 0, 4, 2, 1), 'W'): 1.988889198891989,
#   ((6, True, 0, 4, 2, 1), 'Deliver'): 29.888891988919887,
#   ((6, False, 0, 4, 3, 1), 'SW'): -1.1110801108011084,
#   ((5, False, 0, 4, 3, 1), 'NE'): -1.111108011080111,
#   ((6, False, 0, 4, 3, 1), 'S'): -1.1111108011080113,
#   ((9, False, 0, 4, 3, 1), 'N'): -1.111108011080111,
#   ((6, False, 0, 4, 3, 1), 'E'): -1.1111108011080113,
#   ((7, False, 0, 4, 3, 1), 'W'): -1.111108011080111,
#   ((5, False, 0, 4, 3, 1), 'SW'): -1.1108011080110805,
#   ((4, False, 0, 4, 3, 1), 'NW'): -1.1110801108011084,
#   ((2, False, 0, 4, 3, 1), 'SE'): -1.1108011080110805,
#   ((4, False, 0, 4, 3, 1), 'SW'): -1.1080110801108014,
#   ((3, False, 0, 4, 3, 1), 'NW'): -1.1108011080110805,
#   ((1, False, 0, 4, 3, 1), 'SE'): -1.1080110801108014,
#   ((3, False, 0, 4, 3, 1), 'NE'): -1.1108011080110805,
#   ((4, False, 0, 4, 3, 1), 'NE'): -1.1110801108011084,
#   ((7, False, 0, 4, 3, 1), 'SW'): -1.1111110801108013,
#   ((8, False, 0, 4, 3, 1), 'NE'): -1.1111108011080113,
#   ((3, False, 0, 4, 3, 1), 'SW'): -1.0801108011080114,
#   ((17, False, 0, 4, 3, 1), 'NE'): -1.1080110801108012,
#   ((17, False, 0, 4, 3, 1), 'SW'): -0.8011080110801108,
#   ((16, False, 0, 4, 3, 1), 'S'): -1.0801108011080112,
#   ((15, False, 0, 4, 3, 1), 'N'): -0.8011080110801108,
#   ((16, False, 0, 4, 3, 1), 'E'): 1.988919889198892,
#   ((11, False, 0, 4, 3, 1), 'Pick'): 29.88919889198892,
#   ((11, True, 0, 3, 3, 1), 'W'): -1.1080110801108014,
#   ((16, True, 0, 3, 3, 1), 'S'): -1.0801108011080112,
#   ((15, True, 0, 3, 3, 1), 'N'): -1.1080110801108012,
#   ((16, True, 0, 3, 3, 1), 'E'): -1.1108011080110802,
#   ((16, True, 0, 3, 3, 1), 'NE'): -1.11080110801108,
#   ((17, True, 0, 3, 3, 1), 'NE'): -1.1080111108011081,
#   ((3, True, 0, 3, 3, 1), 'NW'): -1.1108011110801108,
#   ((1, True, 0, 3, 3, 1), 'SE'): -1.108011110801108,
#   ((3, True, 0, 3, 3, 1), 'NE'): -1.0801111080110801,
#   ((4, True, 0, 3, 3, 1), 'NW'): -1.108011110801108,
#   ((2, True, 0, 3, 3, 1), 'SE'): -1.0801111080110801,
#   ((4, True, 0, 3, 3, 1), 'SW'): -1.108011110801108,
#   ((3, True, 0, 3, 3, 1), 'SW'): -1.11080110801108,
#   ((17, True, 0, 3, 3, 1), 'SW'): -1.1080110801108012,
#   ((15, True, 0, 3, 3, 1), 'SE'): -0.8011080110801108,
#   ((12, True, 0, 3, 3, 1), 'NW'): -1.0801108011080112,
#   ((4, True, 0, 3, 3, 1), 'NE'): -0.8011110801108011,
#   ((5, True, 0, 3, 3, 1), 'NE'): 1.988889198891989,
#   ((6, True, 0, 3, 3, 1), 'Deliver'): 29.888891988919887,
#   ((6, True, 0, 1, 4, 2), 'E'): -0.8011111108011075,
#   ((7, True, 0, 1, 4, 2), 'W'): -0.801111108011075,
#   ((6, True, 0, 0, 4, 3), 'E'): -0.75,
#   ((7, True, 0, 0, 4, 3), 'W'): -0.75,
#   ((12, False, 4, 4, 0, 0), 'SE'): -1.11080110801108,
#   ((13, False, 4, 4, 0, 0), 'NW'): -1.1080110801108012,
#   ((16, False, 4, 3, 0, 1), 'NE'): -1.0801108011080112,
#   ((17, False, 4, 3, 0, 1), 'NE'): -1.1080110801108012,
#   ((3, False, 4, 3, 0, 1), 'NW'): -1.11080110801108,
#   ((1, False, 4, 3, 0, 1), 'SE'): -1.1080110801108012,
#   ((3, False, 4, 3, 0, 1), 'NE'): -1.1079797979797983,
#   ((4, False, 4, 3, 0, 1), 'NW'): -1.1107979797979801,
#   ((2, False, 4, 3, 0, 1), 'SE'): -1.1079797979797983,
#   ((4, False, 4, 3, 0, 1), 'SW'): -1.1080110801108012,
#   ((3, False, 4, 3, 0, 1), 'SW'): -1.0801108011080112,
#   ((17, False, 4, 3, 0, 1), 'SW'): -0.8011080110801108,
#   ((12, True, 4, 2, 0, 1), 'SE'): 1.988919889198892,
#   ((13, True, 4, 2, 0, 1), 'Deliver'): 29.88919889198892,
#   ((13, False, 4, 2, 0, 2), 'NW'): -1.1080110801108014,
#   ((12, False, 4, 2, 0, 2), 'NW'): -1.0801108011080114,
#   ((15, False, 4, 2, 0, 2), 'N'): -0.8011080110801109,
#   ((16, False, 4, 2, 0, 2), 'S'): -1.0801108011080112,
#   ((15, False, 4, 2, 0, 2), 'SE'): -1.1080110801108012,
#   ((12, False, 4, 2, 0, 2), 'SE'): -1.1108011080110805,
#   ((16, False, 4, 2, 0, 2), 'E'): 1.988919889198892,
#   ((11, False, 4, 2, 0, 2), 'Pick'): 29.88919889198892,
#   ((11, True, 4, 1, 0, 2), 'W'): -1.1080110801108014,
#   ((16, True, 4, 1, 0, 2), 'S'): -1.0801108011080114,
#   ((15, True, 4, 1, 0, 2), 'N'): -1.1080110801108012,
#   ((16, True, 4, 1, 0, 2), 'E'): -1.1108011080110805,
#   ((16, True, 4, 1, 0, 2), 'NE'): -1.1107979797979803,
#   ((17, True, 4, 1, 0, 2), 'NE'): -1.1079797979797983,
#   ((3, True, 4, 1, 0, 2), 'NW'): -1.1107979797979801,
#   ((1, True, 4, 1, 0, 2), 'SE'): -1.1079797979797983,
#   ((3, True, 4, 1, 0, 2), 'NE'): -1.07979797979798,
#   ((4, True, 4, 1, 0, 2), 'NW'): -1.1079797979797983,
#   ((2, True, 4, 1, 0, 2), 'SE'): -1.07979797979798,
#   ((4, True, 4, 1, 0, 2), 'SW'): -1.1079797979797983,
#   ((3, True, 4, 1, 0, 2), 'SW'): -1.1107979797979801,
#   ((17, True, 4, 1, 0, 2), 'SW'): -1.1080110801108012,
#   ((15, True, 4, 1, 0, 2), 'SE'): -0.8011080110801111,
#   ((12, True, 4, 1, 0, 2), 'NW'): -1.0801108011080112,
#   ((4, True, 4, 1, 0, 2), 'NE'): -0.7979797979797981,
#   ((5, True, 4, 1, 0, 2), 'NE'): 2.0202020202020203,
#   ((6, True, 4, 1, 0, 2), 'Deliver'): 30.2020202020202,
#   ((6, False, 4, 1, 1, 2), 'SW'): -1.0797979797979798,
#   ((5, False, 4, 1, 1, 2), 'NE'): -0.797979797979798,
#   ((6, False, 4, 1, 1, 2), 'S'): -1.0797979797979798,
#   ((9, False, 4, 1, 1, 2), 'N'): -0.797979797979798,
#   ((6, False, 4, 1, 1, 2), 'E'): 2.02020202020202,
#   ((7, False, 4, 1, 1, 2), 'Pick'): 30.2020202020202,
#   ((7, True, 3, 1, 1, 2), 'W'): 2.020202020201989,
#   ((6, True, 3, 1, 1, 2), 'Deliver'): 30.202020202019888,
#   ((6, False, 3, 1, 2, 2), 'SW'): -1.079797979798011,
#   ((5, False, 3, 1, 2, 2), 'NE'): -0.7979797979801111,
#   ((6, False, 3, 1, 2, 2), 'S'): -1.079797979798011,
#   ((9, False, 3, 1, 2, 2), 'N'): -0.7979797979801111,
#   ((6, False, 3, 1, 2, 2), 'E'): 2.020202020198889,
#   ((7, False, 3, 1, 2, 2), 'Pick'): 30.20202020198889,
#   ((7, True, 2, 1, 2, 2), 'W'): 2.020202019888892,
#   ((6, True, 2, 1, 2, 2), 'Deliver'): 30.20202019888892,
#   ((6, False, 2, 1, 3, 2), 'SW'): -1.079797980111108,
#   ((5, False, 2, 1, 3, 2), 'NE'): -0.7979798011110801,
#   ((6, False, 2, 1, 3, 2), 'S'): -1.079797980111108,
#   ((9, False, 2, 1, 3, 2), 'N'): -0.7979798011110801,
#   ((6, False, 2, 1, 3, 2), 'E'): 2.020201988889199,
#   ((7, False, 2, 1, 3, 2), 'Pick'): 30.20201988889199,
#   ((7, True, 1, 1, 3, 2), 'W'): 2.0201988888891993,
#   ((6, True, 1, 1, 3, 2), 'Deliver'): 30.20198888889199,
#   ((6, False, 1, 1, 4, 2), 'SW'): -1.079801111110801,
#   ((5, False, 1, 1, 4, 2), 'NE'): -0.798011111108011,
#   ((6, False, 1, 1, 4, 2), 'S'): -1.079801111110801,
#   ((9, False, 1, 1, 4, 2), 'N'): -0.798011111108011,
#   ((6, False, 1, 1, 4, 2), 'E'): 2.0198888889198896,
#   ((7, False, 1, 1, 4, 2), 'Pick'): 30.198888889198894,
#   ((7, True, 0, 1, 4, 2), 'SW'): 1.9888888919889252,
#   ((8, True, 0, 1, 4, 2), 'Deliver'): 29.88888891988925,
#   ((5, False, 3, 4, 1, 0), 'SW'): -1.1079797979798012,
#   ((4, False, 3, 4, 1, 0), 'NW'): -1.1107979797979801,
#   ((2, False, 3, 4, 1, 0), 'SE'): -1.1079797979798012,
#   ((4, False, 3, 4, 1, 0), 'SW'): -1.1080110801108014,
#   ((3, False, 3, 4, 1, 0), 'NW'): -1.1108011080110805,
#   ((1, False, 3, 4, 1, 0), 'SE'): -1.1080110801108014,
#   ((3, False, 3, 4, 1, 0), 'NE'): -1.1079797979798012,
#   ((4, False, 3, 4, 1, 0), 'NE'): -1.079797979798011,
#   ((7, True, 2, 4, 1, 0), 'SW'): 2.020202019888892,
#   ((8, True, 2, 4, 1, 0), 'Deliver'): 30.20202019888892,
#   ((8, False, 2, 4, 1, 1), 'NE'): 2.020201988889199,
#   ((7, True, 1, 4, 1, 1), 'SW'): 2.0201988889198894,
#   ((8, True, 1, 4, 1, 1), 'Deliver'): 30.20198888919889,
#   ((8, False, 1, 4, 1, 2), 'NE'): 2.01988889198892,
#   ((7, False, 1, 4, 1, 2), 'Pick'): 30.1988889198892,
#   ((7, True, 0, 4, 1, 2), 'W'): 1.988889198891989,
#   ((6, True, 0, 4, 1, 2), 'Deliver'): 29.888891988919887,
#   ((6, False, 0, 4, 2, 2), 'SW'): -1.1110801108011084,
#   ((5, False, 0, 4, 2, 2), 'NE'): -1.111108011080111,
#   ((6, False, 0, 4, 2, 2), 'S'): -1.1111108011080113,
#   ((9, False, 0, 4, 2, 2), 'N'): -1.111108011080111,
#   ((6, False, 0, 4, 2, 2), 'E'): -1.1111108011080113,
#   ((7, False, 0, 4, 2, 2), 'W'): -1.111108011080111,
#   ((5, False, 0, 4, 2, 2), 'SW'): -1.1108011080110805,
#   ((4, False, 0, 4, 2, 2), 'NW'): -1.1110801108011084,
#   ((2, False, 0, 4, 2, 2), 'SE'): -1.1108011080110805,
#   ((4, False, 0, 4, 2, 2), 'SW'): -1.1080110801108014,
#   ((3, False, 0, 4, 2, 2), 'NW'): -1.1108011080110805,
#   ((1, False, 0, 4, 2, 2), 'SE'): -1.1080110801108014,
#   ((3, False, 0, 4, 2, 2), 'NE'): -1.1108011080110805,
#   ((4, False, 0, 4, 2, 2), 'NE'): -1.1110801108011084,
#   ((7, False, 0, 4, 2, 2), 'SW'): -1.1111110801108013,
#   ((8, False, 0, 4, 2, 2), 'NE'): -1.1111108011080113,
#   ((3, False, 0, 4, 2, 2), 'SW'): -1.0801108011080114,
#   ((17, False, 0, 4, 2, 2), 'NE'): -1.1080110801108012,
#   ((17, False, 0, 4, 2, 2), 'SW'): -0.8011080110801108,
#   ((16, False, 0, 4, 2, 2), 'S'): -1.0801108011080112,
#   ((15, False, 0, 4, 2, 2), 'N'): -0.8011080110801108,
#   ((16, False, 0, 4, 2, 2), 'E'): 1.988919889198892,
#   ((11, False, 0, 4, 2, 2), 'Pick'): 29.88919889198892,
#   ((11, True, 0, 3, 2, 2), 'W'): -1.1080110801108014,
#   ((16, True, 0, 3, 2, 2), 'S'): -1.0801108011080112,
#   ((15, True, 0, 3, 2, 2), 'N'): -1.1080110801108012,
#   ((16, True, 0, 3, 2, 2), 'E'): -1.1108011080110802,
#   ((16, True, 0, 3, 2, 2), 'NE'): -1.11080110801108,
#   ((17, True, 0, 3, 2, 2), 'NE'): -1.1080111108011081,
#   ((3, True, 0, 3, 2, 2), 'NW'): -1.1108011110801108,
#   ((1, True, 0, 3, 2, 2), 'SE'): -1.108011110801108,
#   ((3, True, 0, 3, 2, 2), 'NE'): -1.0801111080110801,
#   ((4, True, 0, 3, 2, 2), 'NW'): -1.108011110801108,
#   ((2, True, 0, 3, 2, 2), 'SE'): -1.0801111080110801,
#   ((4, True, 0, 3, 2, 2), 'SW'): -1.108011110801108,
#   ((3, True, 0, 3, 2, 2), 'SW'): -1.11080110801108,
#   ((17, True, 0, 3, 2, 2), 'SW'): -1.1080110801108012,
#   ((15, True, 0, 3, 2, 2), 'SE'): -0.8011080110801108,
#   ((12, True, 0, 3, 2, 2), 'NW'): -1.0801108011080112,
#   ((4, True, 0, 3, 2, 2), 'NE'): -0.8011110801108011,
#   ((5, True, 0, 3, 2, 2), 'NE'): 1.988889198891989,
#   ((6, True, 0, 3, 2, 2), 'Deliver'): 29.888891988919887,
#   ((6, False, 0, 3, 3, 2), 'SW'): -1.1110801108011084,
#   ((5, False, 0, 3, 3, 2), 'NE'): -1.111108011080111,
#   ((6, False, 0, 3, 3, 2), 'S'): -1.1111108011080113,
#   ((9, False, 0, 3, 3, 2), 'N'): -1.111108011080111,
#   ((6, False, 0, 3, 3, 2), 'E'): -1.1111108011080113,
#   ((7, False, 0, 3, 3, 2), 'W'): -1.111108011080111,
#   ((5, False, 0, 3, 3, 2), 'SW'): -1.1108011080110805,
#   ((4, False, 0, 3, 3, 2), 'NW'): -1.1110801108011084,
#   ((2, False, 0, 3, 3, 2), 'SE'): -1.1108011080110805,
#   ((4, False, 0, 3, 3, 2), 'SW'): -1.1080110801108014,
#   ((3, False, 0, 3, 3, 2), 'NW'): -1.11080110801108,
#   ((1, False, 0, 3, 3, 2), 'SE'): -1.1080110801108012,
#   ((3, False, 0, 3, 3, 2), 'NE'): -1.1108011080110802,
#   ((4, False, 0, 3, 3, 2), 'NE'): -1.1110801108011084,
#   ((7, False, 0, 3, 3, 2), 'SW'): -1.1111110801108013,
#   ((8, False, 0, 3, 3, 2), 'NE'): -1.1111108011080113,
#   ((3, False, 0, 3, 3, 2), 'SW'): -1.0801108011080112,
#   ((17, False, 0, 3, 3, 2), 'NE'): -1.1080110801108012,
#   ((17, False, 0, 3, 3, 2), 'SW'): -0.8011080110801108,
#   ((16, False, 0, 3, 3, 2), 'S'): -1.0801108011080112,
#   ((15, False, 0, 3, 3, 2), 'N'): -0.8011080110801108,
#   ((16, False, 0, 3, 3, 2), 'E'): 1.988919889198892,
#   ((11, False, 0, 3, 3, 2), 'Pick'): 29.88919889198892,
#   ((11, True, 0, 2, 3, 2), 'W'): -1.1080110801108014,
#   ((16, True, 0, 2, 3, 2), 'S'): -1.0801108011080112,
#   ((15, True, 0, 2, 3, 2), 'N'): -1.1080110801108012,
#   ((16, True, 0, 2, 3, 2), 'E'): -1.1108011080110802,
#   ((16, True, 0, 2, 3, 2), 'NE'): -1.11080110801108,
#   ((17, True, 0, 2, 3, 2), 'NE'): -1.1080111108011081,
#   ((3, True, 0, 2, 3, 2), 'NW'): -1.1108011110801108,
#   ((1, True, 0, 2, 3, 2), 'SE'): -1.108011110801108,
#   ((3, True, 0, 2, 3, 2), 'NE'): -1.0801111080110801,
#   ((4, True, 0, 2, 3, 2), 'NW'): -1.108011110801108,
#   ((2, True, 0, 2, 3, 2), 'SE'): -1.0801111080110801,
#   ((4, True, 0, 2, 3, 2), 'SW'): -1.108011110801108,
#   ((3, True, 0, 2, 3, 2), 'SW'): -1.11080110801108,
#   ((17, True, 0, 2, 3, 2), 'SW'): -1.1080110801108012,
#   ((15, True, 0, 2, 3, 2), 'SE'): -0.8011080110801108,
#   ((12, True, 0, 2, 3, 2), 'NW'): -1.0801108011080112,
#   ((4, True, 0, 2, 3, 2), 'NE'): -0.8011110801108011,
#   ((5, True, 0, 2, 3, 2), 'NE'): 1.988889198891989,
#   ((6, True, 0, 2, 3, 2), 'Deliver'): 29.888891988919887,
#   ((5, True, 4, 3, 0, 0), 'SW'): -1.0797979797979798,
#   ((5, False, 4, 3, 1, 0), 'SW'): -1.107979797979798,
#   ((4, False, 4, 3, 1, 0), 'NW'): -1.11079797979798,
#   ((2, False, 4, 3, 1, 0), 'SE'): -1.107979797979798,
#   ((4, False, 4, 3, 1, 0), 'SW'): -1.1080110801108014,
#   ((3, False, 4, 3, 1, 0), 'NW'): -1.1108011080110805,
#   ((1, False, 4, 3, 1, 0), 'SE'): -1.1080110801108014,
#   ((3, False, 4, 3, 1, 0), 'NE'): -1.107979797979798,
#   ((4, False, 4, 3, 1, 0), 'NE'): -1.0797979797979798,
#   ((7, True, 3, 3, 1, 0), 'SW'): 2.020202020201989,
#   ((8, True, 3, 3, 1, 0), 'Deliver'): 30.202020202019888,
#   ((8, False, 3, 3, 1, 1), 'NE'): 2.020202020198889,
#   ((7, False, 3, 3, 1, 1), 'Pick'): 30.20202020198889,
#   ((7, True, 2, 3, 1, 1), 'W'): 2.020202019888892,
#   ((6, True, 2, 3, 1, 1), 'Deliver'): 30.20202019888892,
#   ((6, False, 2, 3, 2, 1), 'SW'): -1.079797980111108,
#   ((5, False, 2, 3, 2, 1), 'NE'): -0.7979798011110801,
#   ((6, False, 2, 3, 2, 1), 'S'): -1.079797980111108,
#   ((9, False, 2, 3, 2, 1), 'N'): -0.7979798011110801,
#   ((6, False, 2, 3, 2, 1), 'E'): 2.020201988889199,
#   ((7, False, 2, 3, 2, 1), 'Pick'): 30.20201988889199,
#   ((7, True, 1, 3, 2, 1), 'W'): 2.0201988889198894,
#   ((6, True, 1, 3, 2, 1), 'Deliver'): 30.20198888919889,
#   ((6, False, 1, 3, 3, 1), 'SW'): -1.079801111080111,
#   ((5, False, 1, 3, 3, 1), 'NE'): -0.798011110801108,
#   ((6, False, 1, 3, 3, 1), 'S'): -1.079801111080111,
#   ((9, False, 1, 3, 3, 1), 'N'): -0.798011110801108,
#   ((6, False, 1, 3, 3, 1), 'E'): 2.01988889198892,
#   ((7, False, 1, 3, 3, 1), 'Pick'): 30.1988889198892,
#   ((7, True, 0, 3, 3, 1), 'W'): 1.988889198891989,
#   ((7, True, 0, 0, 4, 3), 'SW'): 2.5,
#   ((8, True, 0, 0, 4, 3), 'Deliver'): 35.0,
#   ((8, False, 0, 0, 4, 4), 'NE'): 50.0,
#   ((7, True, 2, 4, 0, 1), 'SW'): 2.020202019888892,
#   ((8, True, 2, 4, 0, 1), 'Deliver'): 30.20202019888892,
#   ((8, False, 2, 4, 0, 2), 'NE'): 2.020201988889199,
#   ((7, False, 2, 4, 0, 2), 'Pick'): 30.20201988889199,
#   ((7, True, 1, 4, 0, 2), 'W'): 2.0201988889198894,
#   ((6, True, 1, 4, 0, 2), 'Deliver'): 30.20198888919889,
#   ((6, False, 1, 4, 1, 2), 'SW'): -1.079801111080111,
#   ((5, False, 1, 4, 1, 2), 'NE'): -0.798011110801108,
#   ((6, False, 1, 4, 1, 2), 'S'): -1.079801111080111,
#   ((9, False, 1, 4, 1, 2), 'N'): -0.798011110801108,
#   ((6, False, 1, 4, 1, 2), 'E'): 2.01988889198892,
#   ((7, True, 0, 4, 1, 2), 'SW'): 1.9888888919889198,
#   ((8, True, 0, 4, 1, 2), 'Deliver'): 29.888888919889197,
#   ((8, False, 0, 4, 1, 3), 'NE'): -1.1111108011080113,
#   ((7, False, 0, 4, 1, 3), 'W'): -1.111108011080111,
#   ((6, False, 0, 4, 1, 3), 'SW'): -1.1110801108011084,
#   ((5, False, 0, 4, 1, 3), 'NE'): -1.111108011080111,
#   ((6, False, 0, 4, 1, 3), 'S'): -1.1111108011080113,
#   ((9, False, 0, 4, 1, 3), 'N'): -1.111108011080111,
#   ((6, False, 0, 4, 1, 3), 'E'): -1.1111108011080113,
#   ((7, False, 0, 4, 1, 3), 'SW'): -1.1111110801108013,
#   ((5, False, 0, 4, 1, 3), 'SW'): -1.1108011080110805,
#   ((4, False, 0, 4, 1, 3), 'NW'): -1.1110801108011084,
#   ((2, False, 0, 4, 1, 3), 'SE'): -1.1108011080110805,
#   ((4, False, 0, 4, 1, 3), 'SW'): -1.1080110801108014,
#   ((3, False, 0, 4, 1, 3), 'NW'): -1.1108011080110805,
#   ((1, False, 0, 4, 1, 3), 'SE'): -1.1080110801108014,
#   ((3, False, 0, 4, 1, 3), 'NE'): -1.1108011080110805,
#   ((4, False, 0, 4, 1, 3), 'NE'): -1.1110801108011084,
#   ((3, False, 0, 4, 1, 3), 'SW'): -1.0801108011080114,
#   ((17, False, 0, 4, 1, 3), 'NE'): -1.1080110801108012,
#   ((17, False, 0, 4, 1, 3), 'SW'): -0.8011080110801111,
#   ((16, False, 0, 4, 1, 3), 'S'): -1.0801108011080112,
#   ((15, False, 0, 4, 1, 3), 'N'): -0.8011080110801111,
#   ((16, False, 0, 4, 1, 3), 'E'): 1.9889198891988893,
#   ((11, False, 0, 4, 1, 3), 'Pick'): 29.88919889198889,
#   ((11, True, 0, 3, 1, 3), 'W'): -1.1080110801111083,
#   ((16, True, 0, 3, 1, 3), 'S'): -1.08011080111108,
#   ((15, True, 0, 3, 1, 3), 'N'): -1.108011080111108,
#   ((16, True, 0, 3, 1, 3), 'E'): -1.1108011080111109,
#   ((16, True, 0, 3, 1, 3), 'NE'): -1.1108011080111109,
#   ((17, True, 0, 3, 1, 3), 'NE'): -1.1080111108011081,
#   ((3, True, 0, 3, 1, 3), 'NW'): -1.1108011110801108,
#   ((1, True, 0, 3, 1, 3), 'SE'): -1.108011110801108,
#   ((3, True, 0, 3, 1, 3), 'NE'): -1.0801111080110801,
#   ((4, True, 0, 3, 1, 3), 'NW'): -1.108011110801108,
#   ((2, True, 0, 3, 1, 3), 'SE'): -1.0801111080110801,
#   ((4, True, 0, 3, 1, 3), 'SW'): -1.108011110801108,
#   ((3, True, 0, 3, 1, 3), 'SW'): -1.1108011080111109,
#   ((17, True, 0, 3, 1, 3), 'SW'): -1.108011080111108,
#   ((15, True, 0, 3, 1, 3), 'SE'): -0.8011080111108011,
#   ((12, True, 0, 3, 1, 3), 'NW'): -1.08011080111108,
#   ((4, True, 0, 3, 1, 3), 'NE'): -0.8011110801108011,
#   ((5, True, 0, 3, 1, 3), 'NE'): 1.988889198891989,
#   ((6, True, 0, 3, 1, 3), 'Deliver'): 29.888891988919887,
#   ((6, False, 0, 3, 2, 3), 'SW'): -1.1110801108011084,
#   ((5, False, 0, 3, 2, 3), 'NE'): -1.111108011080111,
#   ((6, False, 0, 3, 2, 3), 'S'): -1.1111108011080113,
#   ((9, False, 0, 3, 2, 3), 'N'): -1.111108011080111,
#   ((6, False, 0, 3, 2, 3), 'E'): -1.1111108011080113,
#   ((7, False, 0, 3, 2, 3), 'W'): -1.111108011080111,
#   ((5, False, 0, 3, 2, 3), 'SW'): -1.1108011080110802,
#   ((4, False, 0, 3, 2, 3), 'NW'): -1.1110801108011081,
#   ((2, False, 0, 3, 2, 3), 'SE'): -1.11080110801108,
#   ((4, False, 0, 3, 2, 3), 'SW'): -1.1080110801108012,
#   ((3, False, 0, 3, 2, 3), 'NW'): -1.11080110801108,
#   ((1, False, 0, 3, 2, 3), 'SE'): -1.1080110801108012,
#   ((3, False, 0, 3, 2, 3), 'NE'): -1.11080110801108,
#   ((4, False, 0, 3, 2, 3), 'NE'): -1.1110801108011081,
#   ((7, False, 0, 3, 2, 3), 'SW'): -1.1111110801108013,
#   ((8, False, 0, 3, 2, 3), 'NE'): -1.1111108011080113,
#   ((3, False, 0, 3, 2, 3), 'SW'): -1.0801108011080112,
#   ((17, False, 0, 3, 2, 3), 'NE'): -1.1080110801108012,
#   ((17, False, 0, 3, 2, 3), 'SW'): -0.8011080110801111,
#   ((16, False, 0, 3, 2, 3), 'S'): -1.0801108011080112,
#   ((15, False, 0, 3, 2, 3), 'N'): -0.8011080110801111,
#   ((16, False, 0, 3, 2, 3), 'E'): 1.9889198891988893,
#   ((11, False, 0, 3, 2, 3), 'Pick'): 29.88919889198889,
#   ((11, True, 0, 2, 2, 3), 'W'): -1.1080110801111083,
#   ((16, True, 0, 2, 2, 3), 'S'): -1.08011080111108,
#   ((15, True, 0, 2, 2, 3), 'N'): -1.108011080111108,
#   ((16, True, 0, 2, 2, 3), 'E'): -1.1108011080111109,
#   ((16, True, 0, 2, 2, 3), 'NE'): -1.1108011080111109,
#   ((17, True, 0, 2, 2, 3), 'NE'): -1.1080111108011081,
#   ((3, True, 0, 2, 2, 3), 'NW'): -1.1108011110801108,
#   ((1, True, 0, 2, 2, 3), 'SE'): -1.108011110801108,
#   ((3, True, 0, 2, 2, 3), 'NE'): -1.0801111080110801,
#   ((4, True, 0, 2, 2, 3), 'NW'): -1.108011110801108,
#   ((2, True, 0, 2, 2, 3), 'SE'): -1.0801111080110801,
#   ((4, True, 0, 2, 2, 3), 'SW'): -1.108011110801108,
#   ((3, True, 0, 2, 2, 3), 'SW'): -1.1108011080111109,
#   ((17, True, 0, 2, 2, 3), 'SW'): -1.108011080111108,
#   ((15, True, 0, 2, 2, 3), 'SE'): -0.8011080111108011,
#   ((12, True, 0, 2, 2, 3), 'NW'): -1.08011080111108,
#   ((4, True, 0, 2, 2, 3), 'NE'): -0.8011110801108011,
#   ((5, True, 0, 2, 2, 3), 'NE'): 1.988889198891989,
#   ((6, True, 0, 2, 2, 3), 'Deliver'): 29.888891988919887,
#   ((6, False, 0, 2, 3, 3), 'SW'): -1.1110801108011084,
# ...
#   ((2, True, 0, 2, 3, 2), 'SE'): 2045,
#   ((4, True, 0, 2, 3, 2), 'SW'): 2045,
#   ((3, True, 0, 2, 3, 2), 'SW'): 3067,
#   ((17, True, 0, 2, 3, 2), 'SW'): 4089,
#   ((15, True, 0, 2, 3, 2), 'SE'): 3408,
#   ((12, True, 0, 2, 3, 2), 'NW'): 1704,
#   ((4, True, 0, 2, 3, 2), 'NE'): 2045,
#   ((5, True, 0, 2, 3, 2), 'NE'): 1023,
#   ((6, True, 0, 2, 3, 2), 'Deliver'): 1356,
#   ((5, True, 4, 3, 0, 0), 'SW'): 2810,
#   ((5, False, 4, 3, 1, 0), 'SW'): 2008,
#   ((4, False, 4, 3, 1, 0), 'NW'): 1607,
#   ((2, False, 4, 3, 1, 0), 'SE'): 1607,
#   ((4, False, 4, 3, 1, 0), 'SW'): 1607,
#   ((3, False, 4, 3, 1, 0), 'NW'): 1205,
#   ((1, False, 4, 3, 1, 0), 'SE'): 1205,
#   ((3, False, 4, 3, 1, 0), 'NE'): 1205,
#   ((4, False, 4, 3, 1, 0), 'NE'): 1606,
#   ((7, True, 3, 3, 1, 0), 'SW'): 1204,
#   ((8, True, 3, 3, 1, 0), 'Deliver'): 1204,
#   ((8, False, 3, 3, 1, 1), 'NE'): 1204,
#   ((7, False, 3, 3, 1, 1), 'Pick'): 1539,
#   ((7, True, 2, 3, 1, 1), 'W'): 770,
#   ((6, True, 2, 3, 1, 1), 'Deliver'): 871,
#   ((6, False, 2, 3, 2, 1), 'SW'): 767,
#   ((5, False, 2, 3, 2, 1), 'NE'): 663,
#   ((6, False, 2, 3, 2, 1), 'S'): 767,
#   ((9, False, 2, 3, 2, 1), 'N'): 767,
#   ((6, False, 2, 3, 2, 1), 'E'): 767,
#   ((7, False, 2, 3, 2, 1), 'Pick'): 1369,
#   ((7, True, 1, 3, 2, 1), 'W'): 685,
#   ((6, True, 1, 3, 2, 1), 'Deliver'): 771,
#   ((6, False, 1, 3, 3, 1), 'SW'): 670,
#   ((5, False, 1, 3, 3, 1), 'NE'): 569,
#   ((6, False, 1, 3, 3, 1), 'S'): 670,
#   ((9, False, 1, 3, 3, 1), 'N'): 670,
#   ((6, False, 1, 3, 3, 1), 'E'): 670,
#   ((7, False, 1, 3, 3, 1), 'Pick'): 965,
#   ((7, True, 0, 3, 3, 1), 'W'): 483,
#   ((7, True, 0, 0, 4, 3), 'SW'): 951,
#   ((8, True, 0, 0, 4, 3), 'Deliver'): 951,
#   ((8, False, 0, 0, 4, 4), 'NE'): 951,
#   ((7, True, 2, 4, 0, 1), 'SW'): 1876,
#   ((8, True, 2, 4, 0, 1), 'Deliver'): 1876,
#   ((8, False, 2, 4, 0, 2), 'NE'): 1876,
#   ((7, False, 2, 4, 0, 2), 'Pick'): 1876,
#   ((7, True, 1, 4, 0, 2), 'W'): 938,
#   ((6, True, 1, 4, 0, 2), 'Deliver'): 938,
#   ((6, False, 1, 4, 1, 2), 'SW'): 804,
#   ((5, False, 1, 4, 1, 2), 'NE'): 670,
#   ((6, False, 1, 4, 1, 2), 'S'): 804,
#   ((9, False, 1, 4, 1, 2), 'N'): 804,
#   ((6, False, 1, 4, 1, 2), 'E'): 804,
#   ((7, True, 0, 4, 1, 2), 'SW'): 1206,
#   ((8, True, 0, 4, 1, 2), 'Deliver'): 1206,
#   ((8, False, 0, 4, 1, 3), 'NE'): 12458,
#   ((7, False, 0, 4, 1, 3), 'W'): 11253,
#   ((6, False, 0, 4, 1, 3), 'SW'): 10048,
#   ((5, False, 0, 4, 1, 3), 'NE'): 8373,
#   ((6, False, 0, 4, 1, 3), 'S'): 10047,
#   ((9, False, 0, 4, 1, 3), 'N'): 10047,
#   ((6, False, 0, 4, 1, 3), 'E'): 10047,
#   ((7, False, 0, 4, 1, 3), 'SW'): 11252,
#   ((5, False, 0, 4, 1, 3), 'SW'): 8373,
#   ((4, False, 0, 4, 1, 3), 'NW'): 6699,
#   ((2, False, 0, 4, 1, 3), 'SE'): 6699,
#   ((4, False, 0, 4, 1, 3), 'SW'): 6699,
#   ((3, False, 0, 4, 1, 3), 'NW'): 5024,
#   ((1, False, 0, 4, 1, 3), 'SE'): 5024,
#   ((3, False, 0, 4, 1, 3), 'NE'): 5024,
#   ((4, False, 0, 4, 1, 3), 'NE'): 6698,
#   ((3, False, 0, 4, 1, 3), 'SW'): 5024,
#   ((17, False, 0, 4, 1, 3), 'NE'): 3349,
#   ((17, False, 0, 4, 1, 3), 'SW'): 3349,
#   ((16, False, 0, 4, 1, 3), 'S'): 1675,
#   ((15, False, 0, 4, 1, 3), 'N'): 1675,
#   ((16, False, 0, 4, 1, 3), 'E'): 1675,
#   ((11, False, 0, 4, 1, 3), 'Pick'): 1675,
#   ((11, True, 0, 3, 1, 3), 'W'): 4815,
#   ((16, True, 0, 3, 1, 3), 'S'): 3141,
#   ((15, True, 0, 3, 1, 3), 'N'): 2094,
#   ((16, True, 0, 3, 1, 3), 'E'): 3140,
#   ((16, True, 0, 3, 1, 3), 'NE'): 3140,
#   ((17, True, 0, 3, 1, 3), 'NE'): 2512,
#   ((3, True, 0, 3, 1, 3), 'NW'): 1884,
#   ((1, True, 0, 3, 1, 3), 'SE'): 1884,
#   ((3, True, 0, 3, 1, 3), 'NE'): 1884,
#   ((4, True, 0, 3, 1, 3), 'NW'): 1256,
#   ((2, True, 0, 3, 1, 3), 'SE'): 1256,
#   ((4, True, 0, 3, 1, 3), 'SW'): 1256,
#   ((3, True, 0, 3, 1, 3), 'SW'): 1884,
#   ((17, True, 0, 3, 1, 3), 'SW'): 2512,
#   ((15, True, 0, 3, 1, 3), 'SE'): 2094,
#   ((12, True, 0, 3, 1, 3), 'NW'): 1047,
#   ((4, True, 0, 3, 1, 3), 'NE'): 1255,
#   ((5, True, 0, 3, 1, 3), 'NE'): 628,
#   ((6, True, 0, 3, 1, 3), 'Deliver'): 904,
#   ((6, False, 0, 3, 2, 3), 'SW'): 10266,
#   ((5, False, 0, 3, 2, 3), 'NE'): 8788,
#   ((6, False, 0, 3, 2, 3), 'S'): 10265,
#   ((9, False, 0, 3, 2, 3), 'N'): 10265,
#   ((6, False, 0, 3, 2, 3), 'E'): 10265,
#   ((7, False, 0, 3, 2, 3), 'W'): 10839,
#   ((5, False, 0, 3, 2, 3), 'SW'): 8788,
#   ((4, False, 0, 3, 2, 3), 'NW'): 7311,
#   ((2, False, 0, 3, 2, 3), 'SE'): 7311,
#   ((4, False, 0, 3, 2, 3), 'SW'): 7311,
#   ((3, False, 0, 3, 2, 3), 'NW'): 5833,
#   ((1, False, 0, 3, 2, 3), 'SE'): 5833,
#   ((3, False, 0, 3, 2, 3), 'NE'): 5833,
#   ((4, False, 0, 3, 2, 3), 'NE'): 7310,
#   ((7, False, 0, 3, 2, 3), 'SW'): 10838,
#   ((8, False, 0, 3, 2, 3), 'NE'): 11412,
#   ((3, False, 0, 3, 2, 3), 'SW'): 5833,
#   ((17, False, 0, 3, 2, 3), 'NE'): 4355,
#   ((17, False, 0, 3, 2, 3), 'SW'): 4355,
#   ((16, False, 0, 3, 2, 3), 'S'): 2878,
#   ((15, False, 0, 3, 2, 3), 'N'): 4278,
#   ((16, False, 0, 3, 2, 3), 'E'): 2878,
#   ((11, False, 0, 3, 2, 3), 'Pick'): 2878,
#   ((11, True, 0, 2, 2, 3), 'W'): 8274,
#   ((16, True, 0, 2, 2, 3), 'S'): 5397,
#   ((15, True, 0, 2, 2, 3), 'N'): 3598,
#   ((16, True, 0, 2, 2, 3), 'E'): 5396,
#   ((16, True, 0, 2, 2, 3), 'NE'): 5396,
#   ((17, True, 0, 2, 2, 3), 'NE'): 4317,
#   ((3, True, 0, 2, 2, 3), 'NW'): 3238,
#   ((1, True, 0, 2, 2, 3), 'SE'): 3238,
#   ((3, True, 0, 2, 2, 3), 'NE'): 3238,
#   ((4, True, 0, 2, 2, 3), 'NW'): 2159,
#   ((2, True, 0, 2, 2, 3), 'SE'): 2159,
#   ((4, True, 0, 2, 2, 3), 'SW'): 2159,
#   ((3, True, 0, 2, 2, 3), 'SW'): 3238,
#   ((17, True, 0, 2, 2, 3), 'SW'): 4317,
#   ((15, True, 0, 2, 2, 3), 'SE'): 3598,
#   ((12, True, 0, 2, 2, 3), 'NW'): 1799,
#   ((4, True, 0, 2, 2, 3), 'NE'): 2158,
#   ((5, True, 0, 2, 2, 3), 'NE'): 1079,
#   ((6, True, 0, 2, 2, 3), 'Deliver'): 1417,
#   ((6, False, 0, 2, 3, 3), 'SW'): 12202,
#   ((5, False, 0, 2, 3, 3), 'NE'): 10452,
#   ((6, False, 0, 2, 3, 3), 'S'): 12201,
#   ((9, False, 0, 2, 3, 3), 'N'): 12201,
#   ((6, False, 0, 2, 3, 3), 'E'): 12201,
#   ((7, False, 0, 2, 3, 3), 'W'): 12534,
#   ((5, False, 0, 2, 3, 3), 'SW'): 10452,
#   ((4, False, 0, 2, 3, 3), 'NW'): 8703,
#   ((2, False, 0, 2, 3, 3), 'SE'): 8703,
#   ((4, False, 0, 2, 3, 3), 'SW'): 8703,
#   ((3, False, 0, 2, 3, 3), 'NW'): 6953,
#   ((1, False, 0, 2, 3, 3), 'SE'): 6953,
#   ((3, False, 0, 2, 3, 3), 'NE'): 6953,
#   ((4, False, 0, 2, 3, 3), 'NE'): 8702,
#   ((7, False, 0, 2, 3, 3), 'SW'): 12533,
#   ((8, False, 0, 2, 3, 3), 'NE'): 12866,
#   ((3, False, 0, 2, 3, 3), 'SW'): 6953,
#   ((17, False, 0, 2, 3, 3), 'NE'): 5203,
#   ((17, False, 0, 2, 3, 3), 'SW'): 5203,
#   ((16, False, 0, 2, 3, 3), 'S'): 3454,
#   ((15, False, 0, 2, 3, 3), 'N'): 5158,
#   ((16, False, 0, 2, 3, 3), 'E'): 3454,
#   ((11, False, 0, 2, 3, 3), 'Pick'): 3454,
#   ((11, True, 0, 1, 3, 3), 'W'): 9930,
#   ((16, True, 0, 1, 3, 3), 'S'): 6477,
#   ((15, True, 0, 1, 3, 3), 'N'): 4318,
#   ((16, True, 0, 1, 3, 3), 'E'): 6476,
#   ((16, True, 0, 1, 3, 3), 'NE'): 6476,
#   ((17, True, 0, 1, 3, 3), 'NE'): 5181,
#   ((3, True, 0, 1, 3, 3), 'NW'): 3886,
#   ((1, True, 0, 1, 3, 3), 'SE'): 3886,
#   ((3, True, 0, 1, 3, 3), 'NE'): 3886,
#   ((4, True, 0, 1, 3, 3), 'NW'): 2591,
#   ((2, True, 0, 1, 3, 3), 'SE'): 2591,
#   ((4, True, 0, 1, 3, 3), 'SW'): 2591,
#   ((3, True, 0, 1, 3, 3), 'SW'): 3886,
#   ((17, True, 0, 1, 3, 3), 'SW'): 5181,
#   ((15, True, 0, 1, 3, 3), 'SE'): 4318,
#   ((12, True, 0, 1, 3, 3), 'NW'): 2159,
#   ((4, True, 0, 1, 3, 3), 'NE'): 2590,
#   ((5, True, 0, 1, 3, 3), 'NE'): 1295,
#   ((6, True, 0, 1, 3, 3), 'Deliver'): 1515,
#   ((4, False, 4, 3, 0, 1), 'NE'): 2006,
#   ((5, False, 4, 3, 0, 1), 'NE'): 1338,
#   ((6, False, 4, 3, 0, 1), 'SW'): 669,
#   ((5, False, 4, 3, 0, 1), 'SW'): 1337,
#   ((16, False, 4, 2, 0, 2), 'NE'): 2150,
#   ((17, False, 4, 2, 0, 2), 'NE'): 1792,
#   ((3, False, 4, 2, 0, 2), 'NW'): 1434,
#   ((1, False, 4, 2, 0, 2), 'SE'): 1434,
#   ((3, False, 4, 2, 0, 2), 'NE'): 1434,
#   ((4, False, 4, 2, 0, 2), 'NW'): 1076,
#   ((2, False, 4, 2, 0, 2), 'SE'): 1076,
#   ((4, False, 4, 2, 0, 2), 'SW'): 1076,
#   ((3, False, 4, 2, 0, 2), 'SW'): 1434,
#   ((17, False, 4, 2, 0, 2), 'SW'): 1792,
#   ((12, True, 4, 1, 0, 2), 'SE'): 1345,
#   ((13, True, 4, 1, 0, 2), 'Deliver'): 1345,
#   ((13, False, 4, 1, 0, 3), 'NW'): 5183,
#   ((12, False, 4, 1, 0, 3), 'NW'): 3840,
#   ((15, False, 4, 1, 0, 3), 'N'): 2497,
#   ((16, False, 4, 1, 0, 3), 'S'): 1152,
#   ((15, False, 4, 1, 0, 3), 'SE'): 2495,
#   ((12, False, 4, 1, 0, 3), 'SE'): 3838,
#   ((16, False, 4, 1, 0, 3), 'E'): 1153,
#   ((11, False, 4, 1, 0, 3), 'Pick'): 1153,
#   ((11, True, 4, 0, 0, 3), 'W'): 3312,
#   ((16, True, 4, 0, 0, 3), 'S'): 2161,
#   ((15, True, 4, 0, 0, 3), 'N'): 1440,
#   ((16, True, 4, 0, 0, 3), 'E'): 2159,
#   ((16, True, 4, 0, 0, 3), 'NE'): 2159,
#   ((17, True, 4, 0, 0, 3), 'NE'): 1727,
#   ((3, True, 4, 0, 0, 3), 'NW'): 1295,
#   ((1, True, 4, 0, 0, 3), 'SE'): 1295,
#   ((3, True, 4, 0, 0, 3), 'NE'): 1295,
#   ((4, True, 4, 0, 0, 3), 'NW'): 863,
#   ((2, True, 4, 0, 0, 3), 'SE'): 863,
#   ((4, True, 4, 0, 0, 3), 'SW'): 863,
#   ((3, True, 4, 0, 0, 3), 'SW'): 1295,
#   ((17, True, 4, 0, 0, 3), 'SW'): 1727,
#   ((15, True, 4, 0, 0, 3), 'SE'): 1441,
#   ((12, True, 4, 0, 0, 3), 'NW'): 720,
#   ((4, True, 4, 0, 0, 3), 'NE'): 863,
#   ((5, True, 4, 0, 0, 3), 'NE'): 432,
#   ((6, True, 4, 0, 0, 3), 'Deliver'): 432,
#   ((6, False, 4, 0, 1, 3), 'SW'): 648,
#   ((5, False, 4, 0, 1, 3), 'NE'): 864,
#   ((6, False, 4, 0, 1, 3), 'S'): 648,
#   ((9, False, 4, 0, 1, 3), 'N'): 648,
#   ((6, False, 4, 0, 1, 3), 'E'): 648,
#   ((7, False, 4, 0, 1, 3), 'Pick'): 648,
#   ((7, True, 3, 0, 1, 3), 'W'): 324,
#   ((6, True, 3, 0, 1, 3), 'Deliver'): 370,
#   ((6, False, 3, 0, 2, 3), 'SW'): 483,
#   ((5, False, 3, 0, 2, 3), 'NE'): 596,
#   ((6, False, 3, 0, 2, 3), 'S'): 483,
#   ((9, False, 3, 0, 2, 3), 'N'): 483,
#   ((6, False, 3, 0, 2, 3), 'E'): 483,
#   ((7, False, 3, 0, 2, 3), 'Pick'): 559,
#   ((7, True, 2, 0, 2, 3), 'W'): 280,
#   ((6, True, 2, 0, 2, 3), 'Deliver'): 335,
#   ((6, False, 2, 0, 3, 3), 'SW'): 403,
#   ((5, False, 2, 0, 3, 3), 'NE'): 471,
#   ((6, False, 2, 0, 3, 3), 'S'): 403,
#   ((9, False, 2, 0, 3, 3), 'N'): 403,
#   ((6, False, 2, 0, 3, 3), 'E'): 403,
#   ((7, False, 2, 0, 3, 3), 'Pick'): 488,
#   ((7, True, 1, 0, 3, 3), 'W'): 244,
#   ((6, True, 1, 0, 3, 3), 'Deliver'): 291,
#   ((6, False, 1, 0, 4, 3), 'SW'): 429,
#   ((5, False, 1, 0, 4, 3), 'NE'): 493,
#   ((6, False, 1, 0, 4, 3), 'S'): 429,
#   ((9, False, 1, 0, 4, 3), 'N'): 503,
#   ((6, False, 1, 0, 4, 3), 'E'): 429,
#   ((7, False, 1, 0, 4, 3), 'Pick'): 552,
#   ((3, False, 3, 4, 1, 0), 'SW'): 1607,
#   ((17, False, 3, 4, 1, 0), 'NE'): 1071,
#   ((5, False, 2, 4, 2, 0), 'SW'): 1148,
#   ((4, False, 2, 4, 2, 0), 'NW'): 919,
#   ((2, False, 2, 4, 2, 0), 'SE'): 919,
#   ((4, False, 2, 4, 2, 0), 'SW'): 919,
#   ((3, False, 2, 4, 2, 0), 'NW'): 689,
#   ((1, False, 2, 4, 2, 0), 'SE'): 689,
#   ((3, False, 2, 4, 2, 0), 'NE'): 689,
#   ((4, False, 2, 4, 2, 0), 'NE'): 918,
#   ((7, True, 1, 4, 2, 0), 'SW'): 689,
#   ((8, True, 1, 4, 2, 0), 'Deliver'): 689,
#   ((8, False, 1, 4, 2, 1), 'NE'): 689,
#   ((7, True, 0, 4, 2, 1), 'SW'): 1034,
#   ((8, True, 0, 4, 2, 1), 'Deliver'): 1034,
#   ((16, False, 0, 4, 2, 2), 'NE'): 2239,
#   ((15, False, 0, 4, 2, 2), 'SE'): 2239,
#   ((12, False, 0, 4, 2, 2), 'NW'): 2239,
#   ((12, True, 0, 3, 2, 2), 'SE'): 1400,
#   ((13, True, 0, 3, 2, 2), 'Deliver'): 1400,
#   ((13, False, 0, 3, 2, 3), 'NW'): 7076,
#   ((12, False, 0, 3, 2, 3), 'NW'): 5677,
#   ((15, False, 0, 3, 2, 3), 'SE'): 4277,
#   ((12, False, 0, 3, 2, 3), 'SE'): 5676,
#   ((16, False, 0, 3, 2, 3), 'NE'): 2877,
#   ((12, True, 0, 2, 2, 3), 'SE'): 1799,
#   ((13, True, 0, 2, 2, 3), 'Deliver'): 1799,
#   ((13, False, 0, 2, 2, 4), 'NW'): 9747,
#   ((12, False, 0, 2, 2, 4), 'NW'): 7949,
#   ((15, False, 0, 2, 2, 4), 'N'): 6151,
#   ((16, False, 0, 2, 2, 4), 'S'): 4352,
#   ((15, False, 0, 2, 2, 4), 'SE'): 6150,
#   ((12, False, 0, 2, 2, 4), 'SE'): 7948,
#   ((16, False, 0, 2, 2, 4), 'E'): 4352,
#   ((11, False, 0, 2, 2, 4), 'Pick'): 4352,
#   ((11, True, 0, 1, 2, 4), 'W'): 26109,
#   ((16, True, 0, 1, 2, 4), 'S'): 21757,
#   ((15, True, 0, 1, 2, 4), 'N'): 21757,
#   ((16, True, 0, 1, 2, 4), 'E'): 21757,
#   ((16, True, 0, 1, 2, 4), 'NE'): 21757,
#   ((17, True, 0, 1, 2, 4), 'NE'): 17406,
#   ((3, True, 0, 1, 2, 4), 'NW'): 13055,
#   ((1, True, 0, 1, 2, 4), 'SE'): 13055,
#   ((3, True, 0, 1, 2, 4), 'NE'): 13055,
#   ((4, True, 0, 1, 2, 4), 'NW'): 8703,
#   ((2, True, 0, 1, 2, 4), 'SE'): 8703,
#   ((4, True, 0, 1, 2, 4), 'SW'): 8703,
#   ((3, True, 0, 1, 2, 4), 'SW'): 13054,
#   ((17, True, 0, 1, 2, 4), 'SW'): 17405,
#   ((15, True, 0, 1, 2, 4), 'SE'): 21756,
#   ((12, True, 0, 1, 2, 4), 'NW'): 21756,
#   ((4, True, 0, 1, 2, 4), 'NE'): 8703,
#   ((5, True, 0, 1, 2, 4), 'NE'): 4352,
#   ((6, True, 0, 1, 2, 4), 'Deliver'): 4934,
#   ((6, False, 0, 1, 3, 4), 'SW'): 33081,
#   ((5, False, 0, 1, 3, 4), 'NE'): 27927,
#   ((6, False, 0, 1, 3, 4), 'S'): 33080,
#   ((9, False, 0, 1, 3, 4), 'N'): 33080,
#   ((6, False, 0, 1, 3, 4), 'E'): 33080,
#   ((7, False, 0, 1, 3, 4), 'W'): 33300,
#   ((5, False, 0, 1, 3, 4), 'SW'): 27927,
#   ((4, False, 0, 1, 3, 4), 'NW'): 22774,
#   ((2, False, 0, 1, 3, 4), 'SE'): 22774,
#   ((4, False, 0, 1, 3, 4), 'SW'): 22774,
#   ((3, False, 0, 1, 3, 4), 'NW'): 17620,
#   ((1, False, 0, 1, 3, 4), 'SE'): 17620,
#   ((3, False, 0, 1, 3, 4), 'NE'): 17620,
#   ((4, False, 0, 1, 3, 4), 'NE'): 22773,
#   ((7, False, 0, 1, 3, 4), 'SW'): 33299,
#   ((8, False, 0, 1, 3, 4), 'NE'): 33519,
#   ((3, False, 0, 1, 3, 4), 'SW'): 17620,
#   ((17, False, 0, 1, 3, 4), 'NE'): 12466,
#   ((17, False, 0, 1, 3, 4), 'SW'): 12466,
#   ((16, False, 0, 1, 3, 4), 'S'): 7313,
#   ((15, False, 0, 1, 3, 4), 'N'): 9472,
#   ((16, False, 0, 1, 3, 4), 'E'): 7313,
#   ((11, False, 0, 1, 3, 4), 'Pick'): 7313,
#   ((11, True, 0, 0, 3, 4), 'W'): 43875,
#   ((16, True, 0, 0, 3, 4), 'S'): 36562,
#   ((15, True, 0, 0, 3, 4), 'N'): 36562,
#   ((16, True, 0, 0, 3, 4), 'E'): 36562,
#   ((16, True, 0, 0, 3, 4), 'NE'): 36562,
#   ((17, True, 0, 0, 3, 4), 'NE'): 29250,
#   ((3, True, 0, 0, 3, 4), 'NW'): 21938,
#   ((1, True, 0, 0, 3, 4), 'SE'): 21938,
#   ((3, True, 0, 0, 3, 4), 'NE'): 21938,
#   ((4, True, 0, 0, 3, 4), 'NW'): 14625,
#   ((2, True, 0, 0, 3, 4), 'SE'): 14625,
#   ((4, True, 0, 0, 3, 4), 'SW'): 14625,
#   ((3, True, 0, 0, 3, 4), 'SW'): 21937,
#   ((17, True, 0, 0, 3, 4), 'SW'): 29249,
#   ((15, True, 0, 0, 3, 4), 'SE'): 36561,
#   ((12, True, 0, 0, 3, 4), 'NW'): 36561,
#   ((4, True, 0, 0, 3, 4), 'NE'): 14625,
#   ((5, True, 0, 0, 3, 4), 'NE'): 7313,
#   ((6, True, 0, 0, 3, 4), 'Deliver'): 9331,
#   ((6, False, 0, 0, 4, 4), 'SW'): 3111,
#   ((5, False, 2, 4, 1, 1), 'SW'): 1340,
#   ((4, False, 2, 4, 1, 1), 'NW'): 1072,
#   ((2, False, 2, 4, 1, 1), 'SE'): 1072,
#   ((4, False, 2, 4, 1, 1), 'SW'): 1072,
#   ((3, False, 2, 4, 1, 1), 'NW'): 804,
#   ((1, False, 2, 4, 1, 1), 'SE'): 804,
#   ((3, False, 2, 4, 1, 1), 'NE'): 804,
#   ((4, False, 2, 4, 1, 1), 'NE'): 1072,
#   ((5, False, 1, 4, 2, 1), 'SW'): 1148,
#   ((4, False, 1, 4, 2, 1), 'NW'): 919,
#   ((2, False, 1, 4, 2, 1), 'SE'): 919,
#   ((4, False, 1, 4, 2, 1), 'SW'): 919,
#   ((3, False, 1, 4, 2, 1), 'NW'): 689,
#   ((1, False, 1, 4, 2, 1), 'SE'): 689,
#   ((3, False, 1, 4, 2, 1), 'NE'): 689,
#   ((4, False, 1, 4, 2, 1), 'NE'): 918,
#   ((16, False, 0, 4, 3, 1), 'NE'): 1328,
#   ((15, False, 0, 4, 3, 1), 'SE'): 1328,
#   ((12, False, 0, 4, 3, 1), 'NW'): 1328,
#   ((12, True, 0, 3, 3, 1), 'SE'): 830,
#   ((13, True, 0, 3, 3, 1), 'Deliver'): 830,
#   ((13, False, 0, 3, 3, 2), 'NW'): 5215,
#   ((12, False, 0, 3, 3, 2), 'NW'): 4386,
#   ((15, False, 0, 3, 3, 2), 'SE'): 3556,
#   ((12, False, 0, 3, 3, 2), 'SE'): 4385,
#   ((16, False, 0, 3, 3, 2), 'NE'): 2726,
#   ((12, True, 0, 2, 3, 2), 'SE'): 1704,
#   ((13, True, 0, 2, 3, 2), 'Deliver'): 1704,
#   ((13, False, 0, 2, 3, 3), 'NW'): 8564,
#   ((12, False, 0, 2, 3, 3), 'NW'): 6861,
#   ((15, False, 0, 2, 3, 3), 'SE'): 5157,
#   ((12, False, 0, 2, 3, 3), 'SE'): 6860,
#   ((16, False, 0, 2, 3, 3), 'NE'): 3453,
#   ((12, True, 0, 1, 3, 3), 'SE'): 2159,
#   ((13, True, 0, 1, 3, 3), 'Deliver'): 2159,
#   ((13, False, 0, 1, 3, 4), 'NW'): 13788,
#   ((12, False, 0, 1, 3, 4), 'NW'): 11630,
#   ((15, False, 0, 1, 3, 4), 'SE'): 9471,
#   ((12, False, 0, 1, 3, 4), 'SE'): 11629,
#   ((16, False, 0, 1, 3, 4), 'NE'): 7312,
#   ((12, True, 0, 0, 3, 4), 'SE'): 36560,
#   ((13, True, 0, 0, 3, 4), 'NW'): 36560,
#   ((5, True, 0, 0, 3, 4), 'SW'): 7312,
#   ((6, False, 0, 0, 4, 4), 'S'): 3110,
#   ((6, False, 4, 3, 0, 1), 'S'): 669,
#   ((9, False, 4, 3, 0, 1), 'N'): 669,
#   ((6, False, 4, 3, 0, 1), 'E'): 669,
#   ((7, False, 4, 3, 0, 1), 'Pick'): 669,
#   ...})
